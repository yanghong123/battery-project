# %% [markdown]
# battery json data  convert to matrix and input to CNN for train

# %%
from sklearn import preprocessing 
from scipy.io import loadmat, whosmat
import numpy as np
import datetime
import json
import os
# 获取得到 json data of battery 
def json_load(dictonary):
    with open(dictonary) as f:
        data = json.load(f)
    return data

'''
cycle为行数，循环读取一行数据，对一行数据里面的voltage,current and temp求均值，并添加capacity features
得到battery array
'''
def batteryData2array(battery_data):
    vol_sum = 0
    cur_sum = 0
    temp_sum=0
    battery_array = []
    for cycle in battery_data.keys():
        # list type 
        battery_vols = battery_data[cycle]["voltage_battery"]
        battery_curs = battery_data[cycle]["current_battery"]
        battery_temps=battery_data[cycle]["temp_battery"]
        battery_capacity=battery_data[cycle]["Capacity"]
        for battery_vol in battery_vols:
            vol_sum += float(battery_vol)
        for battery_cur in battery_curs:
            cur_sum += float(battery_cur)
        for battery_temp in battery_temps:
            temp_sum += float(battery_temp)
        #for voltage and current average  & battery_vols,battery_curs,battery_temps's len is equal
        num = len(battery_vols)
        vol_aver = vol_sum / num
        cur_aver = cur_sum / num
        temp_aver=temp_sum/num
        vol_sum = 0
        cur_sum = 0
        temp_sum=0
        battery_array.append([vol_aver,cur_aver,temp_aver,battery_capacity[0]])
#         battery_array.append([vol_aver,cur_aver,battery_capacity[0]])
    return battery_array

# get battery's true soc
def  getTrueSOC(battery_discharge_data):
    batteryCapcity=2
    soc_dict=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        soc_true=cycleCapacity[0]/batteryCapcity
        soc_dict.append(soc_true)
    return soc_dict

# get battery's discgarge capacity
def  getTrueCapacity(battery_discharge_data):
    capacity=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        capacity.append(cycleCapacity[0])
    return capacity

'''
获取得到 battery 's img matrix 图像矩阵  4维特征向量  vol_aver,cur_aver,temp_aver,battery_capacity
返回battery discharge matrix and true soc array
'''
def batterydata2matrix(discharge):
    #get the discharge and charge json data
    discharge_data =json_load(discharge)
    
    #get the true soc data
    true_soc=getTrueSOC(discharge_data)
#   true_capacity=getTrueCapacity(discharge_data)
    #get the battery discharge array data  convert to matrix
    discharge_array = batteryData2array(discharge_data)
    discharge_matrix = np.array(discharge_array)

    discharge_matrix=preprocessing.scale(discharge_matrix)
    return discharge_matrix,true_soc

'''
获取得到每一节电池数据的训练数据集
得到train & test data
'''
def getTrainData(discharge_matrix,true_soc):     
    #循环切片形成数据集
    x=[];y=[]
    x_train=[];y_train=[]
    flag=0

    # 获取得到x,y的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取长度为8的矩阵，叠加循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成4*T的时间维度
            x.append(bataery_data_training.T)
        flag+=1
    #0-》t时刻d x 预测得到t时刻的soc。为了对soc 进行预测，y矩阵为【7：】
    y=true_soc[7:]
#     y=true_capacity[8:]

    VALIDATION_SPLIT=0.9
    x_validation_samples = int( VALIDATION_SPLIT* len(x))
    y_validation_samples = int( VALIDATION_SPLIT*len(y))
    
    
    # 获取得到训练集，验证集，比例9:1
    x_train=np.array(x[:x_validation_samples])
    x_test=np.array(x[x_validation_samples:])
    y_train=np.array(y[:y_validation_samples])
    y_test=np.array(y[y_validation_samples:])
    print("x_train's shape is:", x_train.shape,"，y_train's shape is:",y_train.shape)
    print("x_test's shape is:",x_test.shape,"，y_test's shape is:",y_test.shape)
    return x_train,x_test,y_train,y_test

# %%
# 定义全局变量，将所有电池数据集集合起来，形成训练集，测试集
# x_train_all,x_test_all,y_train_all,y_test_all=[],[],[],[]
for i in range(5,8):
    discharge=r'/home/zsj/yangHong/battery experiment/jsonData/B000'+str(i)+'_discharge.json'
    discharge_matrix,true_soc=batterydata2matrix(discharge)
    train_x,test_x,train_y,test_y=getTrainData(discharge_matrix,true_soc)
    # start 开始时先赋值给x_train_all，x_test_all，y_train_all，y_test_all
    if i==5:
        x_train_all=train_x
        x_test_all=test_x
        y_train_all=train_y
        y_test_all=test_y
    else:
        x_train_all=np.concatenate((x_train_all,train_x),axis=0)
        x_test_all=np.concatenate((x_test_all,test_x),axis=0)
        y_train_all=np.concatenate((y_train_all,train_y),axis=0)
        y_test_all=np.concatenate((y_test_all,test_y),axis=0)
print(np.array(x_train_all).shape,np.array(x_test_all).shape,np.array(y_train_all).shape,np.array(y_test_all).shape)
# Out:
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 4, 8) ，y_test's shape is: (17,)
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 4, 8) ，y_test's shape is: (17,)
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 4, 8) ，y_test's shape is: (17,)
# (432, 4, 8) (51, 4, 8) (432,) (51,)

# %%
#写一个LossHistory类，保存loss和mae
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as k
import matplotlib.pyplot as plt
import numpy as np
from keras import backend as K
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = {'batch':[], 'epoch':[]}
        self.accuracy = {'batch':[], 'epoch':[]}
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_acc = {'batch':[], 'epoch':[]}

    def on_batch_end(self, batch, logs={}):
        self.losses['batch'].append(logs.get('loss'))
        self.accuracy['batch'].append(logs.get('mean_absolute_error'))
        self.val_loss['batch'].append(logs.get('val_loss'))
        self.val_acc['batch'].append(logs.get('val_mean_absolute_error'))

    def on_epoch_end(self, batch, logs={}):
        self.losses['epoch'].append(logs.get('loss'))
        self.accuracy['epoch'].append(logs.get('mean_absolute_error'))
        self.val_loss['epoch'].append(logs.get('val_loss'))
        self.val_acc['epoch'].append(logs.get('val_mean_absolute_error'))

    def loss_plot(self, loss_type):
        iters = range(len(self.losses[loss_type]))
        plt.figure()
        # mae
        plt.plot(iters, self.accuracy[loss_type], 'r', label='train mae')
        # loss
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        if loss_type == 'epoch':
            # val_mean_absolute_error
            plt.plot(iters, self.val_acc[loss_type], 'b', label='val mean absolute error')
            # val_loss
            plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('mae-loss')
        plt.legend(loc="upper right")
        plt.show()
# Out:
# Using TensorFlow backend.

# %%
#使用cnn训练的模型
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras import regularizers
from keras.optimizers import SGD, Adam

num=1
img_rows, img_cols =x_train_all.shape[1],x_train_all.shape[2]
if K.image_dim_ordering() == 'th':
    x_train_all = x_train_all.reshape(x_train_all.shape[0], 1, img_rows, img_cols)
    x_test_all = x_test_all.reshape(x_test_all.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train_all = x_train_all.reshape(x_train_all.shape[0], img_rows, img_cols, 1)
    x_test_all= x_test_all.reshape(x_test_all.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)
# print(x_train.shape,x_test.shape)
# print(y_train.shape)
# keras序贯模型搭建CNN
# model building
model = Sequential()
#convolutional layer with rectified linear unit activation
model.add(Conv2D(32, kernel_size=(1,2),
                 activation='relu',
                 input_shape=input_shape,padding="same"))
#32 convolution filters used each of size 3x3
#again
model.add(Conv2D(32, (2,2), activation='relu',padding="same"))
#64 convolution filters used each of size 3x3
#choose the best features via pooling
model.add(MaxPooling2D(pool_size=(2, 2)))

#randomly turn neurons on and off to improve convergence
# model.add(Dropout(0.25))
#flatten since too many dimensions, we only want a classification output
model.add(Flatten())
#fully connected to get all relevant data
model.add(Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.25))

model.add(Dense(16, activation='relu'))
model.add(Dropout(0.35))
# model.add(Dense(num, activation='sigmoid'))
# The last layer does not use the activation function
model.add(Dense(num))

#Adaptive learning rate (adaDelta) is a popular form of gradient descent rivaled only by adam and adagrad
#categorical ce since we have multiple classes (10) 
# model.compile(loss=keras.losses.sparse_categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])
#回归问题评价指标使用mae
model.compile(loss='mse', optimizer="sgd", metrics=["mae"])


batch_size =16
num_epoch = 64


# decay_rate = learning_rate / num_epoch
# momentum = 0.8
# sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)

# model.compile(loss='mse', optimizer=sgd, metrics=["mae"])
#model training
history = LossHistory()
model.fit(x_train_all, y_train_all,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,validation_split=0.2,callbacks=[history])

mse_score,mae_score= model.evaluate(x_test_all, y_test_all, verbose=0)
print('Test MSE Score:%.3f %%'% (mse_score*100)) 
print('Test MAE Score:%.3f %%'% (mae_score*100))
# Out:
# Train on 345 samples, validate on 87 samples
# Epoch 1/64
# 345/345 [==============================] - 0s - loss: 0.2739 - mean_absolute_error: 0.4005 - val_loss: 0.1285 - val_mean_absolute_error: 0.2337
# Epoch 2/64
# 345/345 [==============================] - 0s - loss: 0.1739 - mean_absolute_error: 0.2814 - val_loss: 0.0960 - val_mean_absolute_error: 0.1689
# Epoch 3/64
# 345/345 [==============================] - 0s - loss: 0.1372 - mean_absolute_error: 0.2330 - val_loss: 0.0823 - val_mean_absolute_error: 0.1345
# Epoch 4/64
# 345/345 [==============================] - 0s - loss: 0.1222 - mean_absolute_error: 0.2081 - val_loss: 0.0770 - val_mean_absolute_error: 0.1218
# Epoch 5/64
# 345/345 [==============================] - 0s - loss: 0.1094 - mean_absolute_error: 0.1787 - val_loss: 0.0726 - val_mean_absolute_error: 0.1086
# Epoch 6/64
# 345/345 [==============================] - 0s - loss: 0.1015 - mean_absolute_error: 0.1701 - val_loss: 0.0704 - val_mean_absolute_error: 0.1015
# Epoch 7/64
# 345/345 [==============================] - 0s - loss: 0.0928 - mean_absolute_error: 0.1527 - val_loss: 0.0688 - val_mean_absolute_error: 0.0972
# Epoch 8/64
# 345/345 [==============================] - 0s - loss: 0.0905 - mean_absolute_error: 0.1447 - val_loss: 0.0634 - val_mean_absolute_error: 0.0680
# Epoch 9/64
# 345/345 [==============================] - 0s - loss: 0.0879 - mean_absolute_error: 0.1364 - val_loss: 0.0640 - val_mean_absolute_error: 0.0741
# Epoch 10/64
# 345/345 [==============================] - 0s - loss: 0.0843 - mean_absolute_error: 0.1290 - val_loss: 0.0651 - val_mean_absolute_error: 0.0812
# Epoch 11/64
# 345/345 [==============================] - 0s - loss: 0.0781 - mean_absolute_error: 0.1138 - val_loss: 0.0619 - val_mean_absolute_error: 0.0610
# Epoch 12/64
# 345/345 [==============================] - 0s - loss: 0.0783 - mean_absolute_error: 0.1148 - val_loss: 0.0616 - val_mean_absolute_error: 0.0600
# Epoch 13/64
# 345/345 [==============================] - 0s - loss: 0.0752 - mean_absolute_error: 0.1095 - val_loss: 0.0612 - val_mean_absolute_error: 0.0578
# Epoch 14/64
# 345/345 [==============================] - 0s - loss: 0.0751 - mean_absolute_error: 0.1019 - val_loss: 0.0625 - val_mean_absolute_error: 0.0692
# Epoch 15/64
# 345/345 [==============================] - 0s - loss: 0.0726 - mean_absolute_error: 0.0992 - val_loss: 0.0612 - val_mean_absolute_error: 0.0602
# Epoch 16/64
# 345/345 [==============================] - 0s - loss: 0.0717 - mean_absolute_error: 0.0952 - val_loss: 0.0616 - val_mean_absolute_error: 0.0642
# Epoch 17/64
# 345/345 [==============================] - 0s - loss: 0.0707 - mean_absolute_error: 0.0886 - val_loss: 0.0607 - val_mean_absolute_error: 0.0572
# Epoch 18/64
# 345/345 [==============================] - 0s - loss: 0.0695 - mean_absolute_error: 0.0856 - val_loss: 0.0608 - val_mean_absolute_error: 0.0594
# Epoch 19/64
# 345/345 [==============================] - 0s - loss: 0.0688 - mean_absolute_error: 0.0856 - val_loss: 0.0595 - val_mean_absolute_error: 0.0479
# Epoch 20/64
# 345/345 [==============================] - 0s - loss: 0.0682 - mean_absolute_error: 0.0833 - val_loss: 0.0605 - val_mean_absolute_error: 0.0584
# Epoch 21/64
# 345/345 [==============================] - 0s - loss: 0.0674 - mean_absolute_error: 0.0785 - val_loss: 0.0597 - val_mean_absolute_error: 0.0514
# Epoch 22/64
# 345/345 [==============================] - ETA: 0s - loss: 0.0615 - mean_absolute_error: 0.057 - 0s - loss: 0.0668 - mean_absolute_error: 0.0804 - val_loss: 0.0594 - val_mean_absolute_error: 0.0498
# Epoch 23/64
# 345/345 [==============================] - 0s - loss: 0.0656 - mean_absolute_error: 0.0726 - val_loss: 0.0590 - val_mean_absolute_error: 0.0458
# Epoch 24/64
# 345/345 [==============================] - 0s - loss: 0.0654 - mean_absolute_error: 0.0717 - val_loss: 0.0585 - val_mean_absolute_error: 0.0419
# Epoch 25/64
# 345/345 [==============================] - 0s - loss: 0.0641 - mean_absolute_error: 0.0671 - val_loss: 0.0582 - val_mean_absolute_error: 0.0392
# Epoch 26/64
# 345/345 [==============================] - ETA: 0s - loss: 0.0611 - mean_absolute_error: 0.062 - 0s - loss: 0.0642 - mean_absolute_error: 0.0685 - val_loss: 0.0588 - val_mean_absolute_error: 0.0462
# Epoch 27/64
# 345/345 [==============================] - 0s - loss: 0.0636 - mean_absolute_error: 0.0644 - val_loss: 0.0587 - val_mean_absolute_error: 0.0463
# Epoch 28/64
# 345/345 [==============================] - 0s - loss: 0.0624 - mean_absolute_error: 0.0600 - val_loss: 0.0583 - val_mean_absolute_error: 0.0419
# Epoch 29/64
# 345/345 [==============================] - 0s - loss: 0.0623 - mean_absolute_error: 0.0599 - val_loss: 0.0579 - val_mean_absolute_error: 0.0377
# Epoch 30/64
# 345/345 [==============================] - 0s - loss: 0.0620 - mean_absolute_error: 0.0578 - val_loss: 0.0581 - val_mean_absolute_error: 0.0407
# Epoch 31/64
# 345/345 [==============================] - 0s - loss: 0.0619 - mean_absolute_error: 0.0565 - val_loss: 0.0580 - val_mean_absolute_error: 0.0412
# Epoch 32/64
# 345/345 [==============================] - 0s - loss: 0.0628 - mean_absolute_error: 0.0634 - val_loss: 0.0580 - val_mean_absolute_error: 0.0414
# Epoch 33/64
# 345/345 [==============================] - 0s - loss: 0.0624 - mean_absolute_error: 0.0619 - val_loss: 0.0580 - val_mean_absolute_error: 0.0418
# Epoch 34/64
# 345/345 [==============================] - 0s - loss: 0.0616 - mean_absolute_error: 0.0576 - val_loss: 0.0577 - val_mean_absolute_error: 0.0394
# Epoch 35/64
# 345/345 [==============================] - 0s - loss: 0.0607 - mean_absolute_error: 0.0524 - val_loss: 0.0579 - val_mean_absolute_error: 0.0415
# Epoch 36/64
# 345/345 [==============================] - 0s - loss: 0.0615 - mean_absolute_error: 0.0572 - val_loss: 0.0576 - val_mean_absolute_error: 0.0390
# Epoch 37/64
# 345/345 [==============================] - 0s - loss: 0.0609 - mean_absolute_error: 0.0536 - val_loss: 0.0576 - val_mean_absolute_error: 0.0399
# Epoch 38/64
# 345/345 [==============================] - 0s - loss: 0.0617 - mean_absolute_error: 0.0579 - val_loss: 0.0575 - val_mean_absolute_error: 0.0394
# Epoch 39/64
# 345/345 [==============================] - 0s - loss: 0.0607 - mean_absolute_error: 0.0544 - val_loss: 0.0571 - val_mean_absolute_error: 0.0348
# Epoch 40/64
# 345/345 [==============================] - 0s - loss: 0.0603 - mean_absolute_error: 0.0535 - val_loss: 0.0570 - val_mean_absolute_error: 0.0337
# Epoch 41/64
# 345/345 [==============================] - 0s - loss: 0.0600 - mean_absolute_error: 0.0506 - val_loss: 0.0571 - val_mean_absolute_error: 0.0354
# Epoch 42/64
# 345/345 [==============================] - 0s - loss: 0.0607 - mean_absolute_error: 0.0543 - val_loss: 0.0571 - val_mean_absolute_error: 0.0361
# Epoch 43/64
# 345/345 [==============================] - 0s - loss: 0.0602 - mean_absolute_error: 0.0523 - val_loss: 0.0570 - val_mean_absolute_error: 0.0358
# Epoch 44/64
# 345/345 [==============================] - 0s - loss: 0.0595 - mean_absolute_error: 0.0479 - val_loss: 0.0572 - val_mean_absolute_error: 0.0388
# Epoch 45/64
# 345/345 [==============================] - 0s - loss: 0.0604 - mean_absolute_error: 0.0543 - val_loss: 0.0568 - val_mean_absolute_error: 0.0353
# Epoch 46/64
# 345/345 [==============================] - 0s - loss: 0.0603 - mean_absolute_error: 0.0524 - val_loss: 0.0567 - val_mean_absolute_error: 0.0346
# Epoch 47/64
# 345/345 [==============================] - 0s - loss: 0.0592 - mean_absolute_error: 0.0472 - val_loss: 0.0569 - val_mean_absolute_error: 0.0372
# Epoch 48/64
# 345/345 [==============================] - 0s - loss: 0.0595 - mean_absolute_error: 0.0495 - val_loss: 0.0569 - val_mean_absolute_error: 0.0372
# Epoch 49/64
# 345/345 [==============================] - 0s - loss: 0.0594 - mean_absolute_error: 0.0497 - val_loss: 0.0565 - val_mean_absolute_error: 0.0326
# Epoch 50/64
# 345/345 [==============================] - 0s - loss: 0.0590 - mean_absolute_error: 0.0485 - val_loss: 0.0566 - val_mean_absolute_error: 0.0352
# Epoch 51/64
# 345/345 [==============================] - ETA: 0s - loss: 0.0591 - mean_absolute_error: 0.046 - 0s - loss: 0.0592 - mean_absolute_error: 0.0490 - val_loss: 0.0566 - val_mean_absolute_error: 0.0365
# Epoch 52/64
# 345/345 [==============================] - 0s - loss: 0.0586 - mean_absolute_error: 0.0456 - val_loss: 0.0567 - val_mean_absolute_error: 0.0377
# Epoch 53/64
# 345/345 [==============================] - 0s - loss: 0.0592 - mean_absolute_error: 0.0486 - val_loss: 0.0565 - val_mean_absolute_error: 0.0362
# Epoch 54/64
# 345/345 [==============================] - 0s - loss: 0.0595 - mean_absolute_error: 0.0504 - val_loss: 0.0564 - val_mean_absolute_error: 0.0351
# Epoch 55/64
# 345/345 [==============================] - 0s - loss: 0.0594 - mean_absolute_error: 0.0519 - val_loss: 0.0564 - val_mean_absolute_error: 0.0353
# Epoch 56/64
# 345/345 [==============================] - 0s - loss: 0.0587 - mean_absolute_error: 0.0481 - val_loss: 0.0563 - val_mean_absolute_error: 0.0346
# Epoch 57/64
# 345/345 [==============================] - 0s - loss: 0.0588 - mean_absolute_error: 0.0480 - val_loss: 0.0563 - val_mean_absolute_error: 0.0359
# Epoch 58/64
# 345/345 [==============================] - 0s - loss: 0.0580 - mean_absolute_error: 0.0433 - val_loss: 0.0563 - val_mean_absolute_error: 0.0356
# Epoch 59/64
# 345/345 [==============================] - 0s - loss: 0.0587 - mean_absolute_error: 0.0492 - val_loss: 0.0563 - val_mean_absolute_error: 0.0370
# Epoch 60/64
# 345/345 [==============================] - 0s - loss: 0.0583 - mean_absolute_error: 0.0457 - val_loss: 0.0561 - val_mean_absolute_error: 0.0350
# Epoch 61/64
# 345/345 [==============================] - 0s - loss: 0.0578 - mean_absolute_error: 0.0425 - val_loss: 0.0561 - val_mean_absolute_error: 0.0351
# Epoch 62/64
# 345/345 [==============================] - 0s - loss: 0.0580 - mean_absolute_error: 0.0448 - val_loss: 0.0560 - val_mean_absolute_error: 0.0348
# Epoch 63/64
# 345/345 [==============================] - 0s - loss: 0.0587 - mean_absolute_error: 0.0500 - val_loss: 0.0559 - val_mean_absolute_error: 0.0338
# Epoch 64/64
# 345/345 [==============================] - 0s - loss: 0.0583 - mean_absolute_error: 0.0473 - val_loss: 0.0559 - val_mean_absolute_error: 0.0343
# Test MSE Score:5.915 %
# Test MAE Score:5.573 %

# %%
#绘制mae-loss曲线
history.loss_plot('epoch')

# %% [markdown]
# 获取得到需要用于预测的电池数据集B0018号电池

# %%
# 获取预测所需的电池数据集
def getBattery008data(discharge_matrix):
    x_pred=[]
    flag=0

    # 获取得到x_pred的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取0--37这段的长度，叠加+1循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成3*T的时间维度
            x_pred.append(bataery_data_training.T)
        flag+=1

    x_pred=np.array(x_pred)
    return x_pred

# return prediction  data &  prediction  data true_so
discharge_008=r'/home/zsj/yangHong/battery experiment/jsonData/B0008_discharge.json'
# 获取得到一节电池的 特征向量 与true soc 
discharge_matrix_008,true_soc_008 =batterydata2matrix(discharge_008)
# 得到预测样本集 t=7
x_test_008=getBattery008data(discharge_matrix_008)


print("x_test_008 data shape is",x_test_008.shape)
# 预测数据集进行转换
if K.image_dim_ordering() == 'th':
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], img_rows, img_cols,1)
    input_shape = (img_rows, img_cols, 1)
# Out:
# x_test_008 data shape is (125, 4, 8)

# %%
pred=model.predict(x_test_008, batch_size=16, verbose=0)
print(pred.shape)
# Out:
# (125, 1)

# %%
import pandas as pd # 导入pandas库用来处理csv文件
import matplotlib.pyplot as plt # 导入matplotlib.pyplot并用plt简称

# true soc predict plot
x_true_soc=range(len(true_soc_008))
# 切割开始的基数一定为7
start=7
x_test_soc_008=range(start,start+pred.shape[0])
print("x_true_soc range is ",x_true_soc,"\n x_test_soc_008  range is:",x_test_soc_008)
plt.plot(x_true_soc, true_soc_008, linewidth=2.0, color='r',label="True SOC")#线的宽度为2.0，颜色为红色
plt.plot(x_test_soc_008, pred, linewidth=2.0, color='g',label="Prediction SOC")#线的宽度为2.0，颜色为绿色


# 设置x ,y轴的步长与刻度属性
plt.xticks([x for x in range(len(x_true_soc) + 1) if x %10 == 0])  # x标记step设置为10
plt.ylim(ymin=0.3,ymax=1.1)
# remark for x & y
plt.xlabel('Cylce')
plt.ylabel('SOC')
plt.title('Real Soc and Predicted Soc')

plt.legend()
plt.show()#显示图像
# Out:
# x_true_soc range is  range(0, 132)
#  x_test_soc_008  range is: range(7, 132)

# %%
len(x_test_soc_008)
# Out:
# 125
