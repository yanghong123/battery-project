# %% [markdown]
# battery json data  convert to matrix and input to CNN for train,no capacity feature

# %%
from sklearn import preprocessing 
from scipy.io import loadmat, whosmat
import numpy as np
import datetime
import json
import os
# 获取得到 json data of battery 
def json_load(dictonary):
    with open(dictonary) as f:
        data = json.load(f)
    return data

'''
cycle为行数，循环读取一行数据，对一行数据里面的voltage,current and temp求均值，并添加capacity features
得到battery array
'''
def batteryData2array(battery_data):
    vol_sum = 0
    cur_sum = 0
    temp_sum=0
    battery_array = []
    for cycle in battery_data.keys():
        # list type 
        battery_vols = battery_data[cycle]["voltage_battery"]
        battery_curs = battery_data[cycle]["current_battery"]
        battery_temps=battery_data[cycle]["temp_battery"]
        battery_capacity=battery_data[cycle]["Capacity"]
        for battery_vol in battery_vols:
            vol_sum += float(battery_vol)
        for battery_cur in battery_curs:
            cur_sum += float(battery_cur)
        for battery_temp in battery_temps:
            temp_sum += float(battery_temp)
        #for voltage and current average  & battery_vols,battery_curs,battery_temps's len is equal
        num = len(battery_vols)
        vol_aver = vol_sum / num
        cur_aver = cur_sum / num
        temp_aver=temp_sum/num
        vol_sum = 0
        cur_sum = 0
        temp_sum=0
#         battery_array.append([vol_aver,cur_aver,temp_aver,battery_capacity[0]])
        battery_array.append([vol_aver,cur_aver,temp_aver])
    return battery_array

# get battery's true soc
def  getTrueSOC(battery_discharge_data):
    batteryCapcity=2
    soc_dict=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        soc_true=cycleCapacity[0]/batteryCapcity
        soc_dict.append(soc_true)
    return soc_dict

# get battery's discgarge capacity
def  getTrueCapacity(battery_discharge_data):
    capacity=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        capacity.append(cycleCapacity[0])
    return capacity

'''
获取得到 battery 's img matrix 图像矩阵  4维特征向量  vol_aver,cur_aver,temp_aver,battery_capacity
返回battery discharge matrix and true soc array
'''
def batterydata2matrix(discharge):
    #get the discharge and charge json data
    discharge_data =json_load(discharge)
    
    #get the true soc data
    true_soc=getTrueSOC(discharge_data)
#   true_capacity=getTrueCapacity(discharge_data)
    #get the battery discharge array data  convert to matrix
    discharge_array = batteryData2array(discharge_data)
    discharge_matrix = np.array(discharge_array)

    discharge_matrix=preprocessing.scale(discharge_matrix)
    return discharge_matrix,true_soc

'''
获取得到每一节电池数据的训练数据集
得到train & test data
'''
def getTrainData(discharge_matrix,true_soc):     
    #循环切片形成数据集
    x=[];y=[]
    x_train=[];y_train=[]
    flag=0

    # 获取得到x,y的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取长度为8的矩阵，叠加循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成4*T的时间维度
            x.append(bataery_data_training)
        flag+=1
    #0-》t时刻d x 预测得到t时刻的soc。为了对soc 进行预测，y矩阵为【7：】
    y=true_soc[8:]
    x=x[:len(x)-1]
#     y=true_capacity[8:]

    VALIDATION_SPLIT=0.9
    x_validation_samples = int( VALIDATION_SPLIT* len(x))
    y_validation_samples = int( VALIDATION_SPLIT*len(y))
    
    
    # 获取得到训练集，验证集，比例9:1
    x_train=np.array(x[:x_validation_samples])
    x_test=np.array(x[x_validation_samples:])
    y_train=np.array(y[:y_validation_samples])
    y_test=np.array(y[y_validation_samples:])
    print("x_train's shape is:", x_train.shape,"，y_train's shape is:",y_train.shape)
    print("x_test's shape is:",x_test.shape,"，y_test's shape is:",y_test.shape)
    return x_train,x_test,y_train,y_test

# %%
# 定义全局变量，将所有电池数据集集合起来，形成训练集，测试集
# x_train_all,x_test_all,y_train_all,y_test_all=[],[],[],[]
for i in range(5,8):
    #/home/aqts/yangHong/battery experiment/jsonData
    discharge=r'/home/aqts/yangHong/battery experiment/jsonData/B000'+str(i)+'_discharge.json'
    discharge_matrix,true_soc=batterydata2matrix(discharge)
    train_x,test_x,train_y,test_y=getTrainData(discharge_matrix,true_soc)
    # start 开始时先赋值给x_train_all，x_test_all，y_train_all，y_test_all
    if i==5:
        x_train_all=train_x
        x_test_all=test_x
        y_train_all=train_y
        y_test_all=test_y
    else:
        x_train_all=np.concatenate((x_train_all,train_x),axis=0)
        x_test_all=np.concatenate((x_test_all,test_x),axis=0)
        y_train_all=np.concatenate((y_train_all,train_y),axis=0)
        y_test_all=np.concatenate((y_test_all,test_y),axis=0)
print(np.array(x_train_all).shape,np.array(x_test_all).shape,np.array(y_train_all).shape,np.array(y_test_all).shape)
# Out:
# x_train's shape is: (144, 8, 3) ，y_train's shape is: (144,)
# x_test's shape is: (16, 8, 3) ，y_test's shape is: (16,)
# x_train's shape is: (144, 8, 3) ，y_train's shape is: (144,)
# x_test's shape is: (16, 8, 3) ，y_test's shape is: (16,)
# x_train's shape is: (144, 8, 3) ，y_train's shape is: (144,)
# x_test's shape is: (16, 8, 3) ，y_test's shape is: (16,)
# (432, 8, 3) (48, 8, 3) (432,) (48,)

# %%
#写一个LossHistory类，保存loss和mae
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as k
import matplotlib.pyplot as plt
import numpy as np
from keras import backend as K
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = {'batch':[], 'epoch':[]}
        self.accuracy = {'batch':[], 'epoch':[]}
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_acc = {'batch':[], 'epoch':[]}

    def on_batch_end(self, batch, logs={}):
        self.losses['batch'].append(logs.get('loss'))
        self.accuracy['batch'].append(logs.get('mean_absolute_error'))
        self.val_loss['batch'].append(logs.get('val_loss'))
        self.val_acc['batch'].append(logs.get('val_mean_absolute_error'))

    def on_epoch_end(self, batch, logs={}):
        self.losses['epoch'].append(logs.get('loss'))
        self.accuracy['epoch'].append(logs.get('mean_absolute_error'))
        self.val_loss['epoch'].append(logs.get('val_loss'))
        self.val_acc['epoch'].append(logs.get('val_mean_absolute_error'))

    def loss_plot(self, loss_type):
        iters = range(len(self.losses[loss_type]))
        plt.figure()
        # mae
        plt.plot(iters, self.accuracy[loss_type], 'r', label='train mae')
        # loss
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        if loss_type == 'epoch':
            # val_mean_absolute_error
            plt.plot(iters, self.val_acc[loss_type], 'b', label='val mean absolute error')
            # val_loss
            plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('mae-loss')
        plt.legend(loc="upper right")
        plt.show()

# %% [markdown]
# 基于序贯(Sequential)编程方式的模型

# %%
#使用cnn训练的模型
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D,GRU,LSTM,Bidirectional
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras import regularizers
from keras.optimizers import SGD, Adam
from keras.layers.normalization import BatchNormalization
from keras.callbacks import EarlyStopping
# 引用GPU命令
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

img_rows, img_cols =x_train_all.shape[1],x_train_all.shape[2]
num=1

#parameters for LSTM
# cell 里面有四个黄色小框里面，每个小黄框里面的神经元个数
nb_lstm_outputs =16  #神经元个数
nb_time_steps = img_rows  #时间序列长度
nb_input_vector=img_cols


tor = img_cols #输入特征序列
#build model
model = Sequential()
# dropout=0.2, recurrent_dropout=0.1,属性return_sequences用于返回数据用于下一层的lstm单元训练
model.add(GRU(units=nb_lstm_outputs, input_shape=(nb_time_steps, nb_input_vector),dropout=0.20, recurrent_dropout=0.10,return_sequences=True))
# model.add(GRU(64, dropout=0.2, recurrent_dropout=0.1,return_sequences=True))
model.add(GRU(64, dropout=0.20,recurrent_dropout=0.10))
model.add(Dropout(0.20))
# model.add(BatchNormalization())
model.add(Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.20))

model.add(Dense(16, activation='relu'))
model.add(Dropout(0.20))
model.add(Dense(num))


model.summary()

#回归问题评价指标使用mae
model.compile(loss='mse', optimizer="sgd", metrics=["mae"])


batch_size =16
num_epoch =64

#model training
history = LossHistory()

# early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=2)

model.fit(x_train_all, y_train_all,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,validation_split=0.3,shuffle=True,callbacks=[history])

mse_score,mae_score= model.evaluate(x_test_all, y_test_all, verbose=0)
print('Test MSE Score:%.3f %%'% (mse_score*100)) 
print('Test MAE Score:%.3f %%'% (mae_score*100))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_48 (GRU)                 (None, 8, 16)             960
# _________________________________________________________________
# gru_49 (GRU)                 (None, 64)                15552
# _________________________________________________________________
# dropout_59 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_76 (Dense)             (None, 16)                1040
# _________________________________________________________________
# dropout_60 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_77 (Dense)             (None, 16)                272
# _________________________________________________________________
# dropout_61 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_78 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 17,841
# Trainable params: 17,841
# Non-trainable params: 0
# _________________________________________________________________
# Train on 302 samples, validate on 130 samples
# Epoch 1/64
# 302/302 [==============================] - 9s 29ms/step - loss: 0.4572 - mean_absolute_error: 0.6390 - val_loss: 0.2493 - val_mean_absolute_error: 0.4706
# Epoch 2/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.1599 - mean_absolute_error: 0.3437 - val_loss: 0.0974 - val_mean_absolute_error: 0.2655
# Epoch 3/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0788 - mean_absolute_error: 0.1995 - val_loss: 0.0475 - val_mean_absolute_error: 0.1441
# Epoch 4/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0489 - mean_absolute_error: 0.1150 - val_loss: 0.0359 - val_mean_absolute_error: 0.0953
# Epoch 5/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0471 - mean_absolute_error: 0.1077 - val_loss: 0.0314 - val_mean_absolute_error: 0.0679
# Epoch 6/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0460 - mean_absolute_error: 0.1051 - val_loss: 0.0298 - val_mean_absolute_error: 0.0558
# Epoch 7/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0432 - mean_absolute_error: 0.0966 - val_loss: 0.0294 - val_mean_absolute_error: 0.0521
# Epoch 8/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0413 - mean_absolute_error: 0.0913 - val_loss: 0.0285 - val_mean_absolute_error: 0.0431
# Epoch 9/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0431 - mean_absolute_error: 0.0973 - val_loss: 0.0285 - val_mean_absolute_error: 0.0436
# Epoch 10/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0396 - mean_absolute_error: 0.0876 - val_loss: 0.0283 - val_mean_absolute_error: 0.0402
# Epoch 11/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0434 - mean_absolute_error: 0.0997 - val_loss: 0.0279 - val_mean_absolute_error: 0.0364
# Epoch 12/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0426 - mean_absolute_error: 0.0982 - val_loss: 0.0280 - val_mean_absolute_error: 0.0376
# Epoch 13/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0398 - mean_absolute_error: 0.0888 - val_loss: 0.0284 - val_mean_absolute_error: 0.0419
# Epoch 14/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0384 - mean_absolute_error: 0.0853 - val_loss: 0.0281 - val_mean_absolute_error: 0.0391
# Epoch 15/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0396 - mean_absolute_error: 0.0889 - val_loss: 0.0281 - val_mean_absolute_error: 0.0392
# Epoch 16/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0370 - mean_absolute_error: 0.0826 - val_loss: 0.0279 - val_mean_absolute_error: 0.0371
# Epoch 17/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0397 - mean_absolute_error: 0.0893 - val_loss: 0.0276 - val_mean_absolute_error: 0.0332
# Epoch 18/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0382 - mean_absolute_error: 0.0819 - val_loss: 0.0278 - val_mean_absolute_error: 0.0362
# Epoch 19/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0375 - mean_absolute_error: 0.0814 - val_loss: 0.0280 - val_mean_absolute_error: 0.0385
# Epoch 20/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0382 - mean_absolute_error: 0.0852 - val_loss: 0.0276 - val_mean_absolute_error: 0.0343
# Epoch 21/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0364 - mean_absolute_error: 0.0800 - val_loss: 0.0274 - val_mean_absolute_error: 0.0318
# Epoch 22/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0358 - mean_absolute_error: 0.0785 - val_loss: 0.0277 - val_mean_absolute_error: 0.0351
# Epoch 23/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0361 - mean_absolute_error: 0.0761 - val_loss: 0.0277 - val_mean_absolute_error: 0.0354
# Epoch 24/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0357 - mean_absolute_error: 0.0753 - val_loss: 0.0276 - val_mean_absolute_error: 0.0353
# Epoch 25/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0354 - mean_absolute_error: 0.0764 - val_loss: 0.0277 - val_mean_absolute_error: 0.0362
# Epoch 26/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0355 - mean_absolute_error: 0.0732 - val_loss: 0.0273 - val_mean_absolute_error: 0.0316
# Epoch 27/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0353 - mean_absolute_error: 0.0756 - val_loss: 0.0273 - val_mean_absolute_error: 0.0324
# Epoch 28/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0339 - mean_absolute_error: 0.0686 - val_loss: 0.0277 - val_mean_absolute_error: 0.0366
# Epoch 29/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0341 - mean_absolute_error: 0.0706 - val_loss: 0.0274 - val_mean_absolute_error: 0.0340
# Epoch 30/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0366 - mean_absolute_error: 0.0809 - val_loss: 0.0273 - val_mean_absolute_error: 0.0318
# Epoch 31/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0337 - mean_absolute_error: 0.0690 - val_loss: 0.0272 - val_mean_absolute_error: 0.0317
# Epoch 32/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0350 - mean_absolute_error: 0.0720 - val_loss: 0.0271 - val_mean_absolute_error: 0.0301
# Epoch 33/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0351 - mean_absolute_error: 0.0742 - val_loss: 0.0272 - val_mean_absolute_error: 0.0323
# Epoch 34/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0343 - mean_absolute_error: 0.0704 - val_loss: 0.0272 - val_mean_absolute_error: 0.0318
# Epoch 35/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0340 - mean_absolute_error: 0.0702 - val_loss: 0.0270 - val_mean_absolute_error: 0.0292
# Epoch 36/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0336 - mean_absolute_error: 0.0682 - val_loss: 0.0270 - val_mean_absolute_error: 0.0295
# Epoch 37/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0328 - mean_absolute_error: 0.0639 - val_loss: 0.0269 - val_mean_absolute_error: 0.0284
# Epoch 38/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0341 - mean_absolute_error: 0.0719 - val_loss: 0.0268 - val_mean_absolute_error: 0.0274
# Epoch 39/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0322 - mean_absolute_error: 0.0637 - val_loss: 0.0271 - val_mean_absolute_error: 0.0320
# Epoch 40/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0330 - mean_absolute_error: 0.0651 - val_loss: 0.0269 - val_mean_absolute_error: 0.0305
# Epoch 41/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0356 - mean_absolute_error: 0.0759 - val_loss: 0.0266 - val_mean_absolute_error: 0.0256
# Epoch 42/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0340 - mean_absolute_error: 0.0702 - val_loss: 0.0266 - val_mean_absolute_error: 0.0254
# Epoch 43/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0328 - mean_absolute_error: 0.0653 - val_loss: 0.0268 - val_mean_absolute_error: 0.0297
# Epoch 44/64
# 302/302 [==============================] - 1s 3ms/step - loss: 0.0327 - mean_absolute_error: 0.0659 - val_loss: 0.0268 - val_mean_absolute_error: 0.0296
# Epoch 45/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0332 - mean_absolute_error: 0.0672 - val_loss: 0.0270 - val_mean_absolute_error: 0.0339
# Epoch 46/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0334 - mean_absolute_error: 0.0698 - val_loss: 0.0268 - val_mean_absolute_error: 0.0312
# Epoch 47/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0336 - mean_absolute_error: 0.0692 - val_loss: 0.0268 - val_mean_absolute_error: 0.0304
# Epoch 48/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0322 - mean_absolute_error: 0.0636 - val_loss: 0.0268 - val_mean_absolute_error: 0.0318
# Epoch 49/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0333 - mean_absolute_error: 0.0656 - val_loss: 0.0266 - val_mean_absolute_error: 0.0280
# Epoch 50/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0328 - mean_absolute_error: 0.0689 - val_loss: 0.0264 - val_mean_absolute_error: 0.0261
# Epoch 51/64
# 302/302 [==============================] - 1s 3ms/step - loss: 0.0330 - mean_absolute_error: 0.0669 - val_loss: 0.0265 - val_mean_absolute_error: 0.0275
# Epoch 52/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0312 - mean_absolute_error: 0.0573 - val_loss: 0.0265 - val_mean_absolute_error: 0.0281
# Epoch 53/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0332 - mean_absolute_error: 0.0669 - val_loss: 0.0263 - val_mean_absolute_error: 0.0257
# Epoch 54/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0315 - mean_absolute_error: 0.0617 - val_loss: 0.0266 - val_mean_absolute_error: 0.0302
# Epoch 55/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0328 - mean_absolute_error: 0.0650 - val_loss: 0.0265 - val_mean_absolute_error: 0.0293
# Epoch 56/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0316 - mean_absolute_error: 0.0618 - val_loss: 0.0264 - val_mean_absolute_error: 0.0290
# Epoch 57/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0309 - mean_absolute_error: 0.0572 - val_loss: 0.0266 - val_mean_absolute_error: 0.0321
# Epoch 58/64
# 302/302 [==============================] - 1s 3ms/step - loss: 0.0312 - mean_absolute_error: 0.0573 - val_loss: 0.0265 - val_mean_absolute_error: 0.0316
# Epoch 59/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0320 - mean_absolute_error: 0.0631 - val_loss: 0.0264 - val_mean_absolute_error: 0.0297
# Epoch 60/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0315 - mean_absolute_error: 0.0631 - val_loss: 0.0265 - val_mean_absolute_error: 0.0309
# Epoch 61/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0318 - mean_absolute_error: 0.0625 - val_loss: 0.0264 - val_mean_absolute_error: 0.0297
# Epoch 62/64
# 302/302 [==============================] - 1s 3ms/step - loss: 0.0320 - mean_absolute_error: 0.0626 - val_loss: 0.0264 - val_mean_absolute_error: 0.0312
# Epoch 63/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0322 - mean_absolute_error: 0.0647 - val_loss: 0.0263 - val_mean_absolute_error: 0.0298
# Epoch 64/64
# 302/302 [==============================] - 1s 2ms/step - loss: 0.0316 - mean_absolute_error: 0.0613 - val_loss: 0.0263 - val_mean_absolute_error: 0.0302
# Test MSE Score:3.082 %
# Test MAE Score:6.056 %

# %%
#绘制mae-loss曲线
history.loss_plot('epoch')
# input_shape[]

# %% [markdown]
# 获取得到需要用于预测的电池数据集B0018号电池

# %%
# 获取预测所需的电池数据集
def getBattery008data(discharge_matrix):
    x_pred=[]
    flag=0

    # 获取得到x_pred的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取0--37这段的长度，叠加+1循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成3*T的时间维度
            x_pred.append(bataery_data_training)
        flag+=1

    x_pred=np.array(x_pred[:len(x_pred)-1])
    return x_pred

# return prediction  data &  prediction  data true_so
discharge_008=r'/home/aqts/yangHong/battery experiment/jsonData/B0008_discharge.json'
# 获取得到一节电池的 特征向量 与true soc 
discharge_matrix_008,true_soc_008 =batterydata2matrix(discharge_008)
# 得到预测样本集 t=7
x_test_008=getBattery008data(discharge_matrix_008)


print("x_test_008 data shape is",x_test_008.shape)
# Out:
# x_test_008 data shape is (124, 8, 3)

# %%
pred=model.predict(x_test_008, batch_size=16, verbose=0)
print(pred.shape)
# Out:
# (124, 1)

# %%
import pandas as pd # 导入pandas库用来处理csv文件
import matplotlib.pyplot as plt # 导入matplotlib.pyplot并用plt简称

# true soc predict plot
x_true_soc=range(len(true_soc_008))
# 切割开始的基数一定为7
start=8
x_test_soc_008=range(start,start+pred.shape[0])
print("x_true_soc range is ",x_true_soc,"\n x_test_soc_008  range is:",x_test_soc_008)
plt.plot(x_true_soc, true_soc_008, linewidth=2.0, color='r',label="True SOC")#线的宽度为2.0，颜色为红色
plt.plot(x_test_soc_008, pred, linewidth=2.0, color='g',label="Prediction SOC")#线的宽度为2.0，颜色为绿色


# 设置x ,y轴的步长与刻度属性
plt.xticks([x for x in range(len(x_true_soc) + 1) if x %10 == 0])  # x标记step设置为10
plt.ylim(ymin=0.3,ymax=1.1)
# remark for x & y
plt.xlabel('Cylce')
plt.ylabel('SOC')
plt.title('Real Soc and Predicted Soc')

plt.legend()
plt.show()#显示图像
# Out:
# x_true_soc range is  range(0, 132)
#  x_test_soc_008  range is: range(8, 132)

# %%
input_shape
# Out:
# (3, 8)
