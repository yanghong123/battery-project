# %% [markdown]
# battery json data  convert to matrix and input to CNN for train，没有容量特征字段

# %%
from sklearn import preprocessing 
from scipy.io import loadmat, whosmat
import numpy as np
import datetime
import json
import os
# 获取得到 json data of battery 
def json_load(dictonary):
    with open(dictonary) as f:
        data = json.load(f)
    return data

'''
cycle为行数，循环读取一行数据，对一行数据里面的voltage,current and temp求均值，并添加capacity features
得到battery array
'''
def batteryData2array(battery_data):
    vol_sum = 0
    cur_sum = 0
    temp_sum=0
    battery_array = []
    for cycle in battery_data.keys():
        # list type 
        battery_vols = battery_data[cycle]["voltage_battery"]
        battery_curs = battery_data[cycle]["current_battery"]
        battery_temps=battery_data[cycle]["temp_battery"]
        battery_capacity=battery_data[cycle]["Capacity"]
        for battery_vol in battery_vols:
            vol_sum += float(battery_vol)
        for battery_cur in battery_curs:
            cur_sum += float(battery_cur)
        for battery_temp in battery_temps:
            temp_sum += float(battery_temp)
        #for voltage and current average  & battery_vols,battery_curs,battery_temps's len is equal
        num = len(battery_vols)
        vol_aver = vol_sum / num
        cur_aver = cur_sum / num
        temp_aver=temp_sum/num
        vol_sum = 0
        cur_sum = 0
        temp_sum=0
        battery_array.append([vol_aver,cur_aver,temp_aver])
#         battery_array.append([vol_aver,cur_aver,battery_capacity[0]])
    return battery_array

# get battery's true soc
def  getTrueSOC(battery_discharge_data):
    batteryCapcity=2
    soc_dict=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        soc_true=cycleCapacity[0]/batteryCapcity
        soc_dict.append(soc_true)
    return soc_dict

# get battery's discgarge capacity
def  getTrueCapacity(battery_discharge_data):
    capacity=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        capacity.append(cycleCapacity[0])
    return capacity

'''
获取得到 battery 's img matrix 图像矩阵  4维特征向量  vol_aver,cur_aver,temp_aver,battery_capacity
返回battery discharge matrix and true soc array
'''
def batterydata2matrix(discharge):
    #get the discharge and charge json data
    discharge_data =json_load(discharge)
    
    #get the true soc data
    true_soc=getTrueSOC(discharge_data)
#   true_capacity=getTrueCapacity(discharge_data)
    #get the battery discharge array data  convert to matrix
    discharge_array = batteryData2array(discharge_data)
    discharge_matrix = np.array(discharge_array)

    discharge_matrix=preprocessing.scale(discharge_matrix)
    return discharge_matrix,true_soc

'''
获取得到每一节电池数据的训练数据集
得到train & test data
'''
def getTrainData(discharge_matrix,true_soc):     
    #循环切片形成数据集
    x=[];y=[]
    x_train=[];y_train=[]
    flag=0

    # 获取得到x,y的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取长度为8的矩阵，叠加循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成4*T的时间维度
            x.append(bataery_data_training.T)
        flag+=1
    #0-》t时刻d x 预测得到t时刻的soc。为了对soc 进行预测，y矩阵为【7：】
    y=true_soc[8:]
    x=x[:len(x)-1]
#     y=true_capacity[8:]

    VALIDATION_SPLIT=0.9
    x_validation_samples = int( VALIDATION_SPLIT* len(x))
    y_validation_samples = int( VALIDATION_SPLIT*len(y))
    
    
    # 获取得到训练集，验证集，比例9:1
    x_train=np.array(x[:x_validation_samples])
    x_test=np.array(x[x_validation_samples:])
    y_train=np.array(y[:y_validation_samples])
    y_test=np.array(y[y_validation_samples:])
    print("x_train's shape is:", x_train.shape,"，y_train's shape is:",y_train.shape)
    print("x_test's shape is:",x_test.shape,"，y_test's shape is:",y_test.shape)
    return x_train,x_test,y_train,y_test

# %%
# 定义全局变量，将所有电池数据集集合起来，形成训练集，测试集
# x_train_all,x_test_all,y_train_all,y_test_all=[],[],[],[]
for i in range(5,8):
    #/home/aqts/yangHong/battery experiment/jsonData
    discharge=r'/home/aqts/yangHong/battery experiment/jsonData/B000'+str(i)+'_discharge.json'
    discharge_matrix,true_soc=batterydata2matrix(discharge)
    train_x,test_x,train_y,test_y=getTrainData(discharge_matrix,true_soc)
    # start 开始时先赋值给x_train_all，x_test_all，y_train_all，y_test_all
    if i==5:
        x_train_all=train_x
        x_test_all=test_x
        y_train_all=train_y
        y_test_all=test_y
    else:
        x_train_all=np.concatenate((x_train_all,train_x),axis=0)
        x_test_all=np.concatenate((x_test_all,test_x),axis=0)
        y_train_all=np.concatenate((y_train_all,train_y),axis=0)
        y_test_all=np.concatenate((y_test_all,test_y),axis=0)
print(np.array(x_train_all).shape,np.array(x_test_all).shape,np.array(y_train_all).shape,np.array(y_test_all).shape)
# Out:
# x_train's shape is: (144, 3, 8) ，y_train's shape is: (144,)
# x_test's shape is: (16, 3, 8) ，y_test's shape is: (16,)
# x_train's shape is: (144, 3, 8) ，y_train's shape is: (144,)
# x_test's shape is: (16, 3, 8) ，y_test's shape is: (16,)
# x_train's shape is: (144, 3, 8) ，y_train's shape is: (144,)
# x_test's shape is: (16, 3, 8) ，y_test's shape is: (16,)
# (432, 3, 8) (48, 3, 8) (432,) (48,)

# %%
#写一个LossHistory类，保存loss和mae
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as k
import matplotlib.pyplot as plt
import numpy as np
from keras import backend as K
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = {'batch':[], 'epoch':[]}
        self.accuracy = {'batch':[], 'epoch':[]}
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_acc = {'batch':[], 'epoch':[]}

    def on_batch_end(self, batch, logs={}):
        self.losses['batch'].append(logs.get('loss'))
        self.accuracy['batch'].append(logs.get('mean_absolute_error'))
        self.val_loss['batch'].append(logs.get('val_loss'))
        self.val_acc['batch'].append(logs.get('val_mean_absolute_error'))

    def on_epoch_end(self, batch, logs={}):
        self.losses['epoch'].append(logs.get('loss'))
        self.accuracy['epoch'].append(logs.get('mean_absolute_error'))
        self.val_loss['epoch'].append(logs.get('val_loss'))
        self.val_acc['epoch'].append(logs.get('val_mean_absolute_error'))

    def loss_plot(self, loss_type):
        iters = range(len(self.losses[loss_type]))
        plt.figure()
        # mae
        plt.plot(iters, self.accuracy[loss_type], 'r', label='train mae')
        # loss
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        if loss_type == 'epoch':
            # val_mean_absolute_error
            plt.plot(iters, self.val_acc[loss_type], 'b', label='val mean absolute error')
            # val_loss
            plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('mae-loss')
        plt.legend(loc="upper right")
        plt.show()

# %% [markdown]
# 基于序贯(Sequential)编程方式的模型

# %%
#使用cnn训练的模型
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D,GRU,LSTM
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras import regularizers
from keras.optimizers import SGD, Adam
from keras.layers.normalization import BatchNormalization
import tensorflow as tf
from keras.layers.noise import GaussianNoise
# 引用GPU命令
import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

num=1
img_rows, img_cols =x_train_all.shape[1],x_train_all.shape[2]
if K.image_dim_ordering() == 'th':
    x_train_all = x_train_all.reshape(x_train_all.shape[0], 1, img_rows, img_cols)
    x_test_all = x_test_all.reshape(x_test_all.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train_all = x_train_all.reshape(x_train_all.shape[0], img_rows, img_cols, 1)
    x_test_all= x_test_all.reshape(x_test_all.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)
    
# lstm_layer=(None, input_shape[0], input_shape[1], input_shape[2])
# print(x_train.shape,x_test.shape)
# print(y_train.shape)
# keras序贯模型搭建CNN
# model building
model = Sequential()
#convolutional layer with rectified linear unit activation
model.add(Conv2D(64, kernel_size=(1,2),
                 activation='relu',
                 input_shape=input_shape,padding="same"))
#32 convolution filters used each of size 3x3
#again
model.add(Conv2D(128, (2,2), activation='relu',padding="same"))
#64 convolution filters used each of size 3x3
#choose the best features via pooling
model.add(MaxPooling2D(pool_size=(1, 2)))

model.add(Conv2D(32, (2,1), activation='relu',padding="same"))

model.add(Conv2D(64, (2,2), activation='relu',padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
#randomly turn neurons on and off to improve convergence
# model.add(Dropout(0.30))
#flatten since too many dimensions, we only want a classification output
model.add(Flatten())
#fully connected to get all relevant data
model.add(Dropout(0.20))
model.add(Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.20))

model.add(Dense(16, activation='relu'))
model.add(Dropout(0.20))
# model.add(Dense(num, activation='sigmoid'))
# The last layer does not use the activation function
model.add(Dense(num))

#Adaptive learning rate (adaDelta) is a popular form of gradient descent rivaled only by adam and adagrad
#categorical ce since we have multiple classes (10) 
# model.compile(loss=keras.losses.sparse_categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])
#回归问题评价指标使用mae
model.compile(loss='mse', optimizer="sgd", metrics=["mae"])

model.summary()
batch_size =16
num_epoch = 128



# decay_rate = learning_rate / num_epoch
# momentum = 0.8
# sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)

# model.compile(loss='mse', optimizer=sgd, metrics=["mae"])
#model training
history = LossHistory()
model.fit(x_train_all, y_train_all,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,validation_split=0.3,callbacks=[history])

mse_score,mae_score= model.evaluate(x_test_all, y_test_all, verbose=0)
print('Test MSE Score:%.3f %%'% (mse_score*100)) 
print('Test MAE Score:%.3f %%'% (mae_score*100))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_145 (Conv2D)          (None, 3, 8, 64)          192
# _________________________________________________________________
# conv2d_146 (Conv2D)          (None, 3, 8, 128)         32896
# _________________________________________________________________
# max_pooling2d_58 (MaxPooling (None, 3, 4, 128)         0
# _________________________________________________________________
# conv2d_147 (Conv2D)          (None, 3, 4, 32)          8224
# _________________________________________________________________
# conv2d_148 (Conv2D)          (None, 3, 4, 64)          8256
# _________________________________________________________________
# max_pooling2d_59 (MaxPooling (None, 1, 2, 64)          0
# _________________________________________________________________
# flatten_34 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dropout_98 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_100 (Dense)            (None, 16)                2064
# _________________________________________________________________
# dropout_99 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_101 (Dense)            (None, 16)                272
# _________________________________________________________________
# dropout_100 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_102 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 51,921
# Trainable params: 51,921
# Non-trainable params: 0
# _________________________________________________________________
# Train on 302 samples, validate on 130 samples
# Epoch 1/128
# 302/302 [==============================] - 3s 9ms/step - loss: 0.2143 - mean_absolute_error: 0.3603 - val_loss: 0.0453 - val_mean_absolute_error: 0.1020
# Epoch 2/128
# 302/302 [==============================] - 0s 477us/step - loss: 0.0958 - mean_absolute_error: 0.2058 - val_loss: 0.0419 - val_mean_absolute_error: 0.0913
# Epoch 3/128
# 302/302 [==============================] - 0s 532us/step - loss: 0.0856 - mean_absolute_error: 0.1918 - val_loss: 0.0379 - val_mean_absolute_error: 0.0757
# Epoch 4/128
# 302/302 [==============================] - 0s 525us/step - loss: 0.0739 - mean_absolute_error: 0.1686 - val_loss: 0.0383 - val_mean_absolute_error: 0.0833
# Epoch 5/128
# 302/302 [==============================] - 0s 521us/step - loss: 0.0636 - mean_absolute_error: 0.1537 - val_loss: 0.0347 - val_mean_absolute_error: 0.0651
# Epoch 6/128
# 302/302 [==============================] - 0s 546us/step - loss: 0.0649 - mean_absolute_error: 0.1530 - val_loss: 0.0348 - val_mean_absolute_error: 0.0686
# Epoch 7/128
# 302/302 [==============================] - 0s 532us/step - loss: 0.0563 - mean_absolute_error: 0.1318 - val_loss: 0.0347 - val_mean_absolute_error: 0.0703
# Epoch 8/128
# 302/302 [==============================] - 0s 538us/step - loss: 0.0552 - mean_absolute_error: 0.1272 - val_loss: 0.0330 - val_mean_absolute_error: 0.0589
# Epoch 9/128
# 302/302 [==============================] - 0s 552us/step - loss: 0.0493 - mean_absolute_error: 0.1131 - val_loss: 0.0320 - val_mean_absolute_error: 0.0522
# Epoch 10/128
# 302/302 [==============================] - 0s 529us/step - loss: 0.0472 - mean_absolute_error: 0.1079 - val_loss: 0.0317 - val_mean_absolute_error: 0.0501
# Epoch 11/128
# 302/302 [==============================] - 0s 509us/step - loss: 0.0453 - mean_absolute_error: 0.1034 - val_loss: 0.0321 - val_mean_absolute_error: 0.0542
# Epoch 12/128
# 302/302 [==============================] - 0s 593us/step - loss: 0.0459 - mean_absolute_error: 0.1005 - val_loss: 0.0325 - val_mean_absolute_error: 0.0577
# Epoch 13/128
# 302/302 [==============================] - 0s 551us/step - loss: 0.0425 - mean_absolute_error: 0.0924 - val_loss: 0.0315 - val_mean_absolute_error: 0.0498
# Epoch 14/128
# 302/302 [==============================] - 0s 496us/step - loss: 0.0415 - mean_absolute_error: 0.0919 - val_loss: 0.0306 - val_mean_absolute_error: 0.0413
# Epoch 15/128
# 302/302 [==============================] - 0s 570us/step - loss: 0.0398 - mean_absolute_error: 0.0847 - val_loss: 0.0311 - val_mean_absolute_error: 0.0467
# Epoch 16/128
# 302/302 [==============================] - 0s 539us/step - loss: 0.0407 - mean_absolute_error: 0.0857 - val_loss: 0.0311 - val_mean_absolute_error: 0.0464
# Epoch 17/128
# 302/302 [==============================] - 0s 525us/step - loss: 0.0412 - mean_absolute_error: 0.0878 - val_loss: 0.0308 - val_mean_absolute_error: 0.0439
# Epoch 18/128
# 302/302 [==============================] - 0s 541us/step - loss: 0.0408 - mean_absolute_error: 0.0876 - val_loss: 0.0311 - val_mean_absolute_error: 0.0465
# Epoch 19/128
# 302/302 [==============================] - 0s 551us/step - loss: 0.0413 - mean_absolute_error: 0.0883 - val_loss: 0.0304 - val_mean_absolute_error: 0.0397
# Epoch 20/128
# 302/302 [==============================] - 0s 521us/step - loss: 0.0387 - mean_absolute_error: 0.0807 - val_loss: 0.0313 - val_mean_absolute_error: 0.0491
# Epoch 21/128
# 302/302 [==============================] - 0s 559us/step - loss: 0.0383 - mean_absolute_error: 0.0800 - val_loss: 0.0306 - val_mean_absolute_error: 0.0419
# Epoch 22/128
# 302/302 [==============================] - 0s 537us/step - loss: 0.0390 - mean_absolute_error: 0.0790 - val_loss: 0.0301 - val_mean_absolute_error: 0.0365
# Epoch 23/128
# 302/302 [==============================] - 0s 547us/step - loss: 0.0356 - mean_absolute_error: 0.0692 - val_loss: 0.0302 - val_mean_absolute_error: 0.0378
# Epoch 24/128
# 302/302 [==============================] - 0s 519us/step - loss: 0.0377 - mean_absolute_error: 0.0768 - val_loss: 0.0305 - val_mean_absolute_error: 0.0424
# Epoch 25/128
# 302/302 [==============================] - 0s 540us/step - loss: 0.0394 - mean_absolute_error: 0.0840 - val_loss: 0.0305 - val_mean_absolute_error: 0.0423
# Epoch 26/128
# 302/302 [==============================] - 0s 518us/step - loss: 0.0375 - mean_absolute_error: 0.0747 - val_loss: 0.0300 - val_mean_absolute_error: 0.0372
# Epoch 27/128
# 302/302 [==============================] - 0s 486us/step - loss: 0.0381 - mean_absolute_error: 0.0806 - val_loss: 0.0299 - val_mean_absolute_error: 0.0361
# Epoch 28/128
# 302/302 [==============================] - 0s 522us/step - loss: 0.0383 - mean_absolute_error: 0.0787 - val_loss: 0.0302 - val_mean_absolute_error: 0.0397
# Epoch 29/128
# 302/302 [==============================] - 0s 492us/step - loss: 0.0366 - mean_absolute_error: 0.0735 - val_loss: 0.0298 - val_mean_absolute_error: 0.0350
# Epoch 30/128
# 302/302 [==============================] - 0s 546us/step - loss: 0.0378 - mean_absolute_error: 0.0765 - val_loss: 0.0303 - val_mean_absolute_error: 0.0420
# Epoch 31/128
# 302/302 [==============================] - 0s 502us/step - loss: 0.0377 - mean_absolute_error: 0.0770 - val_loss: 0.0301 - val_mean_absolute_error: 0.0399
# Epoch 32/128
# 302/302 [==============================] - 0s 536us/step - loss: 0.0373 - mean_absolute_error: 0.0750 - val_loss: 0.0295 - val_mean_absolute_error: 0.0330
# Epoch 33/128
# 302/302 [==============================] - 0s 529us/step - loss: 0.0373 - mean_absolute_error: 0.0737 - val_loss: 0.0292 - val_mean_absolute_error: 0.0298
# Epoch 34/128
# 302/302 [==============================] - 0s 505us/step - loss: 0.0295 - mean_absolute_error: 0.0451 - val_loss: 0.0278 - val_mean_absolute_error: 0.0360
# Epoch 126/128
# 302/302 [==============================] - 0s 533us/step - loss: 0.0297 - mean_absolute_error: 0.0467 - val_loss: 0.0281 - val_mean_absolute_error: 0.0411
# Epoch 127/128
# 302/302 [==============================] - 0s 524us/step - loss: 0.0292 - mean_absolute_error: 0.0443 - val_loss: 0.0280 - val_mean_absolute_error: 0.0396
# Epoch 128/128
# 302/302 [==============================] - 0s 548us/step - loss: 0.0292 - mean_absolute_error: 0.0445 - val_loss: 0.0283 - val_mean_absolute_error: 0.0444
# Test MSE Score:2.822 %
# Test MAE Score:3.720 %

# %% [markdown]
# 将CNN模型使用函数式编程的模式

# %%
# keras 函数时搭建cnn模型
# model building
from keras.models import Input,Model
cnn_main_input = Input(shape=input_shape, dtype='float32')
#convolutional layer with rectified linear unit activation
cnn=Conv2D(64, kernel_size=(1,2),
                 activation='relu',
                 input_shape=input_shape,padding="same")(cnn_main_input)
cnn=Conv2D(128, (2,2), activation='relu',padding="same")(cnn)
cnn=MaxPooling2D(pool_size=(1, 2))(cnn)
# cnn=Dropout(0.20)(cnn)

cnn=Conv2D(32, (2,1), activation='relu',padding="same")(cnn)

cnn=Conv2D(64, (3,2), activation='relu',padding="same")(cnn)
cnn=MaxPooling2D(pool_size=(2,2))(cnn)

cnn=Flatten()(cnn)
# cnn=Dropout(0.20)(cnn)
cnn=Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001))(cnn)
cnn=Dropout(0.20)(cnn)

cnn=Dense(16, activation='relu')(cnn)
cnn=Dropout(0.20)(cnn)

# rnn=LSTM(units=nb_lstm_outputs,dropout=0.4, recurrent_dropout=0.1,return_sequences=True)(lstm_main_input)
# rnn=LSTM(64, dropout=0.4, recurrent_dropout=0.1)(rnn)

# # two model connection
# con = concatenate([cnn,rnn], axis=-1)
main_output = Dense(num)(cnn)
model = Model(inputs = cnn_main_input, outputs = main_output)
sgd = SGD(lr=0.005, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mse', optimizer="sgd", metrics=["mae"])


batch_size =16
num_epoch = 128


model.summary()
# decay_rate = learning_rate / num_epoch
# momentum = 0.8
# sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)

# model.compile(loss='mse', optimizer=sgd, metrics=["mae"])
#model training
history = LossHistory()
model.fit(x_train_all, y_train_all,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,validation_split=0.3,callbacks=[history])

mse_score,mae_score= model.evaluate(x_test_all, y_test_all, verbose=0)
print('Test MSE Score:%.3f %%'% (mse_score*100)) 
print('Test MAE Score:%.3f %%'% (mae_score*100))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_28 (InputLayer)        (None, 3, 8, 1)           0
# _________________________________________________________________
# conv2d_149 (Conv2D)          (None, 3, 8, 64)          192
# _________________________________________________________________
# conv2d_150 (Conv2D)          (None, 3, 8, 128)         32896
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 3, 4, 128)         0
# _________________________________________________________________
# conv2d_151 (Conv2D)          (None, 3, 4, 32)          8224
# _________________________________________________________________
# conv2d_152 (Conv2D)          (None, 3, 4, 64)          12352
# _________________________________________________________________
# max_pooling2d_61 (MaxPooling (None, 1, 2, 64)          0
# _________________________________________________________________
# flatten_35 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_103 (Dense)            (None, 16)                2064
# _________________________________________________________________
# dropout_101 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_104 (Dense)            (None, 16)                272
# _________________________________________________________________
# dropout_102 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_105 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 56,017
# Trainable params: 56,017
# Non-trainable params: 0
# _________________________________________________________________
# Train on 302 samples, validate on 130 samples
# Epoch 1/128
# 302/302 [==============================] - 3s 9ms/step - loss: 0.2947 - mean_absolute_error: 0.4718 - val_loss: 0.0862 - val_mean_absolute_error: 0.2360
# Epoch 2/128
# 302/302 [==============================] - 0s 479us/step - loss: 0.0682 - mean_absolute_error: 0.1623 - val_loss: 0.0388 - val_mean_absolute_error: 0.0910
# Epoch 3/128
# 302/302 [==============================] - 0s 530us/step - loss: 0.0608 - mean_absolute_error: 0.1439 - val_loss: 0.0339 - val_mean_absolute_error: 0.0613
# Epoch 4/128
# 302/302 [==============================] - 0s 528us/step - loss: 0.0561 - mean_absolute_error: 0.1328 - val_loss: 0.0344 - val_mean_absolute_error: 0.0666
# Epoch 5/128
# 302/302 [==============================] - 0s 500us/step - loss: 0.0528 - mean_absolute_error: 0.1261 - val_loss: 0.0323 - val_mean_absolute_error: 0.0535
# Epoch 6/128
# 302/302 [==============================] - 0s 539us/step - loss: 0.0522 - mean_absolute_error: 0.1282 - val_loss: 0.0322 - val_mean_absolute_error: 0.0541
# Epoch 7/128
# 302/302 [==============================] - 0s 554us/step - loss: 0.0523 - mean_absolute_error: 0.1224 - val_loss: 0.0318 - val_mean_absolute_error: 0.0526
# Epoch 8/128
# 302/302 [==============================] - 0s 504us/step - loss: 0.0492 - mean_absolute_error: 0.1136 - val_loss: 0.0321 - val_mean_absolute_error: 0.0554
# Epoch 9/128
# 302/302 [==============================] - 0s 531us/step - loss: 0.0470 - mean_absolute_error: 0.1072 - val_loss: 0.0323 - val_mean_absolute_error: 0.0579
# Epoch 10/128
# 302/302 [==============================] - 0s 552us/step - loss: 0.0459 - mean_absolute_error: 0.1067 - val_loss: 0.0315 - val_mean_absolute_error: 0.0529
# Epoch 11/128
# 302/302 [==============================] - 0s 502us/step - loss: 0.0454 - mean_absolute_error: 0.1080 - val_loss: 0.0315 - val_mean_absolute_error: 0.0529
# Epoch 12/128
# 302/302 [==============================] - 0s 520us/step - loss: 0.0444 - mean_absolute_error: 0.1001 - val_loss: 0.0301 - val_mean_absolute_error: 0.0414
# Epoch 13/128
# 302/302 [==============================] - 0s 518us/step - loss: 0.0408 - mean_absolute_error: 0.0894 - val_loss: 0.0303 - val_mean_absolute_error: 0.0435
# Epoch 14/128
# 302/302 [==============================] - 0s 502us/step - loss: 0.0427 - mean_absolute_error: 0.0967 - val_loss: 0.0302 - val_mean_absolute_error: 0.0436
# Epoch 15/128
# 302/302 [==============================] - 0s 495us/step - loss: 0.0385 - mean_absolute_error: 0.0817 - val_loss: 0.0300 - val_mean_absolute_error: 0.0417
# Epoch 16/128
# 302/302 [==============================] - 0s 560us/step - loss: 0.0405 - mean_absolute_error: 0.0891 - val_loss: 0.0308 - val_mean_absolute_error: 0.0502
# Epoch 17/128
# 302/302 [==============================] - 0s 506us/step - loss: 0.0322 - mean_absolute_error: 0.0552 - val_loss: 0.0281 - val_mean_absolute_error: 0.0311
# Epoch 54/128
# 302/302 [==============================] - 0s 548us/step - loss: 0.0316 - mean_absolute_error: 0.0544 - val_loss: 0.0284 - val_mean_absolute_error: 0.0348
# Epoch 55/128
# 302/302 [==============================] - 0s 510us/step - loss: 0.0316 - mean_absolute_error: 0.0534 - val_loss: 0.0279 - val_mean_absolute_error: 0.0294
# Epoch 56/128
# 302/302 [==============================] - 0s 534us/step - loss: 0.0316 - mean_absolute_error: 0.0523 - val_loss: 0.0279 - val_mean_absolute_error: 0.0289
# Epoch 57/128
# 302/302 [==============================] - 0s 526us/step - loss: 0.0302 - mean_absolute_error: 0.0466 - val_loss: 0.0282 - val_mean_absolute_error: 0.0330
# Epoch 58/128
# 302/302 [==============================] - 0s 521us/step - loss: 0.0318 - mean_absolute_error: 0.0546 - val_loss: 0.0282 - val_mean_absolute_error: 0.0339
# Epoch 59/128
# 302/302 [==============================] - 0s 516us/step - loss: 0.0316 - mean_absolute_error: 0.0547 - val_loss: 0.0281 - val_mean_absolute_error: 0.0329
# Epoch 60/128
# 302/302 [==============================] - 0s 526us/step - loss: 0.0314 - mean_absolute_error: 0.0526 - val_loss: 0.0281 - val_mean_absolute_error: 0.0325
# Epoch 61/128
# 302/302 [==============================] - 0s 522us/step - loss: 0.0306 - mean_absolute_error: 0.0476 - val_loss: 0.0280 - val_mean_absolute_error: 0.0314
# Epoch 62/128
# 302/302 [==============================] - 0s 513us/step - loss: 0.0309 - mean_absolute_error: 0.0503 - val_loss: 0.0278 - val_mean_absolute_error: 0.0297
# Epoch 63/128
# 302/302 [==============================] - 0s 522us/step - loss: 0.0306 - mean_absolute_error: 0.0474 - val_loss: 0.0281 - val_mean_absolute_error: 0.0332
# Epoch 64/128
# 302/302 [==============================] - 0s 521us/step - loss: 0.0310 - mean_absolute_error: 0.0511 - val_loss: 0.0281 - val_mean_absolute_error: 0.0340
# Epoch 65/128
# 302/302 [==============================] - 0s 514us/step - loss: 0.0310 - mean_absolute_error: 0.0512 - val_loss: 0.0276 - val_mean_absolute_error: 0.0282
# Epoch 66/128
# 302/302 [==============================] - 0s 542us/step - loss: 0.0312 - mean_absolute_error: 0.0519 - val_loss: 0.0277 - val_mean_absolute_error: 0.0289
# Epoch 67/128
# 302/302 [==============================] - 0s 505us/step - loss: 0.0304 - mean_absolute_error: 0.0477 - val_loss: 0.0277 - val_mean_absolute_error: 0.0304
# Epoch 68/128
# 302/302 [==============================] - 0s 503us/step - loss: 0.0307 - mean_absolute_error: 0.0495 - val_loss: 0.0281 - val_mean_absolute_error: 0.0351
# Epoch 69/128
# 302/302 [==============================] - 0s 508us/step - loss: 0.0311 - mean_absolute_error: 0.0519 - val_loss: 0.0277 - val_mean_absolute_error: 0.0303
# Epoch 70/128
# 302/302 [==============================] - 0s 497us/step - loss: 0.0306 - mean_absolute_error: 0.0495 - val_loss: 0.0276 - val_mean_absolute_error: 0.0290
# Epoch 71/128
# 302/302 [==============================] - 0s 524us/step - loss: 0.0299 - mean_absolute_error: 0.0445 - val_loss: 0.0280 - val_mean_absolute_error: 0.0339
# Epoch 72/128
# 302/302 [==============================] - 0s 500us/step - loss: 0.0306 - mean_absolute_error: 0.0507 - val_loss: 0.0276 - val_mean_absolute_error: 0.0295
# Epoch 73/128
# 302/302 [==============================] - 0s 544us/step - loss: 0.0305 - mean_absolute_error: 0.0482 - val_loss: 0.0276 - val_mean_absolute_error: 0.0299
# Epoch 74/128
# 302/302 [==============================] - 0s 525us/step - loss: 0.0306 - mean_absolute_error: 0.0502 - val_loss: 0.0276 - val_mean_absolute_error: 0.0307
# Epoch 75/128
# 302/302 [==============================] - 0s 494us/step - loss: 0.0300 - mean_absolute_error: 0.0472 - val_loss: 0.0276 - val_mean_absolute_error: 0.0307
# Epoch 76/128
# 302/302 [==============================] - 0s 523us/step - loss: 0.0302 - mean_absolute_error: 0.0489 - val_loss: 0.0274 - val_mean_absolute_error: 0.0284
# Epoch 77/128
# 302/302 [==============================] - 0s 520us/step - loss: 0.0306 - mean_absolute_error: 0.0493 - val_loss: 0.0278 - val_mean_absolute_error: 0.0332
# Epoch 78/128
# 302/302 [==============================] - 0s 496us/step - loss: 0.0299 - mean_absolute_error: 0.0438 - val_loss: 0.0275 - val_mean_absolute_error: 0.0300
# Epoch 79/128
# 302/302 [==============================] - 0s 515us/step - loss: 0.0302 - mean_absolute_error: 0.0472 - val_loss: 0.0274 - val_mean_absolute_error: 0.0294
# Epoch 80/128
# 302/302 [==============================] - 0s 532us/step - loss: 0.0298 - mean_absolute_error: 0.0453 - val_loss: 0.0275 - val_mean_absolute_error: 0.0312
# Epoch 81/128
# 302/302 [==============================] - 0s 504us/step - loss: 0.0302 - mean_absolute_error: 0.0498 - val_loss: 0.0275 - val_mean_absolute_error: 0.0309
# Epoch 82/128
# 302/302 [==============================] - 0s 504us/step - loss: 0.0297 - mean_absolute_error: 0.0453 - val_loss: 0.0276 - val_mean_absolute_error: 0.0321
# Epoch 83/128
# 302/302 [==============================] - 0s 509us/step - loss: 0.0295 - mean_absolute_error: 0.0436 - val_loss: 0.0274 - val_mean_absolute_error: 0.0308
# Epoch 84/128
# 302/302 [==============================] - 0s 490us/step - loss: 0.0296 - mean_absolute_error: 0.0449 - val_loss: 0.0274 - val_mean_absolute_error: 0.0308
# Epoch 85/128
# 302/302 [==============================] - 0s 488us/step - loss: 0.0296 - mean_absolute_error: 0.0441 - val_loss: 0.0276 - val_mean_absolute_error: 0.0326
# Epoch 86/128
# 302/302 [==============================] - 0s 466us/step - loss: 0.0295 - mean_absolute_error: 0.0440 - val_loss: 0.0274 - val_mean_absolute_error: 0.0309
# Epoch 87/128
# 302/302 [==============================] - 0s 465us/step - loss: 0.0302 - mean_absolute_error: 0.0474 - val_loss: 0.0273 - val_mean_absolute_error: 0.0301
# Epoch 88/128
# 302/302 [==============================] - 0s 449us/step - loss: 0.0295 - mean_absolute_error: 0.0456 - val_loss: 0.0273 - val_mean_absolute_error: 0.0298
# Epoch 89/128
# 302/302 [==============================] - 0s 454us/step - loss: 0.0296 - mean_absolute_error: 0.0454 - val_loss: 0.0274 - val_mean_absolute_error: 0.0316
# 302/302 [==============================] - 0s 526us/step - loss: 0.0282 - mean_absolute_error: 0.0403 - val_loss: 0.0266 - val_mean_absolute_error: 0.0303
# Epoch 126/128
# 302/302 [==============================] - 0s 481us/step - loss: 0.0277 - mean_absolute_error: 0.0369 - val_loss: 0.0266 - val_mean_absolute_error: 0.0311
# Epoch 127/128
# 302/302 [==============================] - 0s 497us/step - loss: 0.0283 - mean_absolute_error: 0.0420 - val_loss: 0.0267 - val_mean_absolute_error: 0.0320
# Epoch 128/128
# 302/302 [==============================] - 0s 539us/step - loss: 0.0276 - mean_absolute_error: 0.0374 - val_loss: 0.0267 - val_mean_absolute_error: 0.0322
# Test MSE Score:2.788 %
# Test MAE Score:3.781 %

# %%
#绘制mae-loss曲线
history.loss_plot('epoch')
# input_shape[]

# %% [markdown]
# 获取得到需要用于预测的电池数据集B0018号电池

# %%
# 获取预测所需的电池数据集
def getBattery008data(discharge_matrix):
    x_pred=[]
    flag=0

    # 获取得到x_pred的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取0--37这段的长度，叠加+1循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成3*T的时间维度
            x_pred.append(bataery_data_training.T)
        flag+=1

    x_pred=np.array(x_pred[:len(x_pred)-1])
    return x_pred

# return prediction  data &  prediction  data true_so
discharge_008=r'/home/aqts/yangHong/battery experiment/jsonData/B0008_discharge.json'
# 获取得到一节电池的 特征向量 与true soc 
discharge_matrix_008,true_soc_008 =batterydata2matrix(discharge_008)
# 得到预测样本集 t=7
x_test_008=getBattery008data(discharge_matrix_008)


print("x_test_008 data shape is",x_test_008.shape)
# 预测数据集进行转换
if K.image_dim_ordering() == 'th':
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], img_rows, img_cols,1)
    input_shape = (img_rows, img_cols, 1)
# Out:
# x_test_008 data shape is (124, 3, 8)

# %%
pred=model.predict(x_test_008, batch_size=16, verbose=0)
print(pred.shape)
# Out:
# (124, 1)

# %%
import pandas as pd # 导入pandas库用来处理csv文件
import matplotlib.pyplot as plt # 导入matplotlib.pyplot并用plt简称

# true soc predict plot
x_true_soc=range(len(true_soc_008))
# 切割开始的基数一定为7
start=8
x_test_soc_008=range(start,start+pred.shape[0])
print("x_true_soc range is ",x_true_soc,"\n x_test_soc_008  range is:",x_test_soc_008)
plt.plot(x_true_soc, true_soc_008, linewidth=2.0, color='r',label="True SOC")#线的宽度为2.0，颜色为红色
plt.plot(x_test_soc_008, pred, linewidth=2.0, color='g',label="Prediction SOC")#线的宽度为2.0，颜色为绿色


# 设置x ,y轴的步长与刻度属性
plt.xticks([x for x in range(len(x_true_soc) + 1) if x %10 == 0])  # x标记step设置为10
plt.ylim(ymin=0.3,ymax=1.1)
# remark for x & y
plt.xlabel('Cylce')
plt.ylabel('SOC')
plt.title('Real Soc and Predicted Soc')

plt.legend()
plt.show()#显示图像
# Out:
# x_true_soc range is  range(0, 132)
#  x_test_soc_008  range is: range(8, 132)
