# %% [markdown]
# battery json data  convert to matrix and input to CNN for train

# %%
from sklearn import preprocessing 
from scipy.io import loadmat, whosmat
import numpy as np
import datetime
import json
import os
# 获取得到 json data of battery 
def json_load(dictonary):
    with open(dictonary) as f:
        data = json.load(f)
    return data

'''
cycle为行数，循环读取一行数据，对一行数据里面的voltage,current and temp求均值，并添加capacity features
得到battery array
'''
def batteryData2array(battery_data):
    vol_sum = 0
    cur_sum = 0
    temp_sum=0
    battery_array = []
    for cycle in battery_data.keys():
        # list type 
        battery_vols = battery_data[cycle]["voltage_battery"]
        battery_curs = battery_data[cycle]["current_battery"]
        battery_temps=battery_data[cycle]["temp_battery"]
        battery_capacity=battery_data[cycle]["Capacity"]
        for battery_vol in battery_vols:
            vol_sum += float(battery_vol)
        for battery_cur in battery_curs:
            cur_sum += float(battery_cur)
        for battery_temp in battery_temps:
            temp_sum += float(battery_temp)
        #for voltage and current average  & battery_vols,battery_curs,battery_temps's len is equal
        num = len(battery_vols)
        vol_aver = vol_sum / num
        cur_aver = cur_sum / num
        temp_aver=temp_sum/num
        vol_sum = 0
        cur_sum = 0
        temp_sum=0
        battery_array.append([vol_aver,cur_aver,temp_aver,battery_capacity[0]])
#         battery_array.append([vol_aver,cur_aver,battery_capacity[0]])
    return battery_array

# get battery's true soc
def  getTrueSOC(battery_discharge_data):
    batteryCapcity=2
    soc_dict=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        soc_true=cycleCapacity[0]/batteryCapcity
        soc_dict.append(soc_true)
    return soc_dict

# get battery's discgarge capacity
def  getTrueCapacity(battery_discharge_data):
    capacity=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        capacity.append(cycleCapacity[0])
    return capacity

'''
获取得到 battery 's img matrix 图像矩阵  4维特征向量  vol_aver,cur_aver,temp_aver,battery_capacity
返回battery discharge matrix and true soc array
'''
def batterydata2matrix(discharge):
    #get the discharge and charge json data
    discharge_data =json_load(discharge)
    
    #get the true soc data
    true_soc=getTrueSOC(discharge_data)
#   true_capacity=getTrueCapacity(discharge_data)
    #get the battery discharge array data  convert to matrix
    discharge_array = batteryData2array(discharge_data)
    discharge_matrix = np.array(discharge_array)

    discharge_matrix=preprocessing.scale(discharge_matrix)
    return discharge_matrix,true_soc

'''
获取得到每一节电池数据的训练数据集
得到train & test data
'''
def getTrainData(discharge_matrix,true_soc):     
    #循环切片形成数据集
    x=[];y=[]
    x_train=[];y_train=[]
    flag=0

    # 获取得到x,y的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取长度为8的矩阵，叠加循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成4*T的时间维度
            x.append(bataery_data_training.T)
        flag+=1
    #0-》t时刻d x 预测得到t时刻的soc。为了对soc 进行预测，y矩阵为【7：】
    y=true_soc[7:]
#     y=true_capacity[8:]

    VALIDATION_SPLIT=0.9
    x_validation_samples = int( VALIDATION_SPLIT* len(x))
    y_validation_samples = int( VALIDATION_SPLIT*len(y))
    
    
    # 获取得到训练集，验证集，比例9:1
    x_train=np.array(x[:x_validation_samples])
    x_test=np.array(x[x_validation_samples:])
    y_train=np.array(y[:y_validation_samples])
    y_test=np.array(y[y_validation_samples:])
    print("x_train's shape is:", x_train.shape,"，y_train's shape is:",y_train.shape)
    print("x_test's shape is:",x_test.shape,"，y_test's shape is:",y_test.shape)
    return x_train,x_test,y_train,y_test

# %%
# 定义全局变量，将所有电池数据集集合起来，形成训练集，测试集
# x_train_all,x_test_all,y_train_all,y_test_all=[],[],[],[]
for i in range(5,8):
    #/home/aqts/yangHong/battery experiment/jsonData
    discharge=r'/home/aqts/yangHong/battery experiment/jsonData/B000'+str(i)+'_discharge.json'
    discharge_matrix,true_soc=batterydata2matrix(discharge)
    train_x,test_x,train_y,test_y=getTrainData(discharge_matrix,true_soc)
    # start 开始时先赋值给x_train_all，x_test_all，y_train_all，y_test_all
    if i==5:
        x_train_all=train_x
        x_test_all=test_x
        y_train_all=train_y
        y_test_all=test_y
    else:
        x_train_all=np.concatenate((x_train_all,train_x),axis=0)
        x_test_all=np.concatenate((x_test_all,test_x),axis=0)
        y_train_all=np.concatenate((y_train_all,train_y),axis=0)
        y_test_all=np.concatenate((y_test_all,test_y),axis=0)
print(np.array(x_train_all).shape,np.array(x_test_all).shape,np.array(y_train_all).shape,np.array(y_test_all).shape)
# Out:
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 4, 8) ，y_test's shape is: (17,)
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 4, 8) ，y_test's shape is: (17,)
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 4, 8) ，y_test's shape is: (17,)
# (432, 4, 8) (51, 4, 8) (432,) (51,)

# %%
#写一个LossHistory类，保存loss和mae
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as k
import matplotlib.pyplot as plt
import numpy as np
from keras import backend as K
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = {'batch':[], 'epoch':[]}
        self.accuracy = {'batch':[], 'epoch':[]}
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_acc = {'batch':[], 'epoch':[]}

    def on_batch_end(self, batch, logs={}):
        self.losses['batch'].append(logs.get('loss'))
        self.accuracy['batch'].append(logs.get('mean_absolute_error'))
        self.val_loss['batch'].append(logs.get('val_loss'))
        self.val_acc['batch'].append(logs.get('val_mean_absolute_error'))

    def on_epoch_end(self, batch, logs={}):
        self.losses['epoch'].append(logs.get('loss'))
        self.accuracy['epoch'].append(logs.get('mean_absolute_error'))
        self.val_loss['epoch'].append(logs.get('val_loss'))
        self.val_acc['epoch'].append(logs.get('val_mean_absolute_error'))

    def loss_plot(self, loss_type):
        iters = range(len(self.losses[loss_type]))
        plt.figure()
        # mae
        plt.plot(iters, self.accuracy[loss_type], 'r', label='train mae')
        # loss
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        if loss_type == 'epoch':
            # val_mean_absolute_error
            plt.plot(iters, self.val_acc[loss_type], 'b', label='val mean absolute error')
            # val_loss
            plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('mae-loss')
        plt.legend(loc="upper right")
        plt.show()
# Out:
# /home/aqts/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#使用cnn训练的模型
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras import regularizers
from keras.optimizers import SGD, Adam
from keras.layers.normalization import BatchNormalization

num=1
img_rows, img_cols =x_train_all.shape[1],x_train_all.shape[2]
if K.image_dim_ordering() == 'th':
    x_train_all = x_train_all.reshape(x_train_all.shape[0], 1, img_rows, img_cols)
    x_test_all = x_test_all.reshape(x_test_all.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train_all = x_train_all.reshape(x_train_all.shape[0], img_rows, img_cols, 1)
    x_test_all= x_test_all.reshape(x_test_all.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)
# print(x_train.shape,x_test.shape)
# print(y_train.shape)
# keras序贯模型搭建CNN
# model building
model = Sequential()
#convolutional layer with rectified linear unit activation
model.add(Conv2D(32, kernel_size=(1,2),
                 activation='relu',
                 input_shape=input_shape,padding="same"))
#32 convolution filters used each of size 3x3
#again
model.add(Conv2D(32, (2,2), activation='relu',padding="same"))
#64 convolution filters used each of size 3x3
#choose the best features via pooling
model.add(MaxPooling2D(pool_size=(2, 2)))

#randomly turn neurons on and off to improve convergence
# model.add(Dropout(0.25))
#flatten since too many dimensions, we only want a classification output
model.add(Flatten())
#fully connected to get all relevant data
model.add(Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.25))

model.add(Dense(16, activation='relu'))
# model.add(Dropout(0.45))
model.add(BatchNormalization())
# model.add(Dense(num, activation='sigmoid'))
# The last layer does not use the activation function
model.add(Dense(num))

#Adaptive learning rate (adaDelta) is a popular form of gradient descent rivaled only by adam and adagrad
#categorical ce since we have multiple classes (10) 
# model.compile(loss=keras.losses.sparse_categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])
#回归问题评价指标使用mae
model.compile(loss='mse', optimizer="sgd", metrics=["mae"])


batch_size =16
num_epoch = 64


# decay_rate = learning_rate / num_epoch
# momentum = 0.8
# sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)

# model.compile(loss='mse', optimizer=sgd, metrics=["mae"])
#model training
history = LossHistory()
model.fit(x_train_all, y_train_all,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,validation_split=0.2,callbacks=[history])

mse_score,mae_score= model.evaluate(x_test_all, y_test_all, verbose=0)
print('Test MSE Score:%.3f %%'% (mse_score*100)) 
print('Test MAE Score:%.3f %%'% (mae_score*100))
# Out:
# Train on 345 samples, validate on 87 samples
# Epoch 1/64
# 345/345 [==============================] - 1s 2ms/step - loss: 0.4840 - mean_absolute_error: 0.5535 - val_loss: 0.2719 - val_mean_absolute_error: 0.4618
# Epoch 2/64
# 345/345 [==============================] - 0s 242us/step - loss: 0.1212 - mean_absolute_error: 0.2149 - val_loss: 0.1066 - val_mean_absolute_error: 0.2204
# Epoch 3/64
# 345/345 [==============================] - 0s 240us/step - loss: 0.0739 - mean_absolute_error: 0.1019 - val_loss: 0.0682 - val_mean_absolute_error: 0.1000
# Epoch 4/64
# 345/345 [==============================] - 0s 243us/step - loss: 0.0657 - mean_absolute_error: 0.0722 - val_loss: 0.0606 - val_mean_absolute_error: 0.0537
# Epoch 5/64
# 345/345 [==============================] - 0s 239us/step - loss: 0.0659 - mean_absolute_error: 0.0733 - val_loss: 0.0641 - val_mean_absolute_error: 0.0795
# Epoch 6/64
# 345/345 [==============================] - 0s 238us/step - loss: 0.0615 - mean_absolute_error: 0.0566 - val_loss: 0.0636 - val_mean_absolute_error: 0.0770
# Epoch 7/64
# 345/345 [==============================] - 0s 237us/step - loss: 0.0615 - mean_absolute_error: 0.0539 - val_loss: 0.0633 - val_mean_absolute_error: 0.0742
# Epoch 8/64
# 345/345 [==============================] - 0s 241us/step - loss: 0.0619 - mean_absolute_error: 0.0591 - val_loss: 0.0629 - val_mean_absolute_error: 0.0731
# Epoch 9/64
# 345/345 [==============================] - 0s 245us/step - loss: 0.0618 - mean_absolute_error: 0.0548 - val_loss: 0.0579 - val_mean_absolute_error: 0.0333
# Epoch 10/64
# 345/345 [==============================] - 0s 244us/step - loss: 0.0616 - mean_absolute_error: 0.0558 - val_loss: 0.0783 - val_mean_absolute_error: 0.1456
# Epoch 11/64
# 345/345 [==============================] - 0s 243us/step - loss: 0.0610 - mean_absolute_error: 0.0539 - val_loss: 0.0649 - val_mean_absolute_error: 0.0884
# Epoch 12/64
# 345/345 [==============================] - 0s 242us/step - loss: 0.0612 - mean_absolute_error: 0.0559 - val_loss: 0.0625 - val_mean_absolute_error: 0.0737
# Epoch 13/64
# 345/345 [==============================] - 0s 250us/step - loss: 0.0603 - mean_absolute_error: 0.0511 - val_loss: 0.0632 - val_mean_absolute_error: 0.0790
# Epoch 14/64
# 345/345 [==============================] - 0s 240us/step - loss: 0.0593 - mean_absolute_error: 0.0448 - val_loss: 0.0647 - val_mean_absolute_error: 0.0879
# Epoch 15/64
# 345/345 [==============================] - 0s 238us/step - loss: 0.0593 - mean_absolute_error: 0.0458 - val_loss: 0.0637 - val_mean_absolute_error: 0.0828
# Epoch 16/64
# 345/345 [==============================] - 0s 246us/step - loss: 0.0599 - mean_absolute_error: 0.0485 - val_loss: 0.0614 - val_mean_absolute_error: 0.0682
# Epoch 17/64
# 345/345 [==============================] - 0s 239us/step - loss: 0.0590 - mean_absolute_error: 0.0431 - val_loss: 0.0642 - val_mean_absolute_error: 0.0871
# Epoch 18/64
# 345/345 [==============================] - 0s 234us/step - loss: 0.0583 - mean_absolute_error: 0.0388 - val_loss: 0.0631 - val_mean_absolute_error: 0.0813
# Epoch 19/64
# 345/345 [==============================] - 0s 234us/step - loss: 0.0592 - mean_absolute_error: 0.0449 - val_loss: 0.0577 - val_mean_absolute_error: 0.0381
# Epoch 20/64
# 345/345 [==============================] - 0s 238us/step - loss: 0.0588 - mean_absolute_error: 0.0449 - val_loss: 0.0600 - val_mean_absolute_error: 0.0605
# Epoch 21/64
# 345/345 [==============================] - 0s 248us/step - loss: 0.0587 - mean_absolute_error: 0.0413 - val_loss: 0.0628 - val_mean_absolute_error: 0.0798
# Epoch 22/64
# 345/345 [==============================] - 0s 238us/step - loss: 0.0584 - mean_absolute_error: 0.0423 - val_loss: 0.0617 - val_mean_absolute_error: 0.0725
# Epoch 23/64
# 345/345 [==============================] - 0s 241us/step - loss: 0.0581 - mean_absolute_error: 0.0395 - val_loss: 0.0588 - val_mean_absolute_error: 0.0513
# Epoch 24/64
# 345/345 [==============================] - 0s 249us/step - loss: 0.0587 - mean_absolute_error: 0.0449 - val_loss: 0.0611 - val_mean_absolute_error: 0.0703
# Epoch 25/64
# 345/345 [==============================] - 0s 243us/step - loss: 0.0581 - mean_absolute_error: 0.0399 - val_loss: 0.0622 - val_mean_absolute_error: 0.0782
# Epoch 26/64
# 345/345 [==============================] - 0s 238us/step - loss: 0.0577 - mean_absolute_error: 0.0373 - val_loss: 0.0582 - val_mean_absolute_error: 0.0473
# Epoch 27/64
# 345/345 [==============================] - 0s 236us/step - loss: 0.0583 - mean_absolute_error: 0.0423 - val_loss: 0.0590 - val_mean_absolute_error: 0.0551
# Epoch 28/64
# 345/345 [==============================] - 0s 242us/step - loss: 0.0586 - mean_absolute_error: 0.0426 - val_loss: 0.0561 - val_mean_absolute_error: 0.0223
# Epoch 29/64
# 345/345 [==============================] - 0s 248us/step - loss: 0.0580 - mean_absolute_error: 0.0399 - val_loss: 0.0623 - val_mean_absolute_error: 0.0792
# Epoch 30/64
# 345/345 [==============================] - 0s 237us/step - loss: 0.0578 - mean_absolute_error: 0.0396 - val_loss: 0.0604 - val_mean_absolute_error: 0.0672
# Epoch 31/64
# 345/345 [==============================] - 0s 244us/step - loss: 0.0576 - mean_absolute_error: 0.0383 - val_loss: 0.0596 - val_mean_absolute_error: 0.0615
# Epoch 32/64
# 345/345 [==============================] - 0s 242us/step - loss: 0.0577 - mean_absolute_error: 0.0403 - val_loss: 0.0603 - val_mean_absolute_error: 0.0679
# Epoch 33/64
# 345/345 [==============================] - 0s 239us/step - loss: 0.0586 - mean_absolute_error: 0.0445 - val_loss: 0.0616 - val_mean_absolute_error: 0.0766
# Epoch 34/64
# 345/345 [==============================] - 0s 232us/step - loss: 0.0575 - mean_absolute_error: 0.0387 - val_loss: 0.0582 - val_mean_absolute_error: 0.0510
# Epoch 35/64
# 345/345 [==============================] - 0s 242us/step - loss: 0.0575 - mean_absolute_error: 0.0375 - val_loss: 0.0574 - val_mean_absolute_error: 0.0439
# Epoch 36/64
# 345/345 [==============================] - 0s 240us/step - loss: 0.0572 - mean_absolute_error: 0.0368 - val_loss: 0.0600 - val_mean_absolute_error: 0.0673
# Epoch 37/64
# 345/345 [==============================] - 0s 241us/step - loss: 0.0569 - mean_absolute_error: 0.0356 - val_loss: 0.0568 - val_mean_absolute_error: 0.0393
# Epoch 38/64
# 345/345 [==============================] - 0s 238us/step - loss: 0.0572 - mean_absolute_error: 0.0369 - val_loss: 0.0567 - val_mean_absolute_error: 0.0390
# Epoch 39/64
# 345/345 [==============================] - 0s 245us/step - loss: 0.0574 - mean_absolute_error: 0.0395 - val_loss: 0.0584 - val_mean_absolute_error: 0.0563
# Epoch 40/64
# 345/345 [==============================] - 0s 236us/step - loss: 0.0567 - mean_absolute_error: 0.0349 - val_loss: 0.0584 - val_mean_absolute_error: 0.0566
# Epoch 41/64
# 345/345 [==============================] - 0s 238us/step - loss: 0.0567 - mean_absolute_error: 0.0351 - val_loss: 0.0604 - val_mean_absolute_error: 0.0718
# Epoch 42/64
# 345/345 [==============================] - 0s 244us/step - loss: 0.0572 - mean_absolute_error: 0.0399 - val_loss: 0.0595 - val_mean_absolute_error: 0.0653
# Epoch 43/64
# 345/345 [==============================] - 0s 241us/step - loss: 0.0570 - mean_absolute_error: 0.0379 - val_loss: 0.0585 - val_mean_absolute_error: 0.0582
# Epoch 44/64
# 345/345 [==============================] - 0s 246us/step - loss: 0.0564 - mean_absolute_error: 0.0337 - val_loss: 0.0592 - val_mean_absolute_error: 0.0645
# Epoch 45/64
# 345/345 [==============================] - 0s 239us/step - loss: 0.0565 - mean_absolute_error: 0.0353 - val_loss: 0.0583 - val_mean_absolute_error: 0.0579
# Epoch 46/64
# 345/345 [==============================] - 0s 238us/step - loss: 0.0566 - mean_absolute_error: 0.0361 - val_loss: 0.0557 - val_mean_absolute_error: 0.0318
# Epoch 47/64
# 345/345 [==============================] - 0s 236us/step - loss: 0.0562 - mean_absolute_error: 0.0319 - val_loss: 0.0570 - val_mean_absolute_error: 0.0473
# Epoch 48/64
# 345/345 [==============================] - 0s 234us/step - loss: 0.0572 - mean_absolute_error: 0.0422 - val_loss: 0.0574 - val_mean_absolute_error: 0.0506
# Epoch 49/64
# 345/345 [==============================] - 0s 240us/step - loss: 0.0564 - mean_absolute_error: 0.0355 - val_loss: 0.0586 - val_mean_absolute_error: 0.0621
# Epoch 50/64
# 345/345 [==============================] - 0s 233us/step - loss: 0.0561 - mean_absolute_error: 0.0328 - val_loss: 0.0605 - val_mean_absolute_error: 0.0756
# Epoch 51/64
# 345/345 [==============================] - 0s 244us/step - loss: 0.0562 - mean_absolute_error: 0.0339 - val_loss: 0.0595 - val_mean_absolute_error: 0.0692
# Epoch 52/64
# 345/345 [==============================] - 0s 240us/step - loss: 0.0562 - mean_absolute_error: 0.0338 - val_loss: 0.0571 - val_mean_absolute_error: 0.0509
# Epoch 53/64
# 345/345 [==============================] - 0s 235us/step - loss: 0.0563 - mean_absolute_error: 0.0367 - val_loss: 0.0595 - val_mean_absolute_error: 0.0692
# Epoch 54/64
# 345/345 [==============================] - 0s 247us/step - loss: 0.0558 - mean_absolute_error: 0.0321 - val_loss: 0.0574 - val_mean_absolute_error: 0.0538
# Epoch 55/64
# 345/345 [==============================] - 0s 242us/step - loss: 0.0560 - mean_absolute_error: 0.0351 - val_loss: 0.0602 - val_mean_absolute_error: 0.0753
# Epoch 56/64
# 345/345 [==============================] - 0s 236us/step - loss: 0.0559 - mean_absolute_error: 0.0352 - val_loss: 0.0555 - val_mean_absolute_error: 0.0353
# Epoch 57/64
# 345/345 [==============================] - 0s 240us/step - loss: 0.0558 - mean_absolute_error: 0.0324 - val_loss: 0.0618 - val_mean_absolute_error: 0.0855
# Epoch 58/64
# 345/345 [==============================] - 0s 241us/step - loss: 0.0555 - mean_absolute_error: 0.0313 - val_loss: 0.0605 - val_mean_absolute_error: 0.0781
# Epoch 59/64
# 345/345 [==============================] - 0s 243us/step - loss: 0.0560 - mean_absolute_error: 0.0353 - val_loss: 0.0576 - val_mean_absolute_error: 0.0581
# Epoch 60/64
# 345/345 [==============================] - 0s 242us/step - loss: 0.0556 - mean_absolute_error: 0.0336 - val_loss: 0.0575 - val_mean_absolute_error: 0.0578
# Epoch 61/64
# 345/345 [==============================] - 0s 236us/step - loss: 0.0553 - mean_absolute_error: 0.0303 - val_loss: 0.0583 - val_mean_absolute_error: 0.0644
# Epoch 62/64
# 345/345 [==============================] - 0s 233us/step - loss: 0.0558 - mean_absolute_error: 0.0349 - val_loss: 0.0597 - val_mean_absolute_error: 0.0740
# Epoch 63/64
# 345/345 [==============================] - 0s 242us/step - loss: 0.0562 - mean_absolute_error: 0.0390 - val_loss: 0.0565 - val_mean_absolute_error: 0.0506
# Epoch 64/64
# 345/345 [==============================] - 0s 239us/step - loss: 0.0556 - mean_absolute_error: 0.0364 - val_loss: 0.0578 - val_mean_absolute_error: 0.0620
# Test MSE Score:5.572 %
# Test MAE Score:3.946 %

# %%
#绘制mae-loss曲线
history.loss_plot('epoch')

# %% [markdown]
# 获取得到需要用于预测的电池数据集B0018号电池

# %%
# 获取预测所需的电池数据集
def getBattery008data(discharge_matrix):
    x_pred=[]
    flag=0

    # 获取得到x_pred的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取0--37这段的长度，叠加+1循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成3*T的时间维度
            x_pred.append(bataery_data_training.T)
        flag+=1

    x_pred=np.array(x_pred)
    return x_pred

# return prediction  data &  prediction  data true_so
discharge_008=r'/home/aqts/yangHong/battery experiment/jsonData/B0008_discharge.json'
# 获取得到一节电池的 特征向量 与true soc 
discharge_matrix_008,true_soc_008 =batterydata2matrix(discharge_008)
# 得到预测样本集 t=7
x_test_008=getBattery008data(discharge_matrix_008)


print("x_test_008 data shape is",x_test_008.shape)
# 预测数据集进行转换
if K.image_dim_ordering() == 'th':
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], img_rows, img_cols,1)
    input_shape = (img_rows, img_cols, 1)
# Out:
# x_test_008 data shape is (125, 4, 8)

# %%
pred=model.predict(x_test_008, batch_size=16, verbose=0)
print(pred.shape)
# Out:
# (125, 1)

# %%
import pandas as pd # 导入pandas库用来处理csv文件
import matplotlib.pyplot as plt # 导入matplotlib.pyplot并用plt简称

# true soc predict plot
x_true_soc=range(len(true_soc_008))
# 切割开始的基数一定为7
start=6
x_test_soc_008=range(start,start+pred.shape[0])
print("x_true_soc range is ",x_true_soc,"\n x_test_soc_008  range is:",x_test_soc_008)
plt.plot(x_true_soc, true_soc_008, linewidth=2.0, color='r',label="True SOC")#线的宽度为2.0，颜色为红色
plt.plot(x_test_soc_008, pred, linewidth=2.0, color='g',label="Prediction SOC")#线的宽度为2.0，颜色为绿色


# 设置x ,y轴的步长与刻度属性
plt.xticks([x for x in range(len(x_true_soc) + 1) if x %10 == 0])  # x标记step设置为10
plt.ylim(ymin=0.3,ymax=1.1)
# remark for x & y
plt.xlabel('Cylce')
plt.ylabel('SOC')
plt.title('Real Soc and Predicted Soc')

plt.legend()
plt.show()#显示图像
# Out:
# x_true_soc range is  range(0, 132)
#  x_test_soc_008  range is: range(6, 131)
