# %% [markdown]
# battery json data  convert to matrix and input to CNN for train

# %%
from sklearn import preprocessing 
from scipy.io import loadmat, whosmat
import numpy as np
import datetime
import json
import os
# 获取得到 json data of battery 
def json_load(dictonary):
    with open(dictonary) as f:
        data = json.load(f)
    return data

'''
cycle为行数，循环读取一行数据，对一行数据里面的voltage,current and temp求均值，并添加capacity features
得到battery array
'''
def batteryData2array(battery_data):
    vol_sum = 0
    cur_sum = 0
    temp_sum=0
    battery_array = []
    for cycle in battery_data.keys():
        # list type 
        battery_vols = battery_data[cycle]["voltage_battery"]
        battery_curs = battery_data[cycle]["current_battery"]
        battery_temps=battery_data[cycle]["temp_battery"]
        battery_capacity=battery_data[cycle]["Capacity"]
        for battery_vol in battery_vols:
            vol_sum += float(battery_vol)
        for battery_cur in battery_curs:
            cur_sum += float(battery_cur)
        for battery_temp in battery_temps:
            temp_sum += float(battery_temp)
        #for voltage and current average  & battery_vols,battery_curs,battery_temps's len is equal
        num = len(battery_vols)
        vol_aver = vol_sum / num
        cur_aver = cur_sum / num
        temp_aver=temp_sum/num
        vol_sum = 0
        cur_sum = 0
        temp_sum=0
#         battery_array.append([vol_aver,cur_aver,temp_aver,battery_capacity[0]])
        battery_array.append([vol_aver,cur_aver,temp_aver])
    return battery_array

# get battery's true soc
def  getTrueSOC(battery_discharge_data):
    batteryCapcity=2
    soc_dict=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        soc_true=cycleCapacity[0]/batteryCapcity
        soc_dict.append(soc_true)
    return soc_dict

# get battery's discgarge capacity
def  getTrueCapacity(battery_discharge_data):
    capacity=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        capacity.append(cycleCapacity[0])
    return capacity

'''
获取得到 battery 's img matrix 图像矩阵  4维特征向量  vol_aver,cur_aver,temp_aver,battery_capacity
返回battery discharge matrix and true soc array
'''
def batterydata2matrix(discharge):
    #get the discharge and charge json data
    discharge_data =json_load(discharge)
    
    #get the true soc data
    true_soc=getTrueSOC(discharge_data)
#   true_capacity=getTrueCapacity(discharge_data)
    #get the battery discharge array data  convert to matrix
    discharge_array = batteryData2array(discharge_data)
    discharge_matrix = np.array(discharge_array)

    discharge_matrix=preprocessing.scale(discharge_matrix)
    return discharge_matrix,true_soc

'''
获取得到每一节电池数据的训练数据集
得到train & test data
'''
def getTrainData(discharge_matrix,true_soc):     
    #循环切片形成数据集
    x=[];y=[]
    x_train=[];y_train=[]
    flag=0

    # 获取得到x,y的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取长度为8的矩阵，叠加循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成4*T的时间维度
            x.append(bataery_data_training.T)
        flag+=1
    #0-》t时刻d x 预测得到t时刻的soc。为了对soc 进行预测，y矩阵为【7：】
    y=true_soc[7:]
#     y=true_capacity[8:]

    VALIDATION_SPLIT=0.9
    x_validation_samples = int( VALIDATION_SPLIT* len(x))
    y_validation_samples = int( VALIDATION_SPLIT*len(y))
    
    
    # 获取得到训练集，验证集，比例9:1
    x_train=np.array(x[:x_validation_samples])
    x_test=np.array(x[x_validation_samples:])
    y_train=np.array(y[:y_validation_samples])
    y_test=np.array(y[y_validation_samples:])
    print("x_train's shape is:", x_train.shape,"，y_train's shape is:",y_train.shape)
    print("x_test's shape is:",x_test.shape,"，y_test's shape is:",y_test.shape)
    return x_train,x_test,y_train,y_test

# %%
# 定义全局变量，将所有电池数据集集合起来，形成训练集，测试集
# x_train_all,x_test_all,y_train_all,y_test_all=[],[],[],[]
for i in range(5,8):
    #/home/aqts/yangHong/battery experiment/jsonData
    discharge=r'/home/aqts/yangHong/battery experiment/jsonData/B000'+str(i)+'_discharge.json'
    discharge_matrix,true_soc=batterydata2matrix(discharge)
    train_x,test_x,train_y,test_y=getTrainData(discharge_matrix,true_soc)
    # start 开始时先赋值给x_train_all，x_test_all，y_train_all，y_test_all
    if i==5:
        x_train_all=train_x
        x_test_all=test_x
        y_train_all=train_y
        y_test_all=test_y
    else:
        x_train_all=np.concatenate((x_train_all,train_x),axis=0)
        x_test_all=np.concatenate((x_test_all,test_x),axis=0)
        y_train_all=np.concatenate((y_train_all,train_y),axis=0)
        y_test_all=np.concatenate((y_test_all,test_y),axis=0)
print(np.array(x_train_all).shape,np.array(x_test_all).shape,np.array(y_train_all).shape,np.array(y_test_all).shape)
# Out:
# x_train's shape is: (144, 3, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 3, 8) ，y_test's shape is: (17,)
# x_train's shape is: (144, 3, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 3, 8) ，y_test's shape is: (17,)
# x_train's shape is: (144, 3, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 3, 8) ，y_test's shape is: (17,)
# (432, 3, 8) (51, 3, 8) (432,) (51,)

# %%
#写一个LossHistory类，保存loss和mae
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as k
import matplotlib.pyplot as plt
import numpy as np
from keras import backend as K
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = {'batch':[], 'epoch':[]}
        self.accuracy = {'batch':[], 'epoch':[]}
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_acc = {'batch':[], 'epoch':[]}

    def on_batch_end(self, batch, logs={}):
        self.losses['batch'].append(logs.get('loss'))
        self.accuracy['batch'].append(logs.get('mean_absolute_error'))
        self.val_loss['batch'].append(logs.get('val_loss'))
        self.val_acc['batch'].append(logs.get('val_mean_absolute_error'))

    def on_epoch_end(self, batch, logs={}):
        self.losses['epoch'].append(logs.get('loss'))
        self.accuracy['epoch'].append(logs.get('mean_absolute_error'))
        self.val_loss['epoch'].append(logs.get('val_loss'))
        self.val_acc['epoch'].append(logs.get('val_mean_absolute_error'))

    def loss_plot(self, loss_type):
        iters = range(len(self.losses[loss_type]))
        plt.figure()
        # mae
        plt.plot(iters, self.accuracy[loss_type], 'r', label='train mae')
        # loss
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        if loss_type == 'epoch':
            # val_mean_absolute_error
            plt.plot(iters, self.val_acc[loss_type], 'b', label='val mean absolute error')
            # val_loss
            plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('mae-loss')
        plt.legend(loc="upper right")
        plt.show()
# Out:
# /home/aqts/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# 基于序贯(Sequential)编程方式的模型

# %%
#使用cnn训练的模型
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D,GRU,LSTM
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras import regularizers
from keras.optimizers import SGD, Adam
from keras.layers.normalization import BatchNormalization
num=1
img_rows, img_cols =x_train_all.shape[1],x_train_all.shape[2]
if K.image_dim_ordering() == 'th':
    x_train_all = x_train_all.reshape(x_train_all.shape[0], 1, img_rows, img_cols)
    x_test_all = x_test_all.reshape(x_test_all.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train_all = x_train_all.reshape(x_train_all.shape[0], img_rows, img_cols, 1)
    x_test_all= x_test_all.reshape(x_test_all.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)
    
lstm_layer=(None, input_shape[0], input_shape[1], input_shape[2])
# print(x_train.shape,x_test.shape)
# print(y_train.shape)
# keras序贯模型搭建CNN
# model building
model = Sequential()
# same 模式 图片的尺寸大小保持不变(相对于输入图片的大小)
model.add(Conv2D(128, kernel_size=(1,2),
                 activation='relu',
                 input_shape=input_shape,padding="same"))
#32 convolution filters used each of size 3x3
#again
model.add(Conv2D(64, (2,2), activation='relu',padding="same"))
#64 convolution filters used each of size 3x3
#choose the best features via pooling
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (2,1), activation='relu',padding="same"))

model.add(Conv2D(32, (2,2), activation='relu',padding="same"))
# model.add(MaxPooling2D(pool_size=(2, 2)))
#randomly turn neurons on and off to improve convergence
# model.add(Dropout(0.30))
#flatten since too many dimensions, we only want a classification output
model.add(Flatten())
#fully connected to get all relevant data
model.add(Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.15))

model.add(Dense(16, activation='relu'))
model.add(Dropout(0.20))
# model.add(Dense(num, activation='sigmoid'))
# The last layer does not use the activation function
model.add(Dense(num))
model.summary()
#Adaptive learning rate (adaDelta) is a popular form of gradient descent rivaled only by adam and adagrad
#categorical ce since we have multiple classes (10) 
# model.compile(loss=keras.losses.sparse_categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])
#回归问题评价指标使用mae
model.compile(loss='mse', optimizer="sgd", metrics=["mae"])


batch_size =16
num_epoch = 128



# decay_rate = learning_rate / num_epoch
# momentum = 0.8
# sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)

# model.compile(loss='mse', optimizer=sgd, metrics=["mae"])
#model training
history = LossHistory()
model.fit(x_train_all, y_train_all,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,validation_split=0.3,callbacks=[history])

mse_score,mae_score= model.evaluate(x_test_all, y_test_all, verbose=0)
print('Test MSE Score:%.3f %%'% (mse_score*100)) 
print('Test MAE Score:%.3f %%'% (mae_score*100))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_246 (Conv2D)          (None, 3, 8, 128)         384
# _________________________________________________________________
# conv2d_247 (Conv2D)          (None, 3, 8, 64)          32832
# _________________________________________________________________
# max_pooling2d_69 (MaxPooling (None, 1, 4, 64)          0
# _________________________________________________________________
# conv2d_248 (Conv2D)          (None, 1, 4, 64)          8256
# _________________________________________________________________
# conv2d_249 (Conv2D)          (None, 1, 4, 32)          8224
# _________________________________________________________________
# flatten_57 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_165 (Dense)            (None, 16)                2064
# _________________________________________________________________
# dropout_109 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_166 (Dense)            (None, 16)                272
# _________________________________________________________________
# dropout_110 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_167 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 52,049
# Trainable params: 52,049
# Non-trainable params: 0
# _________________________________________________________________
# Train on 302 samples, validate on 130 samples
# Epoch 1/128
# 302/302 [==============================] - 6s 21ms/step - loss: 0.3786 - mean_absolute_error: 0.5675 - val_loss: 0.1759 - val_mean_absolute_error: 0.3790
# Epoch 2/128
# 302/302 [==============================] - 0s 500us/step - loss: 0.1045 - mean_absolute_error: 0.2381 - val_loss: 0.0606 - val_mean_absolute_error: 0.1696
# Epoch 3/128
# 302/302 [==============================] - 0s 527us/step - loss: 0.0588 - mean_absolute_error: 0.1327 - val_loss: 0.0398 - val_mean_absolute_error: 0.0913
# Epoch 4/128
# 302/302 [==============================] - 0s 519us/step - loss: 0.0557 - mean_absolute_error: 0.1234 - val_loss: 0.0358 - val_mean_absolute_error: 0.0691
# Epoch 5/128
# 302/302 [==============================] - 0s 533us/step - loss: 0.0498 - mean_absolute_error: 0.1166 - val_loss: 0.0351 - val_mean_absolute_error: 0.0655
# Epoch 6/128
# 302/302 [==============================] - 0s 529us/step - loss: 0.0506 - mean_absolute_error: 0.1125 - val_loss: 0.0335 - val_mean_absolute_error: 0.0545
# Epoch 7/128
# 302/302 [==============================] - 0s 512us/step - loss: 0.0470 - mean_absolute_error: 0.1040 - val_loss: 0.0336 - val_mean_absolute_error: 0.0551
# Epoch 8/128
# 302/302 [==============================] - 0s 518us/step - loss: 0.0454 - mean_absolute_error: 0.1000 - val_loss: 0.0335 - val_mean_absolute_error: 0.0544
# Epoch 9/128
# 302/302 [==============================] - 0s 515us/step - loss: 0.0445 - mean_absolute_error: 0.0985 - val_loss: 0.0334 - val_mean_absolute_error: 0.0540
# Epoch 10/128
# 302/302 [==============================] - 0s 536us/step - loss: 0.0441 - mean_absolute_error: 0.0962 - val_loss: 0.0332 - val_mean_absolute_error: 0.0534
# Epoch 11/128
# 302/302 [==============================] - 0s 532us/step - loss: 0.0443 - mean_absolute_error: 0.0974 - val_loss: 0.0322 - val_mean_absolute_error: 0.0451
# Epoch 12/128
# 302/302 [==============================] - 0s 518us/step - loss: 0.0463 - mean_absolute_error: 0.1000 - val_loss: 0.0323 - val_mean_absolute_error: 0.0454
# Epoch 13/128
# 302/302 [==============================] - ETA: 0s - loss: 0.0431 - mean_absolute_error: 0.089 - 0s 517us/step - loss: 0.0422 - mean_absolute_error: 0.0869 - val_loss: 0.0332 - val_mean_absolute_error: 0.0542
# Epoch 14/128
# 302/302 [==============================] - 0s 514us/step - loss: 0.0398 - mean_absolute_error: 0.0808 - val_loss: 0.0331 - val_mean_absolute_error: 0.0541
# Epoch 15/128
# 302/302 [==============================] - 0s 538us/step - loss: 0.0391 - mean_absolute_error: 0.0758 - val_loss: 0.0328 - val_mean_absolute_error: 0.0519
# Epoch 16/128
# 302/302 [==============================] - 0s 541us/step - loss: 0.0409 - mean_absolute_error: 0.0863 - val_loss: 0.0322 - val_mean_absolute_error: 0.0463
# Epoch 17/128
# 302/302 [==============================] - 0s 526us/step - loss: 0.0388 - mean_absolute_error: 0.0792 - val_loss: 0.0320 - val_mean_absolute_error: 0.0450
# Epoch 18/128
# 302/302 [==============================] - 0s 525us/step - loss: 0.0404 - mean_absolute_error: 0.0821 - val_loss: 0.0318 - val_mean_absolute_error: 0.0427
# Epoch 19/128
# 302/302 [==============================] - 0s 510us/step - loss: 0.0391 - mean_absolute_error: 0.0745 - val_loss: 0.0322 - val_mean_absolute_error: 0.0475
# Epoch 20/128
# 302/302 [==============================] - 0s 516us/step - loss: 0.0390 - mean_absolute_error: 0.0762 - val_loss: 0.0316 - val_mean_absolute_error: 0.0415
# Epoch 21/128
# 302/302 [==============================] - 0s 512us/step - loss: 0.0384 - mean_absolute_error: 0.0757 - val_loss: 0.0320 - val_mean_absolute_error: 0.0456
# Epoch 22/128
# 302/302 [==============================] - 0s 510us/step - loss: 0.0388 - mean_absolute_error: 0.0752 - val_loss: 0.0318 - val_mean_absolute_error: 0.0439
# Epoch 23/128
# 302/302 [==============================] - 0s 522us/step - loss: 0.0391 - mean_absolute_error: 0.0767 - val_loss: 0.0317 - val_mean_absolute_error: 0.0434
# Epoch 24/128
# 302/302 [==============================] - 0s 529us/step - loss: 0.0372 - mean_absolute_error: 0.0690 - val_loss: 0.0316 - val_mean_absolute_error: 0.0424
# Epoch 25/128
# 302/302 [==============================] - 0s 513us/step - loss: 0.0372 - mean_absolute_error: 0.0704 - val_loss: 0.0312 - val_mean_absolute_error: 0.0379
# Epoch 26/128
# 302/302 [==============================] - 0s 507us/step - loss: 0.0374 - mean_absolute_error: 0.0689 - val_loss: 0.0318 - val_mean_absolute_error: 0.0451
# Epoch 27/128
# 302/302 [==============================] - 0s 522us/step - loss: 0.0367 - mean_absolute_error: 0.0670 - val_loss: 0.0315 - val_mean_absolute_error: 0.0415
# Epoch 28/128
# 302/302 [==============================] - 0s 515us/step - loss: 0.0373 - mean_absolute_error: 0.0725 - val_loss: 0.0316 - val_mean_absolute_error: 0.0436
# Epoch 29/128
# 302/302 [==============================] - 0s 525us/step - loss: 0.0360 - mean_absolute_error: 0.0647 - val_loss: 0.0309 - val_mean_absolute_error: 0.0355
# Epoch 30/128
# 302/302 [==============================] - 0s 512us/step - loss: 0.0366 - mean_absolute_error: 0.0666 - val_loss: 0.0314 - val_mean_absolute_error: 0.0410
# Epoch 31/128
# 302/302 [==============================] - 0s 537us/step - loss: 0.0359 - mean_absolute_error: 0.0621 - val_loss: 0.0310 - val_mean_absolute_error: 0.0374
# Epoch 32/128
# 302/302 [==============================] - 0s 529us/step - loss: 0.0357 - mean_absolute_error: 0.0635 - val_loss: 0.0312 - val_mean_absolute_error: 0.0396
# Epoch 33/128
# 302/302 [==============================] - 0s 522us/step - loss: 0.0356 - mean_absolute_error: 0.0634 - val_loss: 0.0314 - val_mean_absolute_error: 0.0427
# Epoch 34/128
# 302/302 [==============================] - 0s 543us/step - loss: 0.0352 - mean_absolute_error: 0.0603 - val_loss: 0.0311 - val_mean_absolute_error: 0.0384
# Epoch 35/128
# 302/302 [==============================] - 0s 536us/step - loss: 0.0362 - mean_absolute_error: 0.0644 - val_loss: 0.0311 - val_mean_absolute_error: 0.0392
# Epoch 36/128
# 302/302 [==============================] - 0s 514us/step - loss: 0.0348 - mean_absolute_error: 0.0576 - val_loss: 0.0310 - val_mean_absolute_error: 0.0386
# Epoch 37/128
# 302/302 [==============================] - 0s 519us/step - loss: 0.0342 - mean_absolute_error: 0.0548 - val_loss: 0.0311 - val_mean_absolute_error: 0.0394
# Epoch 38/128
# 302/302 [==============================] - 0s 521us/step - loss: 0.0347 - mean_absolute_error: 0.0579 - val_loss: 0.0310 - val_mean_absolute_error: 0.0390
# Epoch 39/128
# 302/302 [==============================] - 0s 512us/step - loss: 0.0352 - mean_absolute_error: 0.0592 - val_loss: 0.0314 - val_mean_absolute_error: 0.0446
# Epoch 40/128
# 302/302 [==============================] - 0s 516us/step - loss: 0.0362 - mean_absolute_error: 0.0645 - val_loss: 0.0308 - val_mean_absolute_error: 0.0367
# Epoch 41/128
# 302/302 [==============================] - 0s 511us/step - loss: 0.0343 - mean_absolute_error: 0.0568 - val_loss: 0.0309 - val_mean_absolute_error: 0.0385
# Epoch 42/128
# 302/302 [==============================] - 0s 520us/step - loss: 0.0343 - mean_absolute_error: 0.0554 - val_loss: 0.0308 - val_mean_absolute_error: 0.0375
# Epoch 43/128
# 302/302 [==============================] - 0s 523us/step - loss: 0.0352 - mean_absolute_error: 0.0599 - val_loss: 0.0306 - val_mean_absolute_error: 0.0353
# Epoch 44/128
# 302/302 [==============================] - 0s 518us/step - loss: 0.0344 - mean_absolute_error: 0.0561 - val_loss: 0.0307 - val_mean_absolute_error: 0.0375
# Epoch 45/128
# 302/302 [==============================] - 0s 503us/step - loss: 0.0353 - mean_absolute_error: 0.0616 - val_loss: 0.0306 - val_mean_absolute_error: 0.0356
# Epoch 46/128
# 302/302 [==============================] - 0s 544us/step - loss: 0.0340 - mean_absolute_error: 0.0563 - val_loss: 0.0309 - val_mean_absolute_error: 0.0401
# Epoch 47/128
# 302/302 [==============================] - 0s 527us/step - loss: 0.0339 - mean_absolute_error: 0.0546 - val_loss: 0.0310 - val_mean_absolute_error: 0.0418
# Epoch 48/128
# 302/302 [==============================] - 0s 526us/step - loss: 0.0332 - mean_absolute_error: 0.0525 - val_loss: 0.0307 - val_mean_absolute_error: 0.0384
# Epoch 49/128
# 302/302 [==============================] - 0s 504us/step - loss: 0.0335 - mean_absolute_error: 0.0530 - val_loss: 0.0307 - val_mean_absolute_error: 0.0389
# Epoch 50/128
# 302/302 [==============================] - 0s 507us/step - loss: 0.0338 - mean_absolute_error: 0.0542 - val_loss: 0.0305 - val_mean_absolute_error: 0.0359
# Epoch 51/128
# 302/302 [==============================] - 0s 505us/step - loss: 0.0329 - mean_absolute_error: 0.0498 - val_loss: 0.0303 - val_mean_absolute_error: 0.0340
# Epoch 52/128
# 302/302 [==============================] - 0s 526us/step - loss: 0.0341 - mean_absolute_error: 0.0554 - val_loss: 0.0305 - val_mean_absolute_error: 0.0366
# Epoch 53/128
# 302/302 [==============================] - 0s 534us/step - loss: 0.0336 - mean_absolute_error: 0.0523 - val_loss: 0.0303 - val_mean_absolute_error: 0.0342
# Epoch 54/128
# 302/302 [==============================] - 0s 504us/step - loss: 0.0335 - mean_absolute_error: 0.0521 - val_loss: 0.0302 - val_mean_absolute_error: 0.0334
# Epoch 55/128
# 302/302 [==============================] - 0s 534us/step - loss: 0.0334 - mean_absolute_error: 0.0526 - val_loss: 0.0303 - val_mean_absolute_error: 0.0348
# Epoch 56/128
# 302/302 [==============================] - 0s 545us/step - loss: 0.0333 - mean_absolute_error: 0.0544 - val_loss: 0.0303 - val_mean_absolute_error: 0.0359
# Epoch 57/128
# 302/302 [==============================] - 0s 522us/step - loss: 0.0335 - mean_absolute_error: 0.0540 - val_loss: 0.0301 - val_mean_absolute_error: 0.0323
# Epoch 58/128
# 302/302 [==============================] - 0s 515us/step - loss: 0.0334 - mean_absolute_error: 0.0536 - val_loss: 0.0302 - val_mean_absolute_error: 0.0346
# Epoch 59/128
# 302/302 [==============================] - 0s 521us/step - loss: 0.0330 - mean_absolute_error: 0.0519 - val_loss: 0.0304 - val_mean_absolute_error: 0.0373
# Epoch 60/128
# 302/302 [==============================] - 0s 508us/step - loss: 0.0332 - mean_absolute_error: 0.0528 - val_loss: 0.0303 - val_mean_absolute_error: 0.0366
# Epoch 61/128
# 302/302 [==============================] - 0s 529us/step - loss: 0.0337 - mean_absolute_error: 0.0545 - val_loss: 0.0302 - val_mean_absolute_error: 0.0355
# Epoch 62/128
# 302/302 [==============================] - 0s 528us/step - loss: 0.0337 - mean_absolute_error: 0.0546 - val_loss: 0.0302 - val_mean_absolute_error: 0.0357
# Epoch 63/128
# 302/302 [==============================] - 0s 523us/step - loss: 0.0327 - mean_absolute_error: 0.0495 - val_loss: 0.0304 - val_mean_absolute_error: 0.0383
# Epoch 64/128
# 302/302 [==============================] - 0s 510us/step - loss: 0.0330 - mean_absolute_error: 0.0512 - val_loss: 0.0303 - val_mean_absolute_error: 0.0378
# Epoch 65/128
# 302/302 [==============================] - 0s 526us/step - loss: 0.0330 - mean_absolute_error: 0.0509 - val_loss: 0.0301 - val_mean_absolute_error: 0.0360
# Epoch 66/128
# 302/302 [==============================] - 0s 516us/step - loss: 0.0324 - mean_absolute_error: 0.0482 - val_loss: 0.0301 - val_mean_absolute_error: 0.0358
# Epoch 67/128
# 302/302 [==============================] - 0s 531us/step - loss: 0.0323 - mean_absolute_error: 0.0465 - val_loss: 0.0302 - val_mean_absolute_error: 0.0370
# Epoch 68/128
# 302/302 [==============================] - 0s 522us/step - loss: 0.0334 - mean_absolute_error: 0.0552 - val_loss: 0.0299 - val_mean_absolute_error: 0.0339
# Epoch 69/128
# 302/302 [==============================] - 0s 523us/step - loss: 0.0327 - mean_absolute_error: 0.0506 - val_loss: 0.0299 - val_mean_absolute_error: 0.0345
# Epoch 70/128
# 302/302 [==============================] - 0s 525us/step - loss: 0.0324 - mean_absolute_error: 0.0485 - val_loss: 0.0300 - val_mean_absolute_error: 0.0353
# Epoch 71/128
# 302/302 [==============================] - 0s 518us/step - loss: 0.0318 - mean_absolute_error: 0.0462 - val_loss: 0.0300 - val_mean_absolute_error: 0.0362
# Epoch 72/128
# 302/302 [==============================] - 0s 536us/step - loss: 0.0320 - mean_absolute_error: 0.0464 - val_loss: 0.0299 - val_mean_absolute_error: 0.0348
# Epoch 73/128
# 302/302 [==============================] - 0s 522us/step - loss: 0.0327 - mean_absolute_error: 0.0508 - val_loss: 0.0301 - val_mean_absolute_error: 0.0376
# Epoch 74/128
# 302/302 [==============================] - 0s 520us/step - loss: 0.0323 - mean_absolute_error: 0.0489 - val_loss: 0.0300 - val_mean_absolute_error: 0.0364
# Epoch 75/128
# 302/302 [==============================] - 0s 530us/step - loss: 0.0320 - mean_absolute_error: 0.0471 - val_loss: 0.0297 - val_mean_absolute_error: 0.0332
# Epoch 76/128
# 302/302 [==============================] - 0s 513us/step - loss: 0.0327 - mean_absolute_error: 0.0519 - val_loss: 0.0298 - val_mean_absolute_error: 0.0341
# Epoch 77/128
# 302/302 [==============================] - 0s 521us/step - loss: 0.0324 - mean_absolute_error: 0.0488 - val_loss: 0.0297 - val_mean_absolute_error: 0.0340
# Epoch 78/128
# 302/302 [==============================] - 0s 516us/step - loss: 0.0318 - mean_absolute_error: 0.0465 - val_loss: 0.0297 - val_mean_absolute_error: 0.0334
# Epoch 79/128
# 302/302 [==============================] - 0s 528us/step - loss: 0.0316 - mean_absolute_error: 0.0460 - val_loss: 0.0299 - val_mean_absolute_error: 0.0372
# Epoch 80/128
# 302/302 [==============================] - 0s 520us/step - loss: 0.0323 - mean_absolute_error: 0.0482 - val_loss: 0.0298 - val_mean_absolute_error: 0.0354
# Epoch 81/128
# 302/302 [==============================] - 0s 539us/step - loss: 0.0317 - mean_absolute_error: 0.0452 - val_loss: 0.0300 - val_mean_absolute_error: 0.0383
# Epoch 82/128
# 302/302 [==============================] - 0s 537us/step - loss: 0.0313 - mean_absolute_error: 0.0431 - val_loss: 0.0299 - val_mean_absolute_error: 0.0377
# Epoch 83/128
# 302/302 [==============================] - 0s 525us/step - loss: 0.0316 - mean_absolute_error: 0.0438 - val_loss: 0.0295 - val_mean_absolute_error: 0.0333
# Epoch 84/128
# 302/302 [==============================] - 0s 518us/step - loss: 0.0317 - mean_absolute_error: 0.0443 - val_loss: 0.0297 - val_mean_absolute_error: 0.0359
# Epoch 85/128
# 302/302 [==============================] - 0s 513us/step - loss: 0.0320 - mean_absolute_error: 0.0480 - val_loss: 0.0297 - val_mean_absolute_error: 0.0352
# Epoch 86/128
# 302/302 [==============================] - 0s 514us/step - loss: 0.0311 - mean_absolute_error: 0.0431 - val_loss: 0.0295 - val_mean_absolute_error: 0.0337
# Epoch 87/128
# 302/302 [==============================] - 0s 530us/step - loss: 0.0314 - mean_absolute_error: 0.0428 - val_loss: 0.0296 - val_mean_absolute_error: 0.0346
# Epoch 88/128
# 302/302 [==============================] - 0s 514us/step - loss: 0.0313 - mean_absolute_error: 0.0451 - val_loss: 0.0294 - val_mean_absolute_error: 0.0325
# Epoch 89/128
# 302/302 [==============================] - 0s 526us/step - loss: 0.0319 - mean_absolute_error: 0.0487 - val_loss: 0.0297 - val_mean_absolute_error: 0.0370
# Epoch 90/128
# 302/302 [==============================] - 0s 521us/step - loss: 0.0316 - mean_absolute_error: 0.0465 - val_loss: 0.0295 - val_mean_absolute_error: 0.0340
# Epoch 91/128
# 302/302 [==============================] - 0s 526us/step - loss: 0.0310 - mean_absolute_error: 0.0438 - val_loss: 0.0297 - val_mean_absolute_error: 0.0377
# Epoch 92/128
# 302/302 [==============================] - 0s 532us/step - loss: 0.0314 - mean_absolute_error: 0.0460 - val_loss: 0.0294 - val_mean_absolute_error: 0.0340
# Epoch 93/128
# 302/302 [==============================] - 0s 509us/step - loss: 0.0315 - mean_absolute_error: 0.0450 - val_loss: 0.0294 - val_mean_absolute_error: 0.0344
# Epoch 94/128
# 302/302 [==============================] - 0s 529us/step - loss: 0.0315 - mean_absolute_error: 0.0453 - val_loss: 0.0293 - val_mean_absolute_error: 0.0329
# Epoch 95/128
# 302/302 [==============================] - 0s 528us/step - loss: 0.0309 - mean_absolute_error: 0.0426 - val_loss: 0.0293 - val_mean_absolute_error: 0.0331
# Epoch 96/128
# 302/302 [==============================] - 0s 524us/step - loss: 0.0312 - mean_absolute_error: 0.0444 - val_loss: 0.0297 - val_mean_absolute_error: 0.0384
# Epoch 97/128
# 302/302 [==============================] - 0s 531us/step - loss: 0.0314 - mean_absolute_error: 0.0451 - val_loss: 0.0292 - val_mean_absolute_error: 0.0328
# Epoch 98/128
# 302/302 [==============================] - 0s 532us/step - loss: 0.0305 - mean_absolute_error: 0.0414 - val_loss: 0.0293 - val_mean_absolute_error: 0.0340
# Epoch 99/128
# 302/302 [==============================] - 0s 521us/step - loss: 0.0308 - mean_absolute_error: 0.0427 - val_loss: 0.0292 - val_mean_absolute_error: 0.0329
# Epoch 100/128
# 302/302 [==============================] - 0s 516us/step - loss: 0.0312 - mean_absolute_error: 0.0434 - val_loss: 0.0293 - val_mean_absolute_error: 0.0344
# Epoch 101/128
# 302/302 [==============================] - 0s 525us/step - loss: 0.0308 - mean_absolute_error: 0.0420 - val_loss: 0.0293 - val_mean_absolute_error: 0.0357
# Epoch 102/128
# 302/302 [==============================] - 0s 528us/step - loss: 0.0307 - mean_absolute_error: 0.0404 - val_loss: 0.0292 - val_mean_absolute_error: 0.0348
# Epoch 103/128
# 302/302 [==============================] - 0s 528us/step - loss: 0.0307 - mean_absolute_error: 0.0435 - val_loss: 0.0293 - val_mean_absolute_error: 0.0354
# Epoch 104/128
# 302/302 [==============================] - 0s 525us/step - loss: 0.0310 - mean_absolute_error: 0.0435 - val_loss: 0.0293 - val_mean_absolute_error: 0.0358
# Epoch 105/128
# 302/302 [==============================] - 0s 529us/step - loss: 0.0307 - mean_absolute_error: 0.0428 - val_loss: 0.0293 - val_mean_absolute_error: 0.0371
# Epoch 106/128
# 302/302 [==============================] - 0s 549us/step - loss: 0.0308 - mean_absolute_error: 0.0429 - val_loss: 0.0291 - val_mean_absolute_error: 0.0344
# Epoch 107/128
# 302/302 [==============================] - 0s 521us/step - loss: 0.0304 - mean_absolute_error: 0.0411 - val_loss: 0.0292 - val_mean_absolute_error: 0.0352
# Epoch 108/128
# 302/302 [==============================] - 0s 524us/step - loss: 0.0307 - mean_absolute_error: 0.0414 - val_loss: 0.0289 - val_mean_absolute_error: 0.0319
# Epoch 109/128
# 302/302 [==============================] - 0s 527us/step - loss: 0.0304 - mean_absolute_error: 0.0416 - val_loss: 0.0287 - val_mean_absolute_error: 0.0293
# Epoch 110/128
# 302/302 [==============================] - 0s 524us/step - loss: 0.0303 - mean_absolute_error: 0.0405 - val_loss: 0.0290 - val_mean_absolute_error: 0.0339
# Epoch 111/128
# 302/302 [==============================] - 0s 510us/step - loss: 0.0303 - mean_absolute_error: 0.0397 - val_loss: 0.0290 - val_mean_absolute_error: 0.0338
# Epoch 112/128
# 302/302 [==============================] - 0s 531us/step - loss: 0.0303 - mean_absolute_error: 0.0398 - val_loss: 0.0289 - val_mean_absolute_error: 0.0336
# Epoch 113/128
# 302/302 [==============================] - 0s 533us/step - loss: 0.0304 - mean_absolute_error: 0.0409 - val_loss: 0.0288 - val_mean_absolute_error: 0.0322
# Epoch 114/128
# 302/302 [==============================] - 0s 528us/step - loss: 0.0301 - mean_absolute_error: 0.0398 - val_loss: 0.0290 - val_mean_absolute_error: 0.0344
# Epoch 115/128
# 302/302 [==============================] - 0s 533us/step - loss: 0.0306 - mean_absolute_error: 0.0423 - val_loss: 0.0288 - val_mean_absolute_error: 0.0322
# Epoch 116/128
# 302/302 [==============================] - 0s 519us/step - loss: 0.0301 - mean_absolute_error: 0.0399 - val_loss: 0.0288 - val_mean_absolute_error: 0.0329
# Epoch 117/128
# 302/302 [==============================] - 0s 513us/step - loss: 0.0300 - mean_absolute_error: 0.0388 - val_loss: 0.0288 - val_mean_absolute_error: 0.0330
# Epoch 118/128
# 302/302 [==============================] - 0s 513us/step - loss: 0.0300 - mean_absolute_error: 0.0387 - val_loss: 0.0286 - val_mean_absolute_error: 0.0311
# Epoch 119/128
# 302/302 [==============================] - 0s 533us/step - loss: 0.0301 - mean_absolute_error: 0.0400 - val_loss: 0.0285 - val_mean_absolute_error: 0.0297
# Epoch 120/128
# 302/302 [==============================] - 0s 522us/step - loss: 0.0298 - mean_absolute_error: 0.0384 - val_loss: 0.0285 - val_mean_absolute_error: 0.0305
# Epoch 121/128
# 302/302 [==============================] - 0s 524us/step - loss: 0.0302 - mean_absolute_error: 0.0416 - val_loss: 0.0287 - val_mean_absolute_error: 0.0327
# Epoch 122/128
# 302/302 [==============================] - 0s 512us/step - loss: 0.0299 - mean_absolute_error: 0.0391 - val_loss: 0.0287 - val_mean_absolute_error: 0.0329
# Epoch 123/128
# 302/302 [==============================] - 0s 511us/step - loss: 0.0298 - mean_absolute_error: 0.0379 - val_loss: 0.0288 - val_mean_absolute_error: 0.0351
# Epoch 124/128
# 302/302 [==============================] - 0s 521us/step - loss: 0.0299 - mean_absolute_error: 0.0383 - val_loss: 0.0286 - val_mean_absolute_error: 0.0332
# Epoch 125/128
# 302/302 [==============================] - 0s 504us/step - loss: 0.0301 - mean_absolute_error: 0.0420 - val_loss: 0.0287 - val_mean_absolute_error: 0.0337
# Epoch 126/128
# 302/302 [==============================] - 0s 519us/step - loss: 0.0298 - mean_absolute_error: 0.0390 - val_loss: 0.0286 - val_mean_absolute_error: 0.0329
# Epoch 127/128
# 302/302 [==============================] - 0s 526us/step - loss: 0.0300 - mean_absolute_error: 0.0408 - val_loss: 0.0285 - val_mean_absolute_error: 0.0325
# Epoch 128/128
# 302/302 [==============================] - 0s 524us/step - loss: 0.0300 - mean_absolute_error: 0.0418 - val_loss: 0.0284 - val_mean_absolute_error: 0.0310
# Test MSE Score:3.137 %
# Test MAE Score:5.127 %

# %%
#绘制mae-loss曲线
history.loss_plot('epoch')
# input_shape[]

# %% [markdown]
# 获取得到需要用于预测的电池数据集B0018号电池

# %%
# 获取预测所需的电池数据集
def getBattery008data(discharge_matrix):
    x_pred=[]
    flag=0

    # 获取得到x_pred的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取0--37这段的长度，叠加+1循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成3*T的时间维度
            x_pred.append(bataery_data_training.T)
        flag+=1

    x_pred=np.array(x_pred)
    return x_pred

# return prediction  data &  prediction  data true_so
discharge_008=r'/home/aqts/yangHong/battery experiment/jsonData/B0008_discharge.json'
# 获取得到一节电池的 特征向量 与true soc 
discharge_matrix_008,true_soc_008 =batterydata2matrix(discharge_008)
# 得到预测样本集 t=7
x_test_008=getBattery008data(discharge_matrix_008)


print("x_test_008 data shape is",x_test_008.shape)
# 预测数据集进行转换
if K.image_dim_ordering() == 'th':
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], img_rows, img_cols,1)
    input_shape = (img_rows, img_cols, 1)
# Out:
# x_test_008 data shape is (125, 3, 8)

# %%
pred=model.predict(x_test_008, batch_size=16, verbose=0)
print(pred.shape)
# Out:
# (125, 1)

# %%
import pandas as pd # 导入pandas库用来处理csv文件
import matplotlib.pyplot as plt # 导入matplotlib.pyplot并用plt简称

# true soc predict plot
x_true_soc=range(len(true_soc_008))
# 切割开始的基数一定为7
start=6
x_test_soc_008=range(start,start+pred.shape[0])
print("x_true_soc range is ",x_true_soc,"\n x_test_soc_008  range is:",x_test_soc_008)
plt.plot(x_true_soc, true_soc_008, linewidth=2.0, color='r',label="True SOC")#线的宽度为2.0，颜色为红色
plt.plot(x_test_soc_008, pred, linewidth=2.0, color='g',label="Prediction SOC")#线的宽度为2.0，颜色为绿色


# 设置x ,y轴的步长与刻度属性
plt.xticks([x for x in range(len(x_true_soc) + 1) if x %10 == 0])  # x标记step设置为10
plt.ylim(ymin=0.3,ymax=1.1)
# remark for x & y
plt.xlabel('Cylce')
plt.ylabel('SOC')
plt.title('Real Soc and Predicted Soc')

plt.legend()
plt.show()#显示图像
# Out:
# x_true_soc range is  range(0, 132)
#  x_test_soc_008  range is: range(6, 131)

# %%
input_shape
# Out:
# (3, 8, 1)
