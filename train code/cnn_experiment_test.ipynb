# %% [markdown]
# battery json data  convert to matrix and input to CNN for train

# %%
from sklearn import preprocessing 
from scipy.io import loadmat, whosmat
import numpy as np
import datetime
import json
import os
# 获取得到 json data of battery 
def json_load(dictonary):
    with open(dictonary) as f:
        data = json.load(f)
    return data

'''
cycle为行数，循环读取一行数据，对一行数据里面的voltage,current and temp求均值，并添加capacity features
得到battery array
'''
def batteryData2array(battery_data):
    vol_sum = 0
    cur_sum = 0
    temp_sum=0
    battery_array = []
    for cycle in battery_data.keys():
        # list type 
        battery_vols = battery_data[cycle]["voltage_battery"]
        battery_curs = battery_data[cycle]["current_battery"]
        battery_temps=battery_data[cycle]["temp_battery"]
        battery_capacity=battery_data[cycle]["Capacity"]
        for battery_vol in battery_vols:
            vol_sum += float(battery_vol)
        for battery_cur in battery_curs:
            cur_sum += float(battery_cur)
        for battery_temp in battery_temps:
            temp_sum += float(battery_temp)
        #for voltage and current average  & battery_vols,battery_curs,battery_temps's len is equal
        num = len(battery_vols)
        vol_aver = vol_sum / num
        cur_aver = cur_sum / num
        temp_aver=temp_sum/num
        vol_sum = 0
        cur_sum = 0
        temp_sum=0
        battery_array.append([vol_aver,cur_aver,temp_aver,battery_capacity[0]])
#         battery_array.append([vol_aver,cur_aver,battery_capacity[0]])
    return battery_array

# get battery's true soc
def  getTrueSOC(battery_discharge_data):
    batteryCapcity=2
    soc_dict=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        soc_true=cycleCapacity[0]/batteryCapcity
        soc_dict.append(soc_true)
    return soc_dict

# get battery's discgarge capacity
def  getTrueCapacity(battery_discharge_data):
    capacity=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        capacity.append(cycleCapacity[0])
    return capacity

'''
获取得到 battery 's img matrix 图像矩阵  4维特征向量  vol_aver,cur_aver,temp_aver,battery_capacity
返回battery discharge matrix and true soc array
'''
def batterydata2matrix(discharge):
    #get the discharge and charge json data
    discharge_data =json_load(discharge)
    
    #get the true soc data
    true_soc=getTrueSOC(discharge_data)
#   true_capacity=getTrueCapacity(discharge_data)
    #get the battery discharge array data  convert to matrix
    discharge_array = batteryData2array(discharge_data)
    discharge_matrix = np.array(discharge_array)

    discharge_matrix=preprocessing.scale(discharge_matrix)
    return discharge_matrix,true_soc

'''
获取得到每一节电池数据的训练数据集
得到train & test data
'''
def getTrainData(discharge_matrix,true_soc):     
    #循环切片形成数据集
    x=[];y=[]
    x_train=[];y_train=[]
    flag=0

    # 获取得到x,y的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取长度为8的矩阵，叠加循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成4*T的时间维度
            x.append(bataery_data_training.T)
        flag+=1
    #0-》t时刻d x 预测得到t时刻的soc。为了对soc 进行预测，y矩阵为【7：】
    y=true_soc[7:]
#     y=true_capacity[8:]

    VALIDATION_SPLIT=0.9
    x_validation_samples = int( VALIDATION_SPLIT* len(x))
    y_validation_samples = int( VALIDATION_SPLIT*len(y))
    
    
    # 获取得到训练集，验证集，比例9:1
    x_train=np.array(x[:x_validation_samples])
    x_test=np.array(x[x_validation_samples:])
    y_train=np.array(y[:y_validation_samples])
    y_test=np.array(y[y_validation_samples:])
    print("x_train's shape is:", x_train.shape,"，y_train's shape is:",y_train.shape)
    print("x_test's shape is:",x_test.shape,"，y_test's shape is:",y_test.shape)
    return x_train,x_test,y_train,y_test

# %%
# 定义全局变量，将所有电池数据集集合起来，形成训练集，测试集
# x_train_all,x_test_all,y_train_all,y_test_all=[],[],[],[]
for i in range(5,8):
    #/home/aqts/yangHong/battery experiment/jsonData
    discharge=r'/home/aqts/yangHong/battery experiment/jsonData/B000'+str(i)+'_discharge.json'
    discharge_matrix,true_soc=batterydata2matrix(discharge)
    train_x,test_x,train_y,test_y=getTrainData(discharge_matrix,true_soc)
    # start 开始时先赋值给x_train_all，x_test_all，y_train_all，y_test_all
    if i==5:
        x_train_all=train_x
        x_test_all=test_x
        y_train_all=train_y
        y_test_all=test_y
    else:
        x_train_all=np.concatenate((x_train_all,train_x),axis=0)
        x_test_all=np.concatenate((x_test_all,test_x),axis=0)
        y_train_all=np.concatenate((y_train_all,train_y),axis=0)
        y_test_all=np.concatenate((y_test_all,test_y),axis=0)
print(np.array(x_train_all).shape,np.array(x_test_all).shape,np.array(y_train_all).shape,np.array(y_test_all).shape)
# Out:
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 4, 8) ，y_test's shape is: (17,)
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 4, 8) ，y_test's shape is: (17,)
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 4, 8) ，y_test's shape is: (17,)
# (432, 4, 8) (51, 4, 8) (432,) (51,)

# %%
#写一个LossHistory类，保存loss和mae
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as k
import matplotlib.pyplot as plt
import numpy as np
from keras import backend as K
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = {'batch':[], 'epoch':[]}
        self.accuracy = {'batch':[], 'epoch':[]}
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_acc = {'batch':[], 'epoch':[]}

    def on_batch_end(self, batch, logs={}):
        self.losses['batch'].append(logs.get('loss'))
        self.accuracy['batch'].append(logs.get('mean_absolute_error'))
        self.val_loss['batch'].append(logs.get('val_loss'))
        self.val_acc['batch'].append(logs.get('val_mean_absolute_error'))

    def on_epoch_end(self, batch, logs={}):
        self.losses['epoch'].append(logs.get('loss'))
        self.accuracy['epoch'].append(logs.get('mean_absolute_error'))
        self.val_loss['epoch'].append(logs.get('val_loss'))
        self.val_acc['epoch'].append(logs.get('val_mean_absolute_error'))

    def loss_plot(self, loss_type):
        iters = range(len(self.losses[loss_type]))
        plt.figure()
        # mae
        plt.plot(iters, self.accuracy[loss_type], 'r', label='train mae')
        # loss
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        if loss_type == 'epoch':
            # val_mean_absolute_error
            plt.plot(iters, self.val_acc[loss_type], 'b', label='val mean absolute error')
            # val_loss
            plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('mae-loss')
        plt.legend(loc="upper right")
        plt.show()
# Out:
# /home/aqts/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#使用cnn训练的模型
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D,LSTM,GRU
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras import regularizers
from keras.optimizers import SGD, Adam
from keras.layers.normalization import BatchNormalization
from keras.callbacks import EarlyStopping

num=1
img_rows, img_cols =x_train_all.shape[1],x_train_all.shape[2]
if K.image_dim_ordering() == 'th':
    x_train_all = x_train_all.reshape(x_train_all.shape[0], 1, img_rows, img_cols)
    x_test_all = x_test_all.reshape(x_test_all.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train_all = x_train_all.reshape(x_train_all.shape[0], img_rows, img_cols, 1)
    x_test_all= x_test_all.reshape(x_test_all.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)
# print(x_train.shape,x_test.shape)
# print(y_train.shape)
# keras序贯模型搭建CNN
# model building
model = Sequential()
#convolutional layer with rectified linear unit activation
model.add(Conv2D(32, kernel_size=(1,3),
                 activation='relu',
                 input_shape=input_shape,padding="same"))
#32 convolution filters used each of size 3x3
#again
model.add(Conv2D(32, (2,3), activation='relu',padding="same"))
#64 convolution filters used each of size 3x3
#choose the best features via pooling
model.add(MaxPooling2D(pool_size=(2, 2)))

#randomly turn neurons on and off to improve convergence
model.add(Dropout(0.25))
# model.add(BatchNormalization())
#flatten since too many dimensions, we only want a classification output
model.add(Flatten())
#fully connected to get all relevant data
model.add(Dense(64, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.25))

#add LSTM layer
# model.add(GRU(256, dropout=0.2, recurrent_dropout=0.1))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.25))
# model.add(BatchNormalization())
# model.add(Dense(num, activation='sigmoid'))
# The last layer does not use the activation function
model.add(Dense(num))

#Adaptive learning rate (adaDelta) is a popular form of gradient descent rivaled only by adam and adagrad
#categorical ce since we have multiple classes (10) 
# model.compile(loss=keras.losses.sparse_categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])
#回归问题评价指标使用mae
model.compile(loss='mse', optimizer="sgd", metrics=["mae"])


batch_size =16
num_epoch = 80


# decay_rate = learning_rate / num_epoch
# momentum = 0.8
# sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)

# model.compile(loss='mse', optimizer=sgd, metrics=["mae"])
#model training
# early stopping 技术
early_stopping = EarlyStopping(monitor='val_mean_absolute_error', patience=5, verbose=2)
# history = LossHistory()
model.fit(x_train_all, y_train_all,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,validation_split=0.2,callbacks=[history])

mse_score,mae_score= model.evaluate(x_test_all, y_test_all, verbose=0)
print('Test MSE Score:%.3f %%'% (mse_score*100)) 
print('Test MAE Score:%.3f %%'% (mae_score*100))
# Out:
# Train on 345 samples, validate on 87 samples
# Epoch 1/80
# 345/345 [==============================] - 1s 4ms/step - loss: 0.3783 - mean_absolute_error: 0.4584 - val_loss: 0.1647 - val_mean_absolute_error: 0.2259
# Epoch 2/80
# 345/345 [==============================] - 0s 246us/step - loss: 0.1741 - mean_absolute_error: 0.2237 - val_loss: 0.1362 - val_mean_absolute_error: 0.1633
# Epoch 3/80
# 345/345 [==============================] - 0s 247us/step - loss: 0.1539 - mean_absolute_error: 0.1876 - val_loss: 0.1276 - val_mean_absolute_error: 0.1413
# Epoch 4/80
# 345/345 [==============================] - 0s 256us/step - loss: 0.1438 - mean_absolute_error: 0.1707 - val_loss: 0.1205 - val_mean_absolute_error: 0.1209
# Epoch 5/80
# 345/345 [==============================] - 0s 249us/step - loss: 0.1441 - mean_absolute_error: 0.1632 - val_loss: 0.1161 - val_mean_absolute_error: 0.1059
# Epoch 6/80
# 345/345 [==============================] - 0s 250us/step - loss: 0.1343 - mean_absolute_error: 0.1466 - val_loss: 0.1130 - val_mean_absolute_error: 0.0952
# Epoch 7/80
# 345/345 [==============================] - 0s 255us/step - loss: 0.1298 - mean_absolute_error: 0.1333 - val_loss: 0.1093 - val_mean_absolute_error: 0.0803
# Epoch 8/80
# 345/345 [==============================] - 0s 249us/step - loss: 0.1279 - mean_absolute_error: 0.1305 - val_loss: 0.1079 - val_mean_absolute_error: 0.0740
# Epoch 9/80
# 345/345 [==============================] - 0s 254us/step - loss: 0.1191 - mean_absolute_error: 0.1104 - val_loss: 0.1054 - val_mean_absolute_error: 0.0614
# Epoch 10/80
# 345/345 [==============================] - 0s 264us/step - loss: 0.1207 - mean_absolute_error: 0.1159 - val_loss: 0.1042 - val_mean_absolute_error: 0.0544
# Epoch 11/80
# 345/345 [==============================] - 0s 262us/step - loss: 0.1201 - mean_absolute_error: 0.1100 - val_loss: 0.1055 - val_mean_absolute_error: 0.0629
# Epoch 12/80
# 345/345 [==============================] - 0s 252us/step - loss: 0.1178 - mean_absolute_error: 0.1075 - val_loss: 0.1039 - val_mean_absolute_error: 0.0532
# Epoch 13/80
# 345/345 [==============================] - 0s 250us/step - loss: 0.1149 - mean_absolute_error: 0.0958 - val_loss: 0.1037 - val_mean_absolute_error: 0.0529
# Epoch 14/80
# 345/345 [==============================] - 0s 247us/step - loss: 0.1152 - mean_absolute_error: 0.0961 - val_loss: 0.1033 - val_mean_absolute_error: 0.0513
# Epoch 15/80
# 345/345 [==============================] - 0s 258us/step - loss: 0.1121 - mean_absolute_error: 0.0868 - val_loss: 0.1029 - val_mean_absolute_error: 0.0492
# Epoch 16/80
# 345/345 [==============================] - 0s 250us/step - loss: 0.1115 - mean_absolute_error: 0.0835 - val_loss: 0.1026 - val_mean_absolute_error: 0.0476
# Epoch 17/80
# 345/345 [==============================] - 0s 251us/step - loss: 0.1110 - mean_absolute_error: 0.0848 - val_loss: 0.1024 - val_mean_absolute_error: 0.0472
# Epoch 18/80
# 345/345 [==============================] - 0s 251us/step - loss: 0.1087 - mean_absolute_error: 0.0737 - val_loss: 0.1022 - val_mean_absolute_error: 0.0471
# Epoch 19/80
# 345/345 [==============================] - 0s 249us/step - loss: 0.1114 - mean_absolute_error: 0.0853 - val_loss: 0.1021 - val_mean_absolute_error: 0.0481
# Epoch 20/80
# 345/345 [==============================] - 0s 250us/step - loss: 0.1094 - mean_absolute_error: 0.0769 - val_loss: 0.1018 - val_mean_absolute_error: 0.0465
# Epoch 21/80
# 345/345 [==============================] - 0s 260us/step - loss: 0.1080 - mean_absolute_error: 0.0730 - val_loss: 0.1012 - val_mean_absolute_error: 0.0418
# Epoch 22/80
# 345/345 [==============================] - 0s 254us/step - loss: 0.1081 - mean_absolute_error: 0.0754 - val_loss: 0.1013 - val_mean_absolute_error: 0.0440
# Epoch 23/80
# 345/345 [==============================] - 0s 244us/step - loss: 0.1094 - mean_absolute_error: 0.0825 - val_loss: 0.1011 - val_mean_absolute_error: 0.0435
# Epoch 24/80
# 345/345 [==============================] - 0s 257us/step - loss: 0.1078 - mean_absolute_error: 0.0738 - val_loss: 0.1006 - val_mean_absolute_error: 0.0392
# Epoch 25/80
# 345/345 [==============================] - 0s 247us/step - loss: 0.1081 - mean_absolute_error: 0.0772 - val_loss: 0.1012 - val_mean_absolute_error: 0.0467
# Epoch 26/80
# 345/345 [==============================] - 0s 256us/step - loss: 0.1073 - mean_absolute_error: 0.0712 - val_loss: 0.1007 - val_mean_absolute_error: 0.0429
# Epoch 27/80
# 345/345 [==============================] - 0s 270us/step - loss: 0.1055 - mean_absolute_error: 0.0648 - val_loss: 0.1009 - val_mean_absolute_error: 0.0463
# Epoch 28/80
# 345/345 [==============================] - 0s 248us/step - loss: 0.1051 - mean_absolute_error: 0.0637 - val_loss: 0.1005 - val_mean_absolute_error: 0.0424
# Epoch 29/80
# 345/345 [==============================] - 0s 258us/step - loss: 0.1052 - mean_absolute_error: 0.0646 - val_loss: 0.1002 - val_mean_absolute_error: 0.0406
# Epoch 30/80
# 345/345 [==============================] - 0s 245us/step - loss: 0.1044 - mean_absolute_error: 0.0599 - val_loss: 0.1002 - val_mean_absolute_error: 0.0418
# Epoch 31/80
# 345/345 [==============================] - 0s 251us/step - loss: 0.1053 - mean_absolute_error: 0.0656 - val_loss: 0.1000 - val_mean_absolute_error: 0.0408
# Epoch 32/80
# 345/345 [==============================] - 0s 255us/step - loss: 0.1053 - mean_absolute_error: 0.0653 - val_loss: 0.1000 - val_mean_absolute_error: 0.0421
# Epoch 33/80
# 345/345 [==============================] - 0s 251us/step - loss: 0.1043 - mean_absolute_error: 0.0597 - val_loss: 0.0999 - val_mean_absolute_error: 0.0419
# Epoch 34/80
# 345/345 [==============================] - 0s 247us/step - loss: 0.1043 - mean_absolute_error: 0.0614 - val_loss: 0.0995 - val_mean_absolute_error: 0.0384
# Epoch 35/80
# 345/345 [==============================] - 0s 248us/step - loss: 0.1037 - mean_absolute_error: 0.0602 - val_loss: 0.0996 - val_mean_absolute_error: 0.0403
# Epoch 36/80
# 345/345 [==============================] - 0s 255us/step - loss: 0.1039 - mean_absolute_error: 0.0588 - val_loss: 0.0994 - val_mean_absolute_error: 0.0387
# Epoch 37/80
# 345/345 [==============================] - 0s 253us/step - loss: 0.1036 - mean_absolute_error: 0.0597 - val_loss: 0.0993 - val_mean_absolute_error: 0.0381
# Epoch 38/80
# 345/345 [==============================] - 0s 254us/step - loss: 0.1041 - mean_absolute_error: 0.0628 - val_loss: 0.0989 - val_mean_absolute_error: 0.0350
# Epoch 39/80
# 345/345 [==============================] - 0s 242us/step - loss: 0.1032 - mean_absolute_error: 0.0566 - val_loss: 0.0992 - val_mean_absolute_error: 0.0392
# Epoch 40/80
# 345/345 [==============================] - 0s 241us/step - loss: 0.1032 - mean_absolute_error: 0.0578 - val_loss: 0.0990 - val_mean_absolute_error: 0.0381
# Epoch 41/80
# 345/345 [==============================] - 0s 244us/step - loss: 0.1030 - mean_absolute_error: 0.0584 - val_loss: 0.0991 - val_mean_absolute_error: 0.0404
# Epoch 42/80
# 345/345 [==============================] - 0s 260us/step - loss: 0.1021 - mean_absolute_error: 0.0550 - val_loss: 0.0990 - val_mean_absolute_error: 0.0405
# Epoch 43/80
# 345/345 [==============================] - 0s 253us/step - loss: 0.1025 - mean_absolute_error: 0.0567 - val_loss: 0.0989 - val_mean_absolute_error: 0.0402
# Epoch 44/80
# 345/345 [==============================] - 0s 254us/step - loss: 0.1024 - mean_absolute_error: 0.0570 - val_loss: 0.0988 - val_mean_absolute_error: 0.0407
# Epoch 45/80
# 345/345 [==============================] - 0s 251us/step - loss: 0.1022 - mean_absolute_error: 0.0541 - val_loss: 0.0987 - val_mean_absolute_error: 0.0405
# Epoch 46/80
# 345/345 [==============================] - 0s 255us/step - loss: 0.1018 - mean_absolute_error: 0.0542 - val_loss: 0.0984 - val_mean_absolute_error: 0.0380
# Epoch 47/80
# 345/345 [==============================] - 0s 252us/step - loss: 0.1015 - mean_absolute_error: 0.0545 - val_loss: 0.0988 - val_mean_absolute_error: 0.0433
# Epoch 48/80
# 345/345 [==============================] - 0s 249us/step - loss: 0.1021 - mean_absolute_error: 0.0556 - val_loss: 0.0985 - val_mean_absolute_error: 0.0413
# Epoch 49/80
# 345/345 [==============================] - 0s 249us/step - loss: 0.1015 - mean_absolute_error: 0.0541 - val_loss: 0.0984 - val_mean_absolute_error: 0.0410
# Epoch 50/80
# 345/345 [==============================] - 0s 253us/step - loss: 0.1020 - mean_absolute_error: 0.0552 - val_loss: 0.0984 - val_mean_absolute_error: 0.0419
# Epoch 51/80
# 345/345 [==============================] - 0s 250us/step - loss: 0.1008 - mean_absolute_error: 0.0504 - val_loss: 0.0980 - val_mean_absolute_error: 0.0386
# Epoch 52/80
# 345/345 [==============================] - 0s 256us/step - loss: 0.1008 - mean_absolute_error: 0.0521 - val_loss: 0.0984 - val_mean_absolute_error: 0.0441
# Epoch 53/80
# 345/345 [==============================] - 0s 257us/step - loss: 0.1003 - mean_absolute_error: 0.0492 - val_loss: 0.0982 - val_mean_absolute_error: 0.0426
# Epoch 54/80
# 345/345 [==============================] - 0s 253us/step - loss: 0.1000 - mean_absolute_error: 0.0485 - val_loss: 0.0979 - val_mean_absolute_error: 0.0402
# Epoch 55/80
# 345/345 [==============================] - 0s 257us/step - loss: 0.1004 - mean_absolute_error: 0.0517 - val_loss: 0.0979 - val_mean_absolute_error: 0.0412
# Epoch 56/80
# 345/345 [==============================] - 0s 253us/step - loss: 0.1004 - mean_absolute_error: 0.0507 - val_loss: 0.0978 - val_mean_absolute_error: 0.0420
# Epoch 57/80
# 345/345 [==============================] - 0s 247us/step - loss: 0.1000 - mean_absolute_error: 0.0494 - val_loss: 0.0977 - val_mean_absolute_error: 0.0414
# Epoch 58/80
# 345/345 [==============================] - 0s 258us/step - loss: 0.1001 - mean_absolute_error: 0.0498 - val_loss: 0.0972 - val_mean_absolute_error: 0.0366
# Epoch 59/80
# 345/345 [==============================] - 0s 257us/step - loss: 0.0997 - mean_absolute_error: 0.0485 - val_loss: 0.0974 - val_mean_absolute_error: 0.0405
# Epoch 60/80
# 345/345 [==============================] - 0s 248us/step - loss: 0.1001 - mean_absolute_error: 0.0519 - val_loss: 0.0974 - val_mean_absolute_error: 0.0404
# Epoch 61/80
# 345/345 [==============================] - 0s 255us/step - loss: 0.0996 - mean_absolute_error: 0.0481 - val_loss: 0.0970 - val_mean_absolute_error: 0.0371
# Epoch 62/80
# 345/345 [==============================] - 0s 248us/step - loss: 0.0997 - mean_absolute_error: 0.0499 - val_loss: 0.0972 - val_mean_absolute_error: 0.0401
# Epoch 63/80
# 345/345 [==============================] - 0s 257us/step - loss: 0.0992 - mean_absolute_error: 0.0468 - val_loss: 0.0972 - val_mean_absolute_error: 0.0412
# Epoch 64/80
# 345/345 [==============================] - 0s 244us/step - loss: 0.0996 - mean_absolute_error: 0.0510 - val_loss: 0.0973 - val_mean_absolute_error: 0.0441
# Epoch 65/80
# 345/345 [==============================] - 0s 262us/step - loss: 0.0993 - mean_absolute_error: 0.0482 - val_loss: 0.0970 - val_mean_absolute_error: 0.0413
# Epoch 66/80
# 345/345 [==============================] - 0s 255us/step - loss: 0.0990 - mean_absolute_error: 0.0470 - val_loss: 0.0970 - val_mean_absolute_error: 0.0424
# Epoch 67/80
# 345/345 [==============================] - 0s 252us/step - loss: 0.0987 - mean_absolute_error: 0.0470 - val_loss: 0.0970 - val_mean_absolute_error: 0.0431
# Epoch 68/80
# 345/345 [==============================] - 0s 251us/step - loss: 0.0991 - mean_absolute_error: 0.0488 - val_loss: 0.0969 - val_mean_absolute_error: 0.0434
# Epoch 69/80
# 345/345 [==============================] - 0s 248us/step - loss: 0.0984 - mean_absolute_error: 0.0457 - val_loss: 0.0968 - val_mean_absolute_error: 0.0433
# Epoch 70/80
# 345/345 [==============================] - 0s 254us/step - loss: 0.0986 - mean_absolute_error: 0.0477 - val_loss: 0.0968 - val_mean_absolute_error: 0.0440
# Epoch 71/80
# 345/345 [==============================] - 0s 249us/step - loss: 0.0983 - mean_absolute_error: 0.0476 - val_loss: 0.0965 - val_mean_absolute_error: 0.0410
# Epoch 72/80
# 345/345 [==============================] - 0s 258us/step - loss: 0.0983 - mean_absolute_error: 0.0475 - val_loss: 0.0960 - val_mean_absolute_error: 0.0364
# Epoch 73/80
# 345/345 [==============================] - 0s 250us/step - loss: 0.0983 - mean_absolute_error: 0.0474 - val_loss: 0.0961 - val_mean_absolute_error: 0.0385
# Epoch 74/80
# 345/345 [==============================] - 0s 258us/step - loss: 0.0980 - mean_absolute_error: 0.0455 - val_loss: 0.0961 - val_mean_absolute_error: 0.0399
# Epoch 75/80
# 345/345 [==============================] - 0s 258us/step - loss: 0.0981 - mean_absolute_error: 0.0466 - val_loss: 0.0961 - val_mean_absolute_error: 0.0409
# Epoch 76/80
# 345/345 [==============================] - 0s 256us/step - loss: 0.0981 - mean_absolute_error: 0.0480 - val_loss: 0.0958 - val_mean_absolute_error: 0.0379
# Epoch 77/80
# 345/345 [==============================] - 0s 255us/step - loss: 0.0977 - mean_absolute_error: 0.0451 - val_loss: 0.0959 - val_mean_absolute_error: 0.0407
# Epoch 78/80
# 345/345 [==============================] - 0s 252us/step - loss: 0.0978 - mean_absolute_error: 0.0445 - val_loss: 0.0958 - val_mean_absolute_error: 0.0403
# Epoch 79/80
# 345/345 [==============================] - 0s 256us/step - loss: 0.0977 - mean_absolute_error: 0.0463 - val_loss: 0.0959 - val_mean_absolute_error: 0.0427
# Epoch 80/80
# 345/345 [==============================] - 0s 246us/step - loss: 0.0973 - mean_absolute_error: 0.0439 - val_loss: 0.0957 - val_mean_absolute_error: 0.0413
# Test MSE Score:9.743 %
# Test MAE Score:4.641 %

# %%
#绘制mae-loss曲线
history.loss_plot('epoch')

# %% [markdown]
# 获取得到需要用于预测的电池数据集B0018号电池

# %%
# 获取预测所需的电池数据集
def getBattery008data(discharge_matrix):
    x_pred=[]
    flag=0

    # 获取得到x_pred的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取0--37这段的长度，叠加+1循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成3*T的时间维度
            x_pred.append(bataery_data_training.T)
        flag+=1

    x_pred=np.array(x_pred)
    return x_pred

# return prediction  data &  prediction  data true_so
discharge_008=r'/home/aqts/yangHong/battery experiment/jsonData/B0008_discharge.json'
# 获取得到一节电池的 特征向量 与true soc 
discharge_matrix_008,true_soc_008 =batterydata2matrix(discharge_008)
# 得到预测样本集 t=7
x_test_008=getBattery008data(discharge_matrix_008)


print("x_test_008 data shape is",x_test_008.shape)
# 预测数据集进行转换
if K.image_dim_ordering() == 'th':
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], img_rows, img_cols,1)
    input_shape = (img_rows, img_cols, 1)
# Out:
# x_test_008 data shape is (125, 4, 8)

# %%
pred=model.predict(x_test_008, batch_size=16, verbose=0)
print(pred.shape)
# Out:
# (125, 1)

# %%
import pandas as pd # 导入pandas库用来处理csv文件
import matplotlib.pyplot as plt # 导入matplotlib.pyplot并用plt简称

# true soc predict plot
x_true_soc=range(len(true_soc_008))
# 切割开始的基数一定为7
start=6
x_test_soc_008=range(start,start+pred.shape[0])
print("x_true_soc range is ",x_true_soc,"\n x_test_soc_008  range is:",x_test_soc_008)
plt.plot(x_true_soc, true_soc_008, linewidth=2.0, color='r',label="True SOC")#线的宽度为2.0，颜色为红色
plt.plot(x_test_soc_008, pred, linewidth=2.0, color='g',label="Prediction SOC")#线的宽度为2.0，颜色为绿色


# 设置x ,y轴的步长与刻度属性
plt.xticks([x for x in range(len(x_true_soc) + 1) if x %10 == 0])  # x标记step设置为10
plt.ylim(ymin=0.3,ymax=1.1)
# remark for x & y
plt.xlabel('Cylce')
plt.ylabel('SOC')
plt.title('Real Soc and Predicted Soc')

plt.legend()
plt.show()#显示图像
# Out:
# x_true_soc range is  range(0, 132)
#  x_test_soc_008  range is: range(6, 131)
