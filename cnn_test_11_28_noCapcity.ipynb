# %% [markdown]
# battery json data  convert to matrix and input to CNN for train，没有容量特征字段

# %%
from sklearn import preprocessing 
from scipy.io import loadmat, whosmat
import numpy as np
import datetime
import json
import os
# 获取得到 json data of battery 
def json_load(dictonary):
    with open(dictonary) as f:
        data = json.load(f)
    return data

'''
cycle为行数，循环读取一行数据，对一行数据里面的voltage,current and temp求均值，并添加capacity features
得到battery array
'''
def batteryData2array(battery_data):
    vol_sum = 0
    cur_sum = 0
    temp_sum=0
    battery_array = []
    for cycle in battery_data.keys():
        # list type 
        battery_vols = battery_data[cycle]["voltage_battery"]
        battery_curs = battery_data[cycle]["current_battery"]
        battery_temps=battery_data[cycle]["temp_battery"]
        battery_capacity=battery_data[cycle]["Capacity"]
        for battery_vol in battery_vols:
            vol_sum += float(battery_vol)
        for battery_cur in battery_curs:
            cur_sum += float(battery_cur)
        for battery_temp in battery_temps:
            temp_sum += float(battery_temp)
        #for voltage and current average  & battery_vols,battery_curs,battery_temps's len is equal
        num = len(battery_vols)
        vol_aver = vol_sum / num
        cur_aver = cur_sum / num
        temp_aver=temp_sum/num
        vol_sum = 0
        cur_sum = 0
        temp_sum=0
        battery_array.append([vol_aver,cur_aver,temp_aver])
#         battery_array.append([vol_aver,cur_aver,battery_capacity[0]])
    return battery_array

# get battery's true soc
def  getTrueSOC(battery_discharge_data):
    batteryCapcity=2
    soc_dict=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        soc_true=cycleCapacity[0]/batteryCapcity
        soc_dict.append(soc_true)
    return soc_dict

# get battery's discgarge capacity
def  getTrueCapacity(battery_discharge_data):
    capacity=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        capacity.append(cycleCapacity[0])
    return capacity

'''
获取得到 battery 's img matrix 图像矩阵  4维特征向量  vol_aver,cur_aver,temp_aver,battery_capacity
返回battery discharge matrix and true soc array
'''
def batterydata2matrix(discharge):
    #get the discharge and charge json data
    discharge_data =json_load(discharge)
    
    #get the true soc data
    true_soc=getTrueSOC(discharge_data)
#   true_capacity=getTrueCapacity(discharge_data)
    #get the battery discharge array data  convert to matrix
    discharge_array = batteryData2array(discharge_data)
    discharge_matrix = np.array(discharge_array)

    discharge_matrix=preprocessing.scale(discharge_matrix)
    return discharge_matrix,true_soc

'''
获取得到每一节电池数据的训练数据集
得到train & test data
'''
def getTrainData(discharge_matrix,true_soc):     
    #循环切片形成数据集
    x=[];y=[]
    x_train=[];y_train=[]
    flag=0

    # 获取得到x,y的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取长度为8的矩阵，叠加循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成4*T的时间维度
            x.append(bataery_data_training.T)
        flag+=1
    #0-》t时刻d x 预测得到t时刻的soc。为了对soc 进行预测，y矩阵为【7：】
    y=true_soc[7:]
#     y=true_capacity[8:]

    VALIDATION_SPLIT=0.9
    x_validation_samples = int( VALIDATION_SPLIT* len(x))
    y_validation_samples = int( VALIDATION_SPLIT*len(y))
    
    
    # 获取得到训练集，验证集，比例9:1
    x_train=np.array(x[:x_validation_samples])
    x_test=np.array(x[x_validation_samples:])
    y_train=np.array(y[:y_validation_samples])
    y_test=np.array(y[y_validation_samples:])
    print("x_train's shape is:", x_train.shape,"，y_train's shape is:",y_train.shape)
    print("x_test's shape is:",x_test.shape,"，y_test's shape is:",y_test.shape)
    return x_train,x_test,y_train,y_test

# %%
# 定义全局变量，将所有电池数据集集合起来，形成训练集，测试集
# x_train_all,x_test_all,y_train_all,y_test_all=[],[],[],[]
for i in range(5,8):
    #/home/aqts/yangHong/battery experiment/jsonData
    discharge=r'/home/aqts/yangHong/battery experiment/jsonData/B000'+str(i)+'_discharge.json'
    discharge_matrix,true_soc=batterydata2matrix(discharge)
    train_x,test_x,train_y,test_y=getTrainData(discharge_matrix,true_soc)
    # start 开始时先赋值给x_train_all，x_test_all，y_train_all，y_test_all
    if i==5:
        x_train_all=train_x
        x_test_all=test_x
        y_train_all=train_y
        y_test_all=test_y
    else:
        x_train_all=np.concatenate((x_train_all,train_x),axis=0)
        x_test_all=np.concatenate((x_test_all,test_x),axis=0)
        y_train_all=np.concatenate((y_train_all,train_y),axis=0)
        y_test_all=np.concatenate((y_test_all,test_y),axis=0)
print(np.array(x_train_all).shape,np.array(x_test_all).shape,np.array(y_train_all).shape,np.array(y_test_all).shape)
# Out:
# x_train's shape is: (144, 3, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 3, 8) ，y_test's shape is: (17,)
# x_train's shape is: (144, 3, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 3, 8) ，y_test's shape is: (17,)
# x_train's shape is: (144, 3, 8) ，y_train's shape is: (144,)
# x_test's shape is: (17, 3, 8) ，y_test's shape is: (17,)
# (432, 3, 8) (51, 3, 8) (432,) (51,)

# %%
#写一个LossHistory类，保存loss和mae
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as k
import matplotlib.pyplot as plt
import numpy as np
from keras import backend as K
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = {'batch':[], 'epoch':[]}
        self.accuracy = {'batch':[], 'epoch':[]}
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_acc = {'batch':[], 'epoch':[]}

    def on_batch_end(self, batch, logs={}):
        self.losses['batch'].append(logs.get('loss'))
        self.accuracy['batch'].append(logs.get('mean_absolute_error'))
        self.val_loss['batch'].append(logs.get('val_loss'))
        self.val_acc['batch'].append(logs.get('val_mean_absolute_error'))

    def on_epoch_end(self, batch, logs={}):
        self.losses['epoch'].append(logs.get('loss'))
        self.accuracy['epoch'].append(logs.get('mean_absolute_error'))
        self.val_loss['epoch'].append(logs.get('val_loss'))
        self.val_acc['epoch'].append(logs.get('val_mean_absolute_error'))

    def loss_plot(self, loss_type):
        iters = range(len(self.losses[loss_type]))
        plt.figure()
        # mae
        plt.plot(iters, self.accuracy[loss_type], 'r', label='train mae')
        # loss
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        if loss_type == 'epoch':
            # val_mean_absolute_error
            plt.plot(iters, self.val_acc[loss_type], 'b', label='val mean absolute error')
            # val_loss
            plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('mae-loss')
        plt.legend(loc="upper right")
        plt.show()
# Out:
# /home/aqts/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# 基于序贯(Sequential)编程方式的模型

# %% [markdown]
# 将CNN模型使用函数式编程的模式

# %%
# keras 函数时搭建cnn模型
# model building
#使用cnn训练的模型
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D,GRU,LSTM
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras import regularizers
from keras.optimizers import SGD, Adam
from keras.layers.normalization import BatchNormalization
import tensorflow as tf
from keras.layers.noise import GaussianNoise
# 引用GPU命令
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

num=1
img_rows, img_cols =x_train_all.shape[1],x_train_all.shape[2]
if K.image_dim_ordering() == 'th':
    x_train_all = x_train_all.reshape(x_train_all.shape[0], 1, img_rows, img_cols)
    x_test_all = x_test_all.reshape(x_test_all.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train_all = x_train_all.reshape(x_train_all.shape[0], img_rows, img_cols, 1)
    x_test_all= x_test_all.reshape(x_test_all.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)


# lstm_input_shape=(nb_time_steps, nb_input_vector)
cnn_main_input = Input(shape=input_shape, dtype='float32')
# lstm_main_input = Input(shape=lstm_input_shape, dtype='float32')
#convolutional layer with rectified linear unit activation
cnn=Conv2D(32, kernel_size=(1,2),
                 activation='relu',
                 input_shape=input_shape,padding="same")(cnn_main_input)
cnn=Conv2D(64, (2,2), activation='relu',padding="same")(cnn)
cnn=Conv2D(128, (3,3), activation='relu',padding="same")(cnn)

# cnn=Conv2D(32, (2,1), activation='relu',padding="same")(cnn)

# cnn=Conv2D(64, (2,2), activation='relu',padding="same")(cnn)
cnn=MaxPooling2D(pool_size=(2, 2))(cnn)
cnn=Dropout(0.25)(cnn)
# cnn=MaxPooling2D(pool_size=(2, 2))(cnn)
# cnn=Conv2D(64, (2,1), activation='relu',padding="same")(cnn)
cnn=Flatten()(cnn)
# cnn=Dense(8, activation='relu',kernel_regularizer=regularizers.l2(0.001))(cnn)
# cnn=Dropout(0.15)(cnn)

cnn=Dense(16, activation='relu')(cnn)
cnn=Dropout(0.10)(cnn)

# rnn=LSTM(units=nb_lstm_outputs,dropout=0.4, recurrent_dropout=0.1,return_sequences=True)(lstm_main_input)
# rnn=LSTM(64, dropout=0.4, recurrent_dropout=0.1)(rnn)

# # two model connection
# con = concatenate([cnn,rnn], axis=-1)
main_output = Dense(num,activation="linear")(cnn)
sgd = SGD(lr=0.0001, decay=1e-7, momentum=0.90, nesterov=False)
model = Model(inputs = cnn_main_input, outputs = main_output)
model.compile(loss='mse', optimizer=sgd, metrics=["mae"])


batch_size =16
num_epoch = 64


model.summary()
# decay_rate = learning_rate / num_epoch
# momentum = 0.8
# sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)

# model.compile(loss='mse', optimizer=sgd, metrics=["mae"])
#model training
history = LossHistory()
model.fit(x_train_all, y_train_all,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,validation_data=(x_test_all,y_test_all),callbacks=[history])

mse_score,mae_score= model.evaluate(x_test_all, y_test_all, verbose=0)
print('Test MSE Score:%.3f %%'% (mse_score*100)) 
print('Test MAE Score:%.3f %%'% (mae_score*100))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_30 (InputLayer)        (None, 3, 8, 1)           0
# _________________________________________________________________
# conv2d_92 (Conv2D)           (None, 3, 8, 32)          96
# _________________________________________________________________
# conv2d_93 (Conv2D)           (None, 3, 8, 64)          8256
# _________________________________________________________________
# conv2d_94 (Conv2D)           (None, 3, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 1, 4, 128)         0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 1, 4, 128)         0
# _________________________________________________________________
# flatten_30 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 16)                8208
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_41 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 90,433
# Trainable params: 90,433
# Non-trainable params: 0
# _________________________________________________________________
# Train on 432 samples, validate on 51 samples
# Epoch 1/64
# 432/432 [==============================] - 2s 4ms/step - loss: 0.6346 - mean_absolute_error: 0.7914 - val_loss: 0.4426 - val_mean_absolute_error: 0.6631
# Epoch 2/64
# 432/432 [==============================] - 0s 342us/step - loss: 0.4165 - mean_absolute_error: 0.6378 - val_loss: 0.2748 - val_mean_absolute_error: 0.5230
# Epoch 3/64
# 432/432 [==============================] - 0s 347us/step - loss: 0.2567 - mean_absolute_error: 0.4857 - val_loss: 0.1456 - val_mean_absolute_error: 0.3803
# Epoch 4/64
# 432/432 [==============================] - 0s 322us/step - loss: 0.1541 - mean_absolute_error: 0.3628 - val_loss: 0.0716 - val_mean_absolute_error: 0.2657
# Epoch 5/64
# 432/432 [==============================] - 0s 349us/step - loss: 0.1123 - mean_absolute_error: 0.3021 - val_loss: 0.0354 - val_mean_absolute_error: 0.1855
# Epoch 6/64
# 432/432 [==============================] - 0s 359us/step - loss: 0.0908 - mean_absolute_error: 0.2646 - val_loss: 0.0173 - val_mean_absolute_error: 0.1272
# Epoch 7/64
# 432/432 [==============================] - 0s 353us/step - loss: 0.0733 - mean_absolute_error: 0.2379 - val_loss: 0.0084 - val_mean_absolute_error: 0.0846
# Epoch 8/64
# 432/432 [==============================] - 0s 336us/step - loss: 0.0638 - mean_absolute_error: 0.2149 - val_loss: 0.0044 - val_mean_absolute_error: 0.0551
# Epoch 9/64
# 432/432 [==============================] - 0s 364us/step - loss: 0.0665 - mean_absolute_error: 0.2176 - val_loss: 0.0024 - val_mean_absolute_error: 0.0371
# Epoch 10/64
# 432/432 [==============================] - 0s 344us/step - loss: 0.0558 - mean_absolute_error: 0.1950 - val_loss: 0.0016 - val_mean_absolute_error: 0.0319
# Epoch 11/64
# 432/432 [==============================] - 0s 364us/step - loss: 0.0535 - mean_absolute_error: 0.1889 - val_loss: 0.0015 - val_mean_absolute_error: 0.0335
# Epoch 12/64
# 432/432 [==============================] - 0s 349us/step - loss: 0.0496 - mean_absolute_error: 0.1813 - val_loss: 0.0017 - val_mean_absolute_error: 0.0363
# Epoch 13/64
# 432/432 [==============================] - 0s 357us/step - loss: 0.0499 - mean_absolute_error: 0.1814 - val_loss: 0.0022 - val_mean_absolute_error: 0.0406
# Epoch 14/64
# 432/432 [==============================] - 0s 353us/step - loss: 0.0458 - mean_absolute_error: 0.1707 - val_loss: 0.0029 - val_mean_absolute_error: 0.0461
# Epoch 15/64
# 432/432 [==============================] - 0s 327us/step - loss: 0.0402 - mean_absolute_error: 0.1648 - val_loss: 0.0041 - val_mean_absolute_error: 0.0547
# Epoch 16/64
# 432/432 [==============================] - 0s 353us/step - loss: 0.0398 - mean_absolute_error: 0.1596 - val_loss: 0.0046 - val_mean_absolute_error: 0.0584
# Epoch 17/64
# 432/432 [==============================] - 0s 346us/step - loss: 0.0399 - mean_absolute_error: 0.1612 - val_loss: 0.0053 - val_mean_absolute_error: 0.0628
# Epoch 18/64
# 432/432 [==============================] - 0s 355us/step - loss: 0.0367 - mean_absolute_error: 0.1533 - val_loss: 0.0058 - val_mean_absolute_error: 0.0666
# Epoch 19/64
# 432/432 [==============================] - 0s 338us/step - loss: 0.0348 - mean_absolute_error: 0.1508 - val_loss: 0.0062 - val_mean_absolute_error: 0.0688
# Epoch 20/64
# 432/432 [==============================] - 0s 360us/step - loss: 0.0354 - mean_absolute_error: 0.1484 - val_loss: 0.0065 - val_mean_absolute_error: 0.0711
# Epoch 21/64
# 432/432 [==============================] - 0s 356us/step - loss: 0.0371 - mean_absolute_error: 0.1490 - val_loss: 0.0068 - val_mean_absolute_error: 0.0731
# Epoch 22/64
# 432/432 [==============================] - 0s 326us/step - loss: 0.0298 - mean_absolute_error: 0.1384 - val_loss: 0.0081 - val_mean_absolute_error: 0.0808
# Epoch 23/64
# 432/432 [==============================] - 0s 358us/step - loss: 0.0254 - mean_absolute_error: 0.1295 - val_loss: 0.0086 - val_mean_absolute_error: 0.0837
# Epoch 24/64
# 432/432 [==============================] - 0s 354us/step - loss: 0.0339 - mean_absolute_error: 0.1442 - val_loss: 0.0089 - val_mean_absolute_error: 0.0851
# Epoch 25/64
# 432/432 [==============================] - 0s 373us/step - loss: 0.0335 - mean_absolute_error: 0.1445 - val_loss: 0.0093 - val_mean_absolute_error: 0.0874
# Epoch 26/64
# 432/432 [==============================] - 0s 350us/step - loss: 0.0307 - mean_absolute_error: 0.1377 - val_loss: 0.0096 - val_mean_absolute_error: 0.0894
# Epoch 27/64
# 432/432 [==============================] - 0s 341us/step - loss: 0.0282 - mean_absolute_error: 0.1331 - val_loss: 0.0098 - val_mean_absolute_error: 0.0900
# Epoch 28/64
# 432/432 [==============================] - 0s 327us/step - loss: 0.0319 - mean_absolute_error: 0.1442 - val_loss: 0.0099 - val_mean_absolute_error: 0.0905
# Epoch 29/64
# 432/432 [==============================] - 0s 373us/step - loss: 0.0296 - mean_absolute_error: 0.1346 - val_loss: 0.0100 - val_mean_absolute_error: 0.0912
# Epoch 30/64
# 432/432 [==============================] - 0s 368us/step - loss: 0.0269 - mean_absolute_error: 0.1256 - val_loss: 0.0102 - val_mean_absolute_error: 0.0926
# Epoch 31/64
# 432/432 [==============================] - 0s 343us/step - loss: 0.0291 - mean_absolute_error: 0.1326 - val_loss: 0.0102 - val_mean_absolute_error: 0.0926
# Epoch 32/64
# 432/432 [==============================] - 0s 369us/step - loss: 0.0277 - mean_absolute_error: 0.1277 - val_loss: 0.0097 - val_mean_absolute_error: 0.0896
# Epoch 33/64
# 432/432 [==============================] - 0s 328us/step - loss: 0.0239 - mean_absolute_error: 0.1217 - val_loss: 0.0099 - val_mean_absolute_error: 0.0908
# Epoch 34/64
# 432/432 [==============================] - 0s 368us/step - loss: 0.0241 - mean_absolute_error: 0.1204 - val_loss: 0.0101 - val_mean_absolute_error: 0.0920
# Epoch 35/64
# 432/432 [==============================] - 0s 355us/step - loss: 0.0235 - mean_absolute_error: 0.1195 - val_loss: 0.0103 - val_mean_absolute_error: 0.0930
# Epoch 36/64
# 432/432 [==============================] - 0s 330us/step - loss: 0.0247 - mean_absolute_error: 0.1246 - val_loss: 0.0100 - val_mean_absolute_error: 0.0913
# Epoch 37/64
# 432/432 [==============================] - 0s 351us/step - loss: 0.0237 - mean_absolute_error: 0.1212 - val_loss: 0.0101 - val_mean_absolute_error: 0.0918
# Epoch 38/64
# 432/432 [==============================] - 0s 336us/step - loss: 0.0215 - mean_absolute_error: 0.1167 - val_loss: 0.0103 - val_mean_absolute_error: 0.0927
# Epoch 39/64
# 432/432 [==============================] - 0s 347us/step - loss: 0.0258 - mean_absolute_error: 0.1224 - val_loss: 0.0104 - val_mean_absolute_error: 0.0931
# Epoch 40/64
# 432/432 [==============================] - 0s 336us/step - loss: 0.0292 - mean_absolute_error: 0.1306 - val_loss: 0.0103 - val_mean_absolute_error: 0.0925
# Epoch 41/64
# 432/432 [==============================] - 0s 350us/step - loss: 0.0205 - mean_absolute_error: 0.1094 - val_loss: 0.0094 - val_mean_absolute_error: 0.0878
# Epoch 42/64
# 432/432 [==============================] - 0s 342us/step - loss: 0.0236 - mean_absolute_error: 0.1190 - val_loss: 0.0095 - val_mean_absolute_error: 0.0884
# Epoch 43/64
# 432/432 [==============================] - 0s 344us/step - loss: 0.0207 - mean_absolute_error: 0.1118 - val_loss: 0.0092 - val_mean_absolute_error: 0.0865
# Epoch 44/64
# 432/432 [==============================] - 0s 346us/step - loss: 0.0189 - mean_absolute_error: 0.1068 - val_loss: 0.0090 - val_mean_absolute_error: 0.0850
# Epoch 45/64
# 432/432 [==============================] - 0s 359us/step - loss: 0.0222 - mean_absolute_error: 0.1122 - val_loss: 0.0091 - val_mean_absolute_error: 0.0858
# Epoch 46/64
# 432/432 [==============================] - 0s 349us/step - loss: 0.0228 - mean_absolute_error: 0.1169 - val_loss: 0.0090 - val_mean_absolute_error: 0.0854
# Epoch 47/64
# 432/432 [==============================] - 0s 334us/step - loss: 0.0203 - mean_absolute_error: 0.1100 - val_loss: 0.0086 - val_mean_absolute_error: 0.0830
# Epoch 48/64
# 432/432 [==============================] - 0s 356us/step - loss: 0.0196 - mean_absolute_error: 0.1059 - val_loss: 0.0081 - val_mean_absolute_error: 0.0800
# Epoch 49/64
# 432/432 [==============================] - 0s 361us/step - loss: 0.0205 - mean_absolute_error: 0.1101 - val_loss: 0.0080 - val_mean_absolute_error: 0.0794
# Epoch 50/64
# 432/432 [==============================] - 0s 370us/step - loss: 0.0189 - mean_absolute_error: 0.1032 - val_loss: 0.0079 - val_mean_absolute_error: 0.0785
# Epoch 51/64
# 432/432 [==============================] - 0s 355us/step - loss: 0.0219 - mean_absolute_error: 0.1147 - val_loss: 0.0080 - val_mean_absolute_error: 0.0789
# Epoch 52/64
# 432/432 [==============================] - 0s 365us/step - loss: 0.0223 - mean_absolute_error: 0.1108 - val_loss: 0.0077 - val_mean_absolute_error: 0.0771
# Epoch 53/64
# 432/432 [==============================] - 0s 339us/step - loss: 0.0174 - mean_absolute_error: 0.1035 - val_loss: 0.0076 - val_mean_absolute_error: 0.0764
# Epoch 54/64
# 432/432 [==============================] - 0s 349us/step - loss: 0.0210 - mean_absolute_error: 0.1084 - val_loss: 0.0075 - val_mean_absolute_error: 0.0761
# Epoch 55/64
# 432/432 [==============================] - 0s 356us/step - loss: 0.0185 - mean_absolute_error: 0.1078 - val_loss: 0.0079 - val_mean_absolute_error: 0.0782
# Epoch 56/64
# 432/432 [==============================] - 0s 333us/step - loss: 0.0183 - mean_absolute_error: 0.1042 - val_loss: 0.0076 - val_mean_absolute_error: 0.0761
# Epoch 57/64
# 432/432 [==============================] - 0s 366us/step - loss: 0.0191 - mean_absolute_error: 0.1063 - val_loss: 0.0074 - val_mean_absolute_error: 0.0753
# Epoch 58/64
# 432/432 [==============================] - 0s 366us/step - loss: 0.0193 - mean_absolute_error: 0.1036 - val_loss: 0.0071 - val_mean_absolute_error: 0.0728
# Epoch 59/64
# 432/432 [==============================] - 0s 351us/step - loss: 0.0140 - mean_absolute_error: 0.0896 - val_loss: 0.0068 - val_mean_absolute_error: 0.0711
# Epoch 60/64
# 432/432 [==============================] - 0s 346us/step - loss: 0.0152 - mean_absolute_error: 0.0952 - val_loss: 0.0068 - val_mean_absolute_error: 0.0711
# Epoch 61/64
# 432/432 [==============================] - 0s 344us/step - loss: 0.0163 - mean_absolute_error: 0.0959 - val_loss: 0.0069 - val_mean_absolute_error: 0.0718
# Epoch 62/64
# 432/432 [==============================] - 0s 358us/step - loss: 0.0165 - mean_absolute_error: 0.0958 - val_loss: 0.0071 - val_mean_absolute_error: 0.0730
# Epoch 63/64
# 432/432 [==============================] - 0s 378us/step - loss: 0.0159 - mean_absolute_error: 0.0973 - val_loss: 0.0069 - val_mean_absolute_error: 0.0715
# Epoch 64/64
# 432/432 [==============================] - 0s 333us/step - loss: 0.0181 - mean_absolute_error: 0.1000 - val_loss: 0.0068 - val_mean_absolute_error: 0.0707
# Test MSE Score:0.681 %
# Test MAE Score:7.068 %

# %%
#绘制mae-loss曲线
history.loss_plot('epoch')
# input_shape[]

# %% [markdown]
# 获取得到需要用于预测的电池数据集B0018号电池

# %%
# 获取预测所需的电池数据集
def getBattery008data(discharge_matrix):
    x_pred=[]
    flag=0

    # 获取得到x_pred的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取0--37这段的长度，叠加+1循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成3*T的时间维度
            x_pred.append(bataery_data_training.T)
        flag+=1

    x_pred=np.array(x_pred[:len(x_pred)-1])
    return x_pred

# return prediction  data &  prediction  data true_so
discharge_008=r'/home/aqts/yangHong/battery experiment/jsonData/B0008_discharge.json'
# 获取得到一节电池的 特征向量 与true soc 
discharge_matrix_008,true_soc_008 =batterydata2matrix(discharge_008)
# 得到预测样本集 t=7
x_test_008=getBattery008data(discharge_matrix_008)


print("x_test_008 data shape is",x_test_008.shape)
# 预测数据集进行转换
if K.image_dim_ordering() == 'th':
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], img_rows, img_cols,1)
    input_shape = (img_rows, img_cols, 1)
# Out:
# x_test_008 data shape is (124, 3, 8)

# %%
pred=model.predict(x_test_008, batch_size=16, verbose=0)
print(pred.shape)
# Out:
# (124, 1)

# %%
import pandas as pd # 导入pandas库用来处理csv文件
import matplotlib.pyplot as plt # 导入matplotlib.pyplot并用plt简称

# true soc predict plot
x_true_soc=range(len(true_soc_008))
# 切割开始的基数一定为7
start=8
x_test_soc_008=range(start,start+pred.shape[0])
print("x_true_soc range is ",x_true_soc,"\n x_test_soc_008  range is:",x_test_soc_008)
plt.plot(x_true_soc, true_soc_008, linewidth=2.0, color='r',label="True SOC")#线的宽度为2.0，颜色为红色
plt.plot(x_test_soc_008, pred, linewidth=2.0, color='g',label="Prediction SOC")#线的宽度为2.0，颜色为绿色


# 设置x ,y轴的步长与刻度属性
plt.xticks([x for x in range(len(x_true_soc) + 1) if x %10 == 0])  # x标记step设置为10
plt.ylim(ymin=0.3,ymax=1.1)
# remark for x & y
plt.xlabel('Cylce')
plt.ylabel('SOC')
plt.title('Real Soc and Predicted Soc')

plt.legend()
plt.show()#显示图像
# Out:
# x_true_soc range is  range(0, 132)
#  x_test_soc_008  range is: range(8, 132)
