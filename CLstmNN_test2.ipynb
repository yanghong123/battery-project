# %% [markdown]
# battery json data  convert to matrix and input to CNN for train，没有容量特征字段

# %%
from sklearn import preprocessing 
from scipy.io import loadmat, whosmat
import numpy as np
import datetime
import json
import os
# 获取得到 json data of battery 
def json_load(dictonary):
    with open(dictonary) as f:
        data = json.load(f)
    return data

'''
cycle为行数，循环读取一行数据，对一行数据里面的voltage,current and temp求均值，并添加capacity features
得到battery array
'''
def batteryData2array(battery_data):
    vol_sum = 0
    cur_sum = 0
    temp_sum=0
    battery_array = []
    for cycle in battery_data.keys():
        # list type 
        battery_vols = battery_data[cycle]["voltage_battery"]
        battery_curs = battery_data[cycle]["current_battery"]
        battery_temps=battery_data[cycle]["temp_battery"]
        battery_capacity=battery_data[cycle]["Capacity"]
        for battery_vol in battery_vols:
            vol_sum += float(battery_vol)
        for battery_cur in battery_curs:
            cur_sum += float(battery_cur)
        for battery_temp in battery_temps:
            temp_sum += float(battery_temp)
        #for voltage and current average  & battery_vols,battery_curs,battery_temps's len is equal
        num = len(battery_vols)
        vol_aver = vol_sum / num
        cur_aver = cur_sum / num
        temp_aver=temp_sum/num
        vol_sum = 0
        cur_sum = 0
        temp_sum=0
        battery_array.append([vol_aver,cur_aver,temp_aver])
#         battery_array.append([vol_aver,cur_aver,battery_capacity[0]])
    return battery_array

# get battery's true soc
def  getTrueSOC(battery_discharge_data):
    batteryCapcity=2
    soc_dict=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        soc_true=cycleCapacity[0]/batteryCapcity
        soc_dict.append(soc_true)
    return soc_dict

# get battery's discgarge capacity
def  getTrueCapacity(battery_discharge_data):
    capacity=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        capacity.append(cycleCapacity[0])
    return capacity

'''
获取得到 battery 's img matrix 图像矩阵  4维特征向量  vol_aver,cur_aver,temp_aver,battery_capacity
返回battery discharge matrix and true soc array
'''
def batterydata2matrix(discharge):
    #get the discharge and charge json data
    discharge_data =json_load(discharge)
    
    #get the true soc data
    true_soc=getTrueSOC(discharge_data)
#   true_capacity=getTrueCapacity(discharge_data)
    #get the battery discharge array data  convert to matrix
    discharge_array = batteryData2array(discharge_data)
    discharge_matrix = np.array(discharge_array)

    discharge_matrix=preprocessing.scale(discharge_matrix)
    return discharge_matrix,true_soc

'''
获取得到每一节电池数据的训练数据集
得到train & test data
'''
def getTrainData(discharge_matrix,true_soc):     
    #循环切片形成数据集
    x=[];y=[]
    x_train=[];y_train=[]
    flag=0

    # 获取得到x,y的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取长度为8的矩阵，叠加循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成4*T的时间维度
            x.append(bataery_data_training.T)
        flag+=1
    #0-》t时刻d x 预测得到t时刻的soc。为了对soc 进行预测，y矩阵为【7：】
    y=true_soc[8:]
    x=x[:len(x)-1]
#     y=true_capacity[8:]

    VALIDATION_SPLIT=0.9
    x_validation_samples = int( VALIDATION_SPLIT* len(x))
    y_validation_samples = int( VALIDATION_SPLIT*len(y))
    
    
    # 获取得到训练集，验证集，比例9:1
    x_train=np.array(x[:x_validation_samples])
    x_test=np.array(x[x_validation_samples:])
    y_train=np.array(y[:y_validation_samples])
    y_test=np.array(y[y_validation_samples:])
    print("x_train's shape is:", x_train.shape,"，y_train's shape is:",y_train.shape)
    print("x_test's shape is:",x_test.shape,"，y_test's shape is:",y_test.shape)
    return x_train,x_test,y_train,y_test

# %%
# 定义全局变量，将所有电池数据集集合起来，形成训练集，测试集
# x_train_all,x_test_all,y_train_all,y_test_all=[],[],[],[]
for i in range(5,8):
    #/home/aqts/yangHong/battery experiment/jsonData
    discharge=r'/home/aqts/yangHong/battery experiment/jsonData/B000'+str(i)+'_discharge.json'
    discharge_matrix,true_soc=batterydata2matrix(discharge)
    train_x,test_x,train_y,test_y=getTrainData(discharge_matrix,true_soc)
    # start 开始时先赋值给x_train_all，x_test_all，y_train_all，y_test_all
    if i==5:
        x_train_all=train_x
        x_test_all=test_x
        y_train_all=train_y
        y_test_all=test_y
    else:
        x_train_all=np.concatenate((x_train_all,train_x),axis=0)
        x_test_all=np.concatenate((x_test_all,test_x),axis=0)
        y_train_all=np.concatenate((y_train_all,train_y),axis=0)
        y_test_all=np.concatenate((y_test_all,test_y),axis=0)
print(np.array(x_train_all).shape,np.array(x_test_all).shape,np.array(y_train_all).shape,np.array(y_test_all).shape)
# Out:
# x_train's shape is: (144, 3, 8) ，y_train's shape is: (144,)
# x_test's shape is: (16, 3, 8) ，y_test's shape is: (16,)
# x_train's shape is: (144, 3, 8) ，y_train's shape is: (144,)
# x_test's shape is: (16, 3, 8) ，y_test's shape is: (16,)
# x_train's shape is: (144, 3, 8) ，y_train's shape is: (144,)
# x_test's shape is: (16, 3, 8) ，y_test's shape is: (16,)
# (432, 3, 8) (48, 3, 8) (432,) (48,)

# %%
#写一个LossHistory类，保存loss和mae
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as k
import matplotlib.pyplot as plt
import numpy as np
from keras import backend as K
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = {'batch':[], 'epoch':[]}
        self.accuracy = {'batch':[], 'epoch':[]}
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_acc = {'batch':[], 'epoch':[]}

    def on_batch_end(self, batch, logs={}):
        self.losses['batch'].append(logs.get('loss'))
        self.accuracy['batch'].append(logs.get('mean_absolute_error'))
        self.val_loss['batch'].append(logs.get('val_loss'))
        self.val_acc['batch'].append(logs.get('val_mean_absolute_error'))

    def on_epoch_end(self, batch, logs={}):
        self.losses['epoch'].append(logs.get('loss'))
        self.accuracy['epoch'].append(logs.get('mean_absolute_error'))
        self.val_loss['epoch'].append(logs.get('val_loss'))
        self.val_acc['epoch'].append(logs.get('val_mean_absolute_error'))

    def loss_plot(self, loss_type):
        iters = range(len(self.losses[loss_type]))
        plt.figure()
        # mae
        plt.plot(iters, self.accuracy[loss_type], 'r', label='train mae')
        # loss
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        if loss_type == 'epoch':
            # val_mean_absolute_error
            plt.plot(iters, self.val_acc[loss_type], 'b', label='val mean absolute error')
            # val_loss
            plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('mae-loss')
        plt.legend(loc="upper right")
        plt.show()

# %%
#使用cnn训练的模型
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D,GRU,LSTM,Bidirectional,RepeatVector,concatenate
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras import regularizers
from keras.optimizers import SGD, Adam
from keras.layers.normalization import BatchNormalization
import tensorflow as tf
from keras.layers.noise import GaussianNoise
from keras.layers.wrappers import TimeDistributed
from keras.layers.core import Reshape
# 引用GPU命令
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
num=1
img_rows, img_cols =x_train_all.shape[1],x_train_all.shape[2]
if K.image_dim_ordering() == 'th':
    x_train_all = x_train_all.reshape(x_train_all.shape[0], 1, img_rows, img_cols)
    x_test_all = x_test_all.reshape(x_test_all.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train_all = x_train_all.reshape(x_train_all.shape[0], img_rows, img_cols, 1)
    x_test_all= x_test_all.reshape(x_test_all.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

# if K.image_dim_ordering() == 'th':
#     x_train_all = x_train_all.reshape(x_train_all.shape[0], img_rows, img_cols)
#     x_test_all = x_test_all.reshape(x_test_all.shape[0], img_rows, img_cols)
#     input_shape = (1, img_rows, img_cols)
# else:
#     x_train_all = x_train_all.reshape(x_train_all.shape[0], img_rows, img_cols)
#     x_test_all= x_test_all.reshape(x_test_all.shape[0], img_rows, img_cols)
#     input_shape = (img_rows, img_cols, 1)
    
# keras 函数时搭建cnn模型
# model building
nb_lstm_outputs =16  #神经元个数
main_input_cnn= Input(shape=input_shape, dtype='float32')
# print(main_input_cnn.shape)
# main_input_rnn = Input(shape=(img_rows, img_cols), dtype='float32')
# print(main_input_rnn.shape)
# CNN model 
cnn=Conv2D(64, kernel_size=(1,2),
                 activation='relu',
                 input_shape=input_shape,padding="same")(main_input_cnn)
cnn=Conv2D(128, (2,2), activation='relu',padding="same")(cnn)
cnn=MaxPooling2D(pool_size=(1, 2))(cnn)
# cnn=Dropout(0.20)(cnn)

cnn=Conv2D(32, (2,1), activation='relu',padding="same")(cnn)

cnn=Conv2D(64, (3,2), activation='relu',padding="same")(cnn)
# print("cnn's first shape",cnn.shape)
# cnn=MaxPooling2D(pool_size=(2,2))(cnn)
# cnn=Reshape((cnn[1]*cnn[2], cnn[3]))
# print("cnn's reshae shape",cnn)
cnn=Flatten()(cnn)
# print("cnn's second shape",cnn.shape)
# cnn=Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001))(cnn)
# cnn=Dropout(0.20)(cnn)
# cnn=Dense(16, activation='relu')(cnn)
# cnn=Dropout(0.20)(cnn)
print(cnn.shape)
# RNN model
gru=Reshape((-1,2))(cnn)
print(gru)
rnn=GRU(units=nb_lstm_outputs,dropout=0.20, recurrent_dropout=0.10,return_sequences=True)(gru)
rnn=GRU(64, dropout=0.20,recurrent_dropout=0.10)(rnn)
rnn=Dropout(0.20)(rnn)
rnn=Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001))(rnn)
rnn=Dropout(0.20)(rnn)

# rnn=Dense(16, activation='relu')(rnn)
# rnn=Dropout(0.20)(rnn)


# con = concatenate([cnn,rnn], axis=-1)
main_output = Dense(num)(rnn)
# model = Model(inputs = [main_input_cnn,main_input_rnn], outputs = main_output)
model = Model(inputs = [main_input_cnn], outputs = main_output)
sgd = SGD(lr=0.005, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='mse', optimizer="sgd", metrics=["mae"])


batch_size =16
num_epoch = 128


model.summary()
# decay_rate = learning_rate / num_epoch
# momentum = 0.8
# sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)

# model.compile(loss='mse', optimizer=sgd, metrics=["mae"])
#model training
history = LossHistory()
model.fit(x_train_all, y_train_all,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,validation_split=0.3,callbacks=[history])

mse_score,mae_score= model.evaluate(x_test_all, y_test_all, verbose=0)
print('Test MSE Score:%.3f %%'% (mse_score*100)) 
print('Test MAE Score:%.3f %%'% (mae_score*100))
# Out:
# (?, ?)
# Tensor("reshape_11/Reshape:0", shape=(?, ?, 2), dtype=float32)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_62 (InputLayer)        (None, 3, 8, 1)           0
# _________________________________________________________________
# conv2d_114 (Conv2D)          (None, 3, 8, 64)          192
# _________________________________________________________________
# conv2d_115 (Conv2D)          (None, 3, 8, 128)         32896
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 3, 4, 128)         0
# _________________________________________________________________
# conv2d_116 (Conv2D)          (None, 3, 4, 32)          8224
# _________________________________________________________________
# conv2d_117 (Conv2D)          (None, 3, 4, 64)          12352
# _________________________________________________________________
# flatten_28 (Flatten)         (None, 768)               0
# _________________________________________________________________
# reshape_11 (Reshape)         (None, 384, 2)            0
# _________________________________________________________________
# gru_40 (GRU)                 (None, 384, 16)           912
# _________________________________________________________________
# gru_41 (GRU)                 (None, 64)                15552
# _________________________________________________________________
# dropout_70 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_79 (Dense)             (None, 16)                1040
# _________________________________________________________________
# dropout_71 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_80 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 71,185
# Trainable params: 71,185
# Non-trainable params: 0
# _________________________________________________________________
# Train on 302 samples, validate on 130 samples
# Epoch 1/128
# 302/302 [==============================] - 29s 95ms/step - loss: 0.2843 - mean_absolute_error: 0.4597 - val_loss: 0.0784 - val_mean_absolute_error: 0.2194
# Epoch 2/128
# 302/302 [==============================] - 22s 74ms/step - loss: 0.0801 - mean_absolute_error: 0.1821 - val_loss: 0.0374 - val_mean_absolute_error: 0.0866
# Epoch 3/128
# 302/302 [==============================] - 23s 75ms/step - loss: 0.0689 - mean_absolute_error: 0.1629 - val_loss: 0.0330 - val_mean_absolute_error: 0.0667
# Epoch 4/128
# 302/302 [==============================] - 22s 74ms/step - loss: 0.0638 - mean_absolute_error: 0.1533 - val_loss: 0.0336 - val_mean_absolute_error: 0.0692
# Epoch 5/128
# 302/302 [==============================] - 23s 75ms/step - loss: 0.0590 - mean_absolute_error: 0.1433 - val_loss: 0.0333 - val_mean_absolute_error: 0.0683
# Epoch 6/128
# 302/302 [==============================] - 23s 75ms/step - loss: 0.0574 - mean_absolute_error: 0.1421 - val_loss: 0.0355 - val_mean_absolute_error: 0.0778
# Epoch 7/128
# 302/302 [==============================] - 23s 76ms/step - loss: 0.0615 - mean_absolute_error: 0.1494 - val_loss: 0.0341 - val_mean_absolute_error: 0.0715
# Epoch 8/128
# 302/302 [==============================] - 23s 75ms/step - loss: 0.0572 - mean_absolute_error: 0.1396 - val_loss: 0.0329 - val_mean_absolute_error: 0.0669
# Epoch 9/128
# 302/302 [==============================] - 23s 75ms/step - loss: 0.0548 - mean_absolute_error: 0.1345 - val_loss: 0.0331 - val_mean_absolute_error: 0.0675
# Epoch 10/128
# 302/302 [==============================] - 23s 76ms/step - loss: 0.0517 - mean_absolute_error: 0.1270 - val_loss: 0.0329 - val_mean_absolute_error: 0.0670
# Epoch 11/128
# 302/302 [==============================] - 23s 76ms/step - loss: 0.0531 - mean_absolute_error: 0.1331 - val_loss: 0.0326 - val_mean_absolute_error: 0.0659
# Epoch 12/128
# 302/302 [==============================] - 23s 76ms/step - loss: 0.0553 - mean_absolute_error: 0.1414 - val_loss: 0.0327 - val_mean_absolute_error: 0.0662
# Epoch 13/128
# 302/302 [==============================] - 23s 76ms/step - loss: 0.0481 - mean_absolute_error: 0.1210 - val_loss: 0.0327 - val_mean_absolute_error: 0.0662
# Epoch 14/128
# 302/302 [==============================] - 23s 77ms/step - loss: 0.0474 - mean_absolute_error: 0.1187 - val_loss: 0.0329 - val_mean_absolute_error: 0.0671
# Epoch 15/128
# 302/302 [==============================] - 23s 76ms/step - loss: 0.0476 - mean_absolute_error: 0.1231 - val_loss: 0.0322 - val_mean_absolute_error: 0.0646
# Epoch 16/128
# 302/302 [==============================] - 23s 76ms/step - loss: 0.0490 - mean_absolute_error: 0.1230 - val_loss: 0.0328 - val_mean_absolute_error: 0.0670
# Epoch 17/128
# 302/302 [==============================] - 22s 74ms/step - loss: 0.0475 - mean_absolute_error: 0.1191 - val_loss: 0.0328 - val_mean_absolute_error: 0.0672
# Epoch 18/128
# 160/302 [==============>...............] - ETA: 8s - loss: 0.0490 - mean_absolute_error: 0.1210
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-c9e4ef03f490> in <module>
#     103           batch_size=batch_size,
#     104           epochs=num_epoch,
# --> 105           verbose=1,validation_split=0.3,callbacks=[history])
#     106
#     107 mse_score,mae_score= model.evaluate(x_test_all, y_test_all, verbose=0)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# 基于序贯(Sequential)编程方式的模型

# %%
#使用cnn训练的模型
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D,GRU,LSTM,Bidirectional,RepeatVector
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras import regularizers
from keras.optimizers import SGD, Adam
from keras.layers.normalization import BatchNormalization
import tensorflow as tf
from keras.layers.noise import GaussianNoise
from keras.layers.wrappers import TimeDistributed
# 引用GPU命令
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
num=1

img_rows, img_cols =x_train_all.shape[1],x_train_all.shape[2]
if K.image_dim_ordering() == 'th':
    x_train_all = x_train_all.reshape(x_train_all.shape[0], 1, img_rows, img_cols)
    x_test_all = x_test_all.reshape(x_test_all.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train_all = x_train_all.reshape(x_train_all.shape[0],img_rows, img_cols, 1)
    x_test_all= x_test_all.reshape(x_test_all.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

# Sequential model about CNN building
model = Sequential()
model.add(Conv2D(64, kernel_size=(1,2),
                 activation='relu',
                 input_shape=input_shape,padding="same"))
model.add(Conv2D(128, (2,2), activation='relu',padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Dropout(0.20))
model.add(Conv2D(32, (2,1), activation='relu',padding="same"))

model.add(Conv2D(64, (2,2), activation='relu',padding="same"))

model.add(Flatten())
model.add(Dropout(0.20))
model.add(Reshape((-1,8)))
print(model.output_shape)
model.add(GRU(16, return_sequences=True,dropout=0.20, recurrent_dropout=0.10))
# model.add(Dropout(0.20))
model.add(GRU(64,dropout=0.20,recurrent_dropout=0.10))
model.add(Dropout(0.20))
model.add(Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.20))

model.add(Dense(32, activation='relu'))
model.add(Dropout(0.20))
model.add(Dense(num))

#回归问题评价指标使用mae
model.compile(loss='mse', optimizer="sgd", metrics=["mae"])
model.summary()
batch_size =16
num_epoch = 64

#model training
history = LossHistory()
model.fit(x_train_all, y_train_all,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,validation_split=0.2,callbacks=[history])
mse_score,mae_score= model.evaluate(x_test_all, y_test_all, verbose=0)
print('Test MSE Score:%.3f %%'% (mse_score*100)) 
print('Test MAE Score:%.3f %%'% (mae_score*100))
# Out:
# (None, 32, 8)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_195 (Conv2D)          (None, 3, 8, 64)          192
# _________________________________________________________________
# conv2d_196 (Conv2D)          (None, 3, 8, 128)         32896
# _________________________________________________________________
# max_pooling2d_56 (MaxPooling (None, 1, 4, 128)         0
# _________________________________________________________________
# conv2d_197 (Conv2D)          (None, 1, 4, 32)          8224
# _________________________________________________________________
# conv2d_198 (Conv2D)          (None, 1, 4, 64)          8256
# _________________________________________________________________
# flatten_47 (Flatten)         (None, 256)               0
# _________________________________________________________________
# dropout_105 (Dropout)        (None, 256)               0
# _________________________________________________________________
# reshape_26 (Reshape)         (None, 32, 8)             0
# _________________________________________________________________
# gru_54 (GRU)                 (None, 32, 16)            1200
# _________________________________________________________________
# gru_55 (GRU)                 (None, 64)                15552
# _________________________________________________________________
# dropout_106 (Dropout)        (None, 64)                0
# _________________________________________________________________
# dense_99 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_107 (Dropout)        (None, 32)                0
# _________________________________________________________________
# dense_100 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dropout_108 (Dropout)        (None, 32)                0
# _________________________________________________________________
# dense_101 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 69,489
# Trainable params: 69,489
# Non-trainable params: 0
# _________________________________________________________________
# Train on 345 samples, validate on 87 samples
# Epoch 1/64
# 345/345 [==============================] - 9s 25ms/step - loss: 0.2962 - mean_absolute_error: 0.4520 - val_loss: 0.0627 - val_mean_absolute_error: 0.1392
# Epoch 2/64
# 345/345 [==============================] - 2s 6ms/step - loss: 0.0743 - mean_absolute_error: 0.1438 - val_loss: 0.0433 - val_mean_absolute_error: 0.0328
# Epoch 3/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0674 - mean_absolute_error: 0.1286 - val_loss: 0.0441 - val_mean_absolute_error: 0.0399
# Epoch 4/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0661 - mean_absolute_error: 0.1293 - val_loss: 0.0439 - val_mean_absolute_error: 0.0384
# Epoch 5/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0621 - mean_absolute_error: 0.1129 - val_loss: 0.0432 - val_mean_absolute_error: 0.0328
# Epoch 6/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0631 - mean_absolute_error: 0.1182 - val_loss: 0.0437 - val_mean_absolute_error: 0.0370
# Epoch 7/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0607 - mean_absolute_error: 0.1121 - val_loss: 0.0435 - val_mean_absolute_error: 0.0362
# Epoch 8/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0627 - mean_absolute_error: 0.1185 - val_loss: 0.0433 - val_mean_absolute_error: 0.0342
# Epoch 9/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0608 - mean_absolute_error: 0.1112 - val_loss: 0.0434 - val_mean_absolute_error: 0.0355
# Epoch 10/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0629 - mean_absolute_error: 0.1175 - val_loss: 0.0432 - val_mean_absolute_error: 0.0345
# Epoch 11/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0605 - mean_absolute_error: 0.1115 - val_loss: 0.0440 - val_mean_absolute_error: 0.0411
# Epoch 12/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0624 - mean_absolute_error: 0.1218 - val_loss: 0.0432 - val_mean_absolute_error: 0.0346
# Epoch 13/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0597 - mean_absolute_error: 0.1092 - val_loss: 0.0431 - val_mean_absolute_error: 0.0344
# Epoch 14/64
# 345/345 [==============================] - 2s 6ms/step - loss: 0.0596 - mean_absolute_error: 0.1093 - val_loss: 0.0434 - val_mean_absolute_error: 0.0371
# Epoch 15/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0584 - mean_absolute_error: 0.1063 - val_loss: 0.0435 - val_mean_absolute_error: 0.0387
# Epoch 16/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0579 - mean_absolute_error: 0.1045 - val_loss: 0.0428 - val_mean_absolute_error: 0.0332
# Epoch 17/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0591 - mean_absolute_error: 0.1111 - val_loss: 0.0430 - val_mean_absolute_error: 0.0350
# Epoch 18/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0560 - mean_absolute_error: 0.1005 - val_loss: 0.0431 - val_mean_absolute_error: 0.0357
# Epoch 19/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0562 - mean_absolute_error: 0.1008 - val_loss: 0.0429 - val_mean_absolute_error: 0.0344
# Epoch 20/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0574 - mean_absolute_error: 0.1064 - val_loss: 0.0429 - val_mean_absolute_error: 0.0351
# Epoch 21/64
# 345/345 [==============================] - 2s 6ms/step - loss: 0.0556 - mean_absolute_error: 0.0989 - val_loss: 0.0433 - val_mean_absolute_error: 0.0387
# Epoch 22/64
# 345/345 [==============================] - 2s 6ms/step - loss: 0.0576 - mean_absolute_error: 0.1096 - val_loss: 0.0429 - val_mean_absolute_error: 0.0353
# Epoch 23/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0552 - mean_absolute_error: 0.0996 - val_loss: 0.0429 - val_mean_absolute_error: 0.0357
# Epoch 24/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0560 - mean_absolute_error: 0.1027 - val_loss: 0.0427 - val_mean_absolute_error: 0.0341
# Epoch 25/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0561 - mean_absolute_error: 0.1027 - val_loss: 0.0430 - val_mean_absolute_error: 0.0371
# Epoch 26/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0556 - mean_absolute_error: 0.1031 - val_loss: 0.0424 - val_mean_absolute_error: 0.0325
# Epoch 27/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0564 - mean_absolute_error: 0.1034 - val_loss: 0.0425 - val_mean_absolute_error: 0.0338
# Epoch 28/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0560 - mean_absolute_error: 0.1028 - val_loss: 0.0430 - val_mean_absolute_error: 0.0386
# Epoch 29/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0547 - mean_absolute_error: 0.0986 - val_loss: 0.0427 - val_mean_absolute_error: 0.0357
# Epoch 30/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0546 - mean_absolute_error: 0.0978 - val_loss: 0.0425 - val_mean_absolute_error: 0.0346
# Epoch 31/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0541 - mean_absolute_error: 0.0970 - val_loss: 0.0423 - val_mean_absolute_error: 0.0328
# Epoch 32/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0541 - mean_absolute_error: 0.0967 - val_loss: 0.0425 - val_mean_absolute_error: 0.0349
# Epoch 33/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0543 - mean_absolute_error: 0.0985 - val_loss: 0.0424 - val_mean_absolute_error: 0.0346
# Epoch 34/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0536 - mean_absolute_error: 0.0960 - val_loss: 0.0424 - val_mean_absolute_error: 0.0346
# Epoch 35/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0532 - mean_absolute_error: 0.0933 - val_loss: 0.0426 - val_mean_absolute_error: 0.0368
# Epoch 36/64
# 345/345 [==============================] - 2s 6ms/step - loss: 0.0533 - mean_absolute_error: 0.0945 - val_loss: 0.0424 - val_mean_absolute_error: 0.0351
# Epoch 37/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0544 - mean_absolute_error: 0.0996 - val_loss: 0.0425 - val_mean_absolute_error: 0.0363
# Epoch 38/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0529 - mean_absolute_error: 0.0945 - val_loss: 0.0423 - val_mean_absolute_error: 0.0350
# Epoch 39/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0530 - mean_absolute_error: 0.0964 - val_loss: 0.0421 - val_mean_absolute_error: 0.0342
# Epoch 40/64
# 345/345 [==============================] - 2s 6ms/step - loss: 0.0552 - mean_absolute_error: 0.1028 - val_loss: 0.0421 - val_mean_absolute_error: 0.0343
# Epoch 41/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0535 - mean_absolute_error: 0.0974 - val_loss: 0.0422 - val_mean_absolute_error: 0.0352
# Epoch 42/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0539 - mean_absolute_error: 0.0979 - val_loss: 0.0422 - val_mean_absolute_error: 0.0358
# Epoch 43/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0539 - mean_absolute_error: 0.1001 - val_loss: 0.0425 - val_mean_absolute_error: 0.0387
# Epoch 44/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0527 - mean_absolute_error: 0.0956 - val_loss: 0.0425 - val_mean_absolute_error: 0.0387
# Epoch 45/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0526 - mean_absolute_error: 0.0949 - val_loss: 0.0420 - val_mean_absolute_error: 0.0345
# Epoch 46/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0529 - mean_absolute_error: 0.0960 - val_loss: 0.0423 - val_mean_absolute_error: 0.0374
# Epoch 47/64
# 345/345 [==============================] - 2s 6ms/step - loss: 0.0528 - mean_absolute_error: 0.0944 - val_loss: 0.0422 - val_mean_absolute_error: 0.0369
# Epoch 48/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0537 - mean_absolute_error: 0.0975 - val_loss: 0.0421 - val_mean_absolute_error: 0.0361
# Epoch 49/64
# 345/345 [==============================] - 2s 6ms/step - loss: 0.0522 - mean_absolute_error: 0.0937 - val_loss: 0.0423 - val_mean_absolute_error: 0.0384
# Epoch 50/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0522 - mean_absolute_error: 0.0937 - val_loss: 0.0421 - val_mean_absolute_error: 0.0370
# Epoch 51/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0532 - mean_absolute_error: 0.0984 - val_loss: 0.0418 - val_mean_absolute_error: 0.0347
# Epoch 52/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0525 - mean_absolute_error: 0.0959 - val_loss: 0.0419 - val_mean_absolute_error: 0.0362
# Epoch 53/64
# 345/345 [==============================] - 2s 6ms/step - loss: 0.0523 - mean_absolute_error: 0.0960 - val_loss: 0.0419 - val_mean_absolute_error: 0.0366
# Epoch 54/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0528 - mean_absolute_error: 0.0981 - val_loss: 0.0421 - val_mean_absolute_error: 0.0379
# Epoch 55/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0522 - mean_absolute_error: 0.0951 - val_loss: 0.0417 - val_mean_absolute_error: 0.0355
# Epoch 56/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0523 - mean_absolute_error: 0.0974 - val_loss: 0.0419 - val_mean_absolute_error: 0.0369
# Epoch 57/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0511 - mean_absolute_error: 0.0901 - val_loss: 0.0417 - val_mean_absolute_error: 0.0360
# Epoch 58/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0518 - mean_absolute_error: 0.0946 - val_loss: 0.0419 - val_mean_absolute_error: 0.0377
# Epoch 59/64
# 345/345 [==============================] - 2s 6ms/step - loss: 0.0503 - mean_absolute_error: 0.0885 - val_loss: 0.0417 - val_mean_absolute_error: 0.0359
# Epoch 60/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0526 - mean_absolute_error: 0.0966 - val_loss: 0.0420 - val_mean_absolute_error: 0.0391
# Epoch 61/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0512 - mean_absolute_error: 0.0934 - val_loss: 0.0416 - val_mean_absolute_error: 0.0359
# Epoch 62/64
# 345/345 [==============================] - 2s 7ms/step - loss: 0.0510 - mean_absolute_error: 0.0913 - val_loss: 0.0416 - val_mean_absolute_error: 0.0363
# Epoch 63/64
# 345/345 [==============================] - 2s 6ms/step - loss: 0.0513 - mean_absolute_error: 0.0936 - val_loss: 0.0414 - val_mean_absolute_error: 0.0353
# Epoch 64/64
# 345/345 [==============================] - 2s 6ms/step - loss: 0.0512 - mean_absolute_error: 0.0929 - val_loss: 0.0413 - val_mean_absolute_error: 0.0344
# Test MSE Score:6.148 %
# Test MAE Score:14.026 %

# %%
#绘制mae-loss曲线
history.loss_plot('epoch')
# input_shape[]

# %% [markdown]
# 获取得到需要用于预测的电池数据集B0018号电池

# %%
# 获取预测所需的电池数据集
def getBattery008data(discharge_matrix):
    x_pred=[]
    flag=0

    # 获取得到x_pred的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取0--37这段的长度，叠加+1循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成3*T的时间维度
            x_pred.append(bataery_data_training.T)
        flag+=1

    x_pred=np.array(x_pred[:len(x_pred)-1])
    return x_pred

# return prediction  data &  prediction  data true_so
discharge_008=r'/home/aqts/yangHong/battery experiment/jsonData/B0008_discharge.json'
# 获取得到一节电池的 特征向量 与true soc 
discharge_matrix_008,true_soc_008 =batterydata2matrix(discharge_008)
# 得到预测样本集 t=7
x_test_008=getBattery008data(discharge_matrix_008)


print("x_test_008 data shape is",x_test_008.shape)
# 预测数据集进行转换
if K.image_dim_ordering() == 'th':
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], img_rows, img_cols,1)
    input_shape = (img_rows, img_cols, 1)
# Out:
# x_test_008 data shape is (124, 3, 8)

# %%
pred=model.predict(x_test_008, batch_size=16, verbose=0)
print(pred.shape)
# Out:
# (124, 1)

# %%
import pandas as pd # 导入pandas库用来处理csv文件
import matplotlib.pyplot as plt # 导入matplotlib.pyplot并用plt简称

# true soc predict plot
x_true_soc=range(len(true_soc_008))
# 切割开始的基数一定为7
start=8
x_test_soc_008=range(start,start+pred.shape[0])
print("x_true_soc range is ",x_true_soc,"\n x_test_soc_008  range is:",x_test_soc_008)
plt.plot(x_true_soc, true_soc_008, linewidth=2.0, color='r',label="True SOC")#线的宽度为2.0，颜色为红色
plt.plot(x_test_soc_008, pred, linewidth=2.0, color='g',label="Prediction SOC")#线的宽度为2.0，颜色为绿色


# 设置x ,y轴的步长与刻度属性
plt.xticks([x for x in range(len(x_true_soc) + 1) if x %10 == 0])  # x标记step设置为10
plt.ylim(ymin=0.3,ymax=1.1)
# remark for x & y
plt.xlabel('Cylce')
plt.ylabel('SOC')
plt.title('Real Soc and Predicted Soc')

plt.legend()
plt.show()#显示图像
# Out:
# x_true_soc range is  range(0, 132)
#  x_test_soc_008  range is: range(8, 132)
