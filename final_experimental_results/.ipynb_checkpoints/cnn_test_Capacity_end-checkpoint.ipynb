# %% [markdown]
# battery json data  convert to matrix and input to CNN for train,有容量特征字段

# %%
from sklearn import preprocessing 
from scipy.io import loadmat, whosmat
import numpy as np
import datetime
import json
import os
# 获取得到 json data of battery 
def json_load(dictonary):
    with open(dictonary) as f:
        data = json.load(f)
    return data

'''
cycle为行数，循环读取一行数据，对一行数据里面的voltage,current and temp求均值，并添加capacity features
得到battery array
'''
def batteryData2array(battery_data):
    vol_sum = 0
    cur_sum = 0
    temp_sum=0
    battery_array = []
    for cycle in battery_data.keys():
        # list type 
        battery_vols = battery_data[cycle]["voltage_battery"]
        battery_curs = battery_data[cycle]["current_battery"]
        battery_temps=battery_data[cycle]["temp_battery"]
        battery_capacity=battery_data[cycle]["Capacity"]
        for battery_vol in battery_vols:
            vol_sum += float(battery_vol)
        for battery_cur in battery_curs:
            cur_sum += float(battery_cur)
        for battery_temp in battery_temps:
            temp_sum += float(battery_temp)
        #for voltage and current average  & battery_vols,battery_curs,battery_temps's len is equal
        num = len(battery_vols)
        vol_aver = vol_sum / num
        cur_aver = cur_sum / num
        temp_aver=temp_sum/num
        vol_sum = 0
        cur_sum = 0
        temp_sum=0
        battery_array.append([vol_aver,cur_aver,temp_aver,battery_capacity[0]])
#         battery_array.append([vol_aver,cur_aver,battery_capacity[0]])
    return battery_array

# get battery's true soc
def  getTrueSOC(battery_discharge_data):
    batteryCapcity=2
    soc_dict=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        soc_true=cycleCapacity[0]/batteryCapcity
        soc_dict.append(soc_true)
    return soc_dict

# get battery's discgarge capacity
def  getTrueCapacity(battery_discharge_data):
    capacity=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        capacity.append(cycleCapacity[0])
    return capacity

'''
获取得到 battery 's img matrix 图像矩阵  4维特征向量  vol_aver,cur_aver,temp_aver,battery_capacity
返回battery discharge matrix and true soc array
'''
def batterydata2matrix(discharge):
    #get the discharge and charge json data
    discharge_data =json_load(discharge)
    
    #get the true soc data
    true_soc=getTrueSOC(discharge_data)
#   true_capacity=getTrueCapacity(discharge_data)
    #get the battery discharge array data  convert to matrix
    discharge_array = batteryData2array(discharge_data)
    discharge_matrix = np.array(discharge_array)

    discharge_matrix=preprocessing.scale(discharge_matrix)
    return discharge_matrix,true_soc

'''
获取得到每一节电池数据的训练数据集
得到train & test data
'''
def getTrainData(discharge_matrix,true_soc):     
    #循环切片形成数据集
    x=[];y=[]
    x_train=[];y_train=[]
    flag=0

    # 获取得到x,y的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取长度为8的矩阵，叠加循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成4*T的时间维度
            x.append(bataery_data_training.T)
        flag+=1
    #0-》t时刻d x 预测得到t时刻的soc。为了对soc 进行预测，y矩阵为【7：】
    x=x[:len(x)-1]
    y=true_soc[8:]
#     print(len(x))
#     y=true_capacity[8:]

    VALIDATION_SPLIT=0.9
    x_validation_samples = int( VALIDATION_SPLIT* len(x))
    y_validation_samples = int( VALIDATION_SPLIT*len(y))
    
    
    # 获取得到训练集，验证集，比例9:1
    x_train=np.array(x[:x_validation_samples])
    x_test=np.array(x[x_validation_samples:])
    y_train=np.array(y[:y_validation_samples])
    y_test=np.array(y[y_validation_samples:])
    print("x_train's shape is:", x_train.shape,"，y_train's shape is:",y_train.shape)
    print("x_test's shape is:",x_test.shape,"，y_test's shape is:",y_test.shape)
    return x_train,x_test,y_train,y_test

# %%
# 定义全局变量，将所有电池数据集集合起来，形成训练集，测试集
# x_train_all,x_test_all,y_train_all,y_test_all=[],[],[],[]
for i in range(5,8):
    #/home/aqts/yangHong/battery experiment/jsonData
    discharge=r'/home/aqts/yangHong/battery experiment/jsonData/B000'+str(i)+'_discharge.json'
    discharge_matrix,true_soc=batterydata2matrix(discharge)
    train_x,test_x,train_y,test_y=getTrainData(discharge_matrix,true_soc)
    # start 开始时先赋值给x_train_all，x_test_all，y_train_all，y_test_all
    if i==5:
        x_train_all=train_x
        x_test_all=test_x
        y_train_all=train_y
        y_test_all=test_y
    else:
        x_train_all=np.concatenate((x_train_all,train_x),axis=0)
        x_test_all=np.concatenate((x_test_all,test_x),axis=0)
        y_train_all=np.concatenate((y_train_all,train_y),axis=0)
        y_test_all=np.concatenate((y_test_all,test_y),axis=0)
print(np.array(x_train_all).shape,np.array(x_test_all).shape,np.array(y_train_all).shape,np.array(y_test_all).shape)
# Out:
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (16, 4, 8) ，y_test's shape is: (16,)
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (16, 4, 8) ，y_test's shape is: (16,)
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (16, 4, 8) ，y_test's shape is: (16,)
# (432, 4, 8) (48, 4, 8) (432,) (48,)

# %%
#写一个LossHistory类，保存loss和mae
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as k
import matplotlib.pyplot as plt
import numpy as np
from keras import backend as K
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = {'batch':[], 'epoch':[]}
        self.accuracy = {'batch':[], 'epoch':[]}
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_acc = {'batch':[], 'epoch':[]}

    def on_batch_end(self, batch, logs={}):
        self.losses['batch'].append(logs.get('loss'))
        self.accuracy['batch'].append(logs.get('mean_absolute_error'))
        self.val_loss['batch'].append(logs.get('val_loss'))
        self.val_acc['batch'].append(logs.get('val_mean_absolute_error'))

    def on_epoch_end(self, batch, logs={}):
        self.losses['epoch'].append(logs.get('loss'))
        self.accuracy['epoch'].append(logs.get('mean_absolute_error'))
        self.val_loss['epoch'].append(logs.get('val_loss'))
        self.val_acc['epoch'].append(logs.get('val_mean_absolute_error'))

    def loss_plot(self, loss_type):
        iters = range(len(self.losses[loss_type]))
        plt.figure()
        # mae
        plt.plot(iters, self.accuracy[loss_type], 'r', label='train mae')
        # loss
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        if loss_type == 'epoch':
            # val_mean_absolute_error
            plt.plot(iters, self.val_acc[loss_type], 'b', label='val mean absolute error')
            # val_loss
            plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('mae-loss')
        plt.legend(loc="upper right")
        plt.show()
# Out:
# /home/aqts/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#使用cnn训练的模型
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras import regularizers
from keras.optimizers import SGD, Adam
from keras.layers.normalization import BatchNormalization

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
num=1
img_rows, img_cols =x_train_all.shape[1],x_train_all.shape[2]
if K.image_dim_ordering() == 'th':
    x_train_all = x_train_all.reshape(x_train_all.shape[0], 1, img_rows, img_cols)
    x_test_all = x_test_all.reshape(x_test_all.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train_all = x_train_all.reshape(x_train_all.shape[0], img_rows, img_cols, 1)
    x_test_all= x_test_all.reshape(x_test_all.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)
# print(x_train.shape,x_test.shape)
# print(y_train.shape)
# keras序贯模型搭建CNN
# model building
model = Sequential()
#convolutional layer with rectified linear unit activation
model.add(Conv2D(64, kernel_size=(1,2),
                 activation='relu',
                 input_shape=input_shape,padding="same"))
#32 convolution filters used each of size 3x3
#again
model.add(Conv2D(128, (2,2), activation='relu',padding="same"))
#64 convolution filters used each of size 3x3
#choose the best features via pooling
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (2,1), activation='relu',padding="same"))

model.add(Conv2D(64, (2,2), activation='relu',padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
#randomly turn neurons on and off to improve convergence
# model.add(Dropout(0.30))
#flatten since too many dimensions, we only want a classification output
model.add(Flatten())
#fully connected to get all relevant data
model.add(Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.20))

model.add(Dense(16, activation='relu'))
model.add(Dropout(0.20))
# model.add(Dense(num, activation='sigmoid'))
# The last layer does not use the activation function
model.add(Dense(num))

#Adaptive learning rate (adaDelta) is a popular form of gradient descent rivaled only by adam and adagrad
#categorical ce since we have multiple classes (10) 
# model.compile(loss=keras.losses.sparse_categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])
#回归问题评价指标使用mae
model.compile(loss='mse', optimizer="sgd", metrics=["mae"])

model.summary()
batch_size =16
num_epoch = 128



# decay_rate = learning_rate / num_epoch
# momentum = 0.8
# sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)

# model.compile(loss='mse', optimizer=sgd, metrics=["mae"])
#model training
history = LossHistory()
model.fit(x_train_all, y_train_all,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,validation_split=0.3,callbacks=[history])

mse_score,mae_score= model.evaluate(x_test_all, y_test_all, verbose=0)
print('Test MSE Score:%.3f %%'% (mse_score*100)) 
print('Test MAE Score:%.3f %%'% (mae_score*100))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_93 (Conv2D)           (None, 4, 8, 64)          192
# _________________________________________________________________
# conv2d_94 (Conv2D)           (None, 4, 8, 128)         32896
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 2, 4, 128)         0
# _________________________________________________________________
# conv2d_95 (Conv2D)           (None, 2, 4, 32)          8224
# _________________________________________________________________
# conv2d_96 (Conv2D)           (None, 2, 4, 64)          8256
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 1, 2, 64)          0
# _________________________________________________________________
# flatten_24 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_70 (Dense)             (None, 16)                2064
# _________________________________________________________________
# dropout_57 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_71 (Dense)             (None, 16)                272
# _________________________________________________________________
# dropout_58 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_72 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 51,921
# Trainable params: 51,921
# Non-trainable params: 0
# _________________________________________________________________
# Train on 302 samples, validate on 130 samples
# Epoch 1/128
# 302/302 [==============================] - 2s 7ms/step - loss: 0.2800 - mean_absolute_error: 0.4491 - val_loss: 0.0667 - val_mean_absolute_error: 0.1836
# Epoch 2/128
# 302/302 [==============================] - 0s 470us/step - loss: 0.0857 - mean_absolute_error: 0.1979 - val_loss: 0.0415 - val_mean_absolute_error: 0.0918
# Epoch 3/128
# 302/302 [==============================] - 0s 480us/step - loss: 0.0716 - mean_absolute_error: 0.1697 - val_loss: 0.0399 - val_mean_absolute_error: 0.0873
# Epoch 4/128
# 302/302 [==============================] - 0s 483us/step - loss: 0.0634 - mean_absolute_error: 0.1468 - val_loss: 0.0367 - val_mean_absolute_error: 0.0695
# Epoch 5/128
# 302/302 [==============================] - 0s 478us/step - loss: 0.0611 - mean_absolute_error: 0.1435 - val_loss: 0.0364 - val_mean_absolute_error: 0.0716
# Epoch 6/128
# 302/302 [==============================] - 0s 478us/step - loss: 0.0540 - mean_absolute_error: 0.1269 - val_loss: 0.0346 - val_mean_absolute_error: 0.0601
# Epoch 7/128
# 302/302 [==============================] - 0s 484us/step - loss: 0.0593 - mean_absolute_error: 0.1390 - val_loss: 0.0345 - val_mean_absolute_error: 0.0626
# Epoch 8/128
# 302/302 [==============================] - 0s 496us/step - loss: 0.0519 - mean_absolute_error: 0.1210 - val_loss: 0.0359 - val_mean_absolute_error: 0.0762
# Epoch 9/128
# 302/302 [==============================] - 0s 423us/step - loss: 0.0510 - mean_absolute_error: 0.1148 - val_loss: 0.0340 - val_mean_absolute_error: 0.0641
# Epoch 10/128
# 302/302 [==============================] - 0s 494us/step - loss: 0.0460 - mean_absolute_error: 0.1069 - val_loss: 0.0351 - val_mean_absolute_error: 0.0735
# Epoch 11/128
# 302/302 [==============================] - 0s 491us/step - loss: 0.0458 - mean_absolute_error: 0.1023 - val_loss: 0.0335 - val_mean_absolute_error: 0.0633
# Epoch 12/128
# 302/302 [==============================] - 0s 529us/step - loss: 0.0444 - mean_absolute_error: 0.1001 - val_loss: 0.0330 - val_mean_absolute_error: 0.0603
# Epoch 13/128
# 302/302 [==============================] - 0s 503us/step - loss: 0.0439 - mean_absolute_error: 0.0973 - val_loss: 0.0332 - val_mean_absolute_error: 0.0631
# Epoch 14/128
# 302/302 [==============================] - 0s 481us/step - loss: 0.0399 - mean_absolute_error: 0.0854 - val_loss: 0.0339 - val_mean_absolute_error: 0.0687
# Epoch 15/128
# 302/302 [==============================] - 0s 476us/step - loss: 0.0427 - mean_absolute_error: 0.0900 - val_loss: 0.0327 - val_mean_absolute_error: 0.0605
# Epoch 16/128
# 302/302 [==============================] - 0s 493us/step - loss: 0.0409 - mean_absolute_error: 0.0874 - val_loss: 0.0315 - val_mean_absolute_error: 0.0494
# Epoch 17/128
# 302/302 [==============================] - 0s 500us/step - loss: 0.0375 - mean_absolute_error: 0.0734 - val_loss: 0.0324 - val_mean_absolute_error: 0.0587
# Epoch 18/128
# 302/302 [==============================] - 0s 507us/step - loss: 0.0403 - mean_absolute_error: 0.0827 - val_loss: 0.0314 - val_mean_absolute_error: 0.0496
# Epoch 19/128
# 302/302 [==============================] - 0s 485us/step - loss: 0.0406 - mean_absolute_error: 0.0849 - val_loss: 0.0305 - val_mean_absolute_error: 0.0405
# Epoch 20/128
# 302/302 [==============================] - 0s 500us/step - loss: 0.0375 - mean_absolute_error: 0.0774 - val_loss: 0.0319 - val_mean_absolute_error: 0.0554
# Epoch 21/128
# 302/302 [==============================] - 0s 472us/step - loss: 0.0370 - mean_absolute_error: 0.0705 - val_loss: 0.0317 - val_mean_absolute_error: 0.0542
# Epoch 22/128
# 302/302 [==============================] - 0s 470us/step - loss: 0.0368 - mean_absolute_error: 0.0730 - val_loss: 0.0322 - val_mean_absolute_error: 0.0589
# Epoch 23/128
# 302/302 [==============================] - 0s 477us/step - loss: 0.0382 - mean_absolute_error: 0.0761 - val_loss: 0.0322 - val_mean_absolute_error: 0.0588
# Epoch 24/128
# 302/302 [==============================] - 0s 485us/step - loss: 0.0370 - mean_absolute_error: 0.0731 - val_loss: 0.0312 - val_mean_absolute_error: 0.0504
# Epoch 25/128
# 302/302 [==============================] - 0s 521us/step - loss: 0.0364 - mean_absolute_error: 0.0701 - val_loss: 0.0309 - val_mean_absolute_error: 0.0471
# Epoch 26/128
# 302/302 [==============================] - 0s 520us/step - loss: 0.0366 - mean_absolute_error: 0.0691 - val_loss: 0.0307 - val_mean_absolute_error: 0.0446
# Epoch 27/128
# 302/302 [==============================] - 0s 506us/step - loss: 0.0382 - mean_absolute_error: 0.0752 - val_loss: 0.0305 - val_mean_absolute_error: 0.0426
# Epoch 28/128
# 302/302 [==============================] - 0s 505us/step - loss: 0.0359 - mean_absolute_error: 0.0674 - val_loss: 0.0311 - val_mean_absolute_error: 0.0498
# Epoch 29/128
# 302/302 [==============================] - 0s 496us/step - loss: 0.0362 - mean_absolute_error: 0.0692 - val_loss: 0.0310 - val_mean_absolute_error: 0.0493
# Epoch 30/128
# 302/302 [==============================] - 0s 510us/step - loss: 0.0350 - mean_absolute_error: 0.0621 - val_loss: 0.0305 - val_mean_absolute_error: 0.0438
# Epoch 31/128
# 302/302 [==============================] - 0s 536us/step - loss: 0.0353 - mean_absolute_error: 0.0634 - val_loss: 0.0313 - val_mean_absolute_error: 0.0524
# Epoch 32/128
# 302/302 [==============================] - 0s 488us/step - loss: 0.0352 - mean_absolute_error: 0.0627 - val_loss: 0.0310 - val_mean_absolute_error: 0.0498
# Epoch 33/128
# 302/302 [==============================] - 0s 462us/step - loss: 0.0348 - mean_absolute_error: 0.0621 - val_loss: 0.0311 - val_mean_absolute_error: 0.0504
# Epoch 34/128
# 302/302 [==============================] - 0s 512us/step - loss: 0.0337 - mean_absolute_error: 0.0581 - val_loss: 0.0312 - val_mean_absolute_error: 0.0522
# Epoch 35/128
# 302/302 [==============================] - 0s 475us/step - loss: 0.0345 - mean_absolute_error: 0.0589 - val_loss: 0.0313 - val_mean_absolute_error: 0.0528
# Epoch 36/128
# 302/302 [==============================] - 0s 493us/step - loss: 0.0339 - mean_absolute_error: 0.0569 - val_loss: 0.0307 - val_mean_absolute_error: 0.0474
# Epoch 37/128
# 302/302 [==============================] - 0s 482us/step - loss: 0.0336 - mean_absolute_error: 0.0551 - val_loss: 0.0312 - val_mean_absolute_error: 0.0518
# Epoch 38/128
# 302/302 [==============================] - 0s 466us/step - loss: 0.0334 - mean_absolute_error: 0.0558 - val_loss: 0.0311 - val_mean_absolute_error: 0.0512
# Epoch 39/128
# 302/302 [==============================] - 0s 491us/step - loss: 0.0338 - mean_absolute_error: 0.0585 - val_loss: 0.0301 - val_mean_absolute_error: 0.0407
# Epoch 40/128
# 302/302 [==============================] - 0s 469us/step - loss: 0.0334 - mean_absolute_error: 0.0551 - val_loss: 0.0298 - val_mean_absolute_error: 0.0375
# Epoch 41/128
# 302/302 [==============================] - 0s 499us/step - loss: 0.0333 - mean_absolute_error: 0.0577 - val_loss: 0.0300 - val_mean_absolute_error: 0.0395
# Epoch 42/128
# 302/302 [==============================] - 0s 537us/step - loss: 0.0331 - mean_absolute_error: 0.0537 - val_loss: 0.0301 - val_mean_absolute_error: 0.0419
# Epoch 43/128
# 302/302 [==============================] - 0s 524us/step - loss: 0.0333 - mean_absolute_error: 0.0547 - val_loss: 0.0299 - val_mean_absolute_error: 0.0395
# Epoch 44/128
# 302/302 [==============================] - 0s 466us/step - loss: 0.0336 - mean_absolute_error: 0.0582 - val_loss: 0.0299 - val_mean_absolute_error: 0.0397
# Epoch 45/128
# 302/302 [==============================] - 0s 522us/step - loss: 0.0333 - mean_absolute_error: 0.0548 - val_loss: 0.0303 - val_mean_absolute_error: 0.0453
# Epoch 46/128
# 302/302 [==============================] - 0s 533us/step - loss: 0.0330 - mean_absolute_error: 0.0535 - val_loss: 0.0301 - val_mean_absolute_error: 0.0429
# Epoch 47/128
# 302/302 [==============================] - 0s 547us/step - loss: 0.0332 - mean_absolute_error: 0.0548 - val_loss: 0.0304 - val_mean_absolute_error: 0.0466
# Epoch 48/128
# 302/302 [==============================] - 0s 500us/step - loss: 0.0324 - mean_absolute_error: 0.0507 - val_loss: 0.0303 - val_mean_absolute_error: 0.0460
# Epoch 49/128
# 302/302 [==============================] - 0s 481us/step - loss: 0.0321 - mean_absolute_error: 0.0500 - val_loss: 0.0305 - val_mean_absolute_error: 0.0478
# Epoch 50/128
# 302/302 [==============================] - 0s 501us/step - loss: 0.0329 - mean_absolute_error: 0.0545 - val_loss: 0.0299 - val_mean_absolute_error: 0.0411
# Epoch 51/128
# 302/302 [==============================] - 0s 476us/step - loss: 0.0327 - mean_absolute_error: 0.0514 - val_loss: 0.0304 - val_mean_absolute_error: 0.0475
# Epoch 52/128
# 302/302 [==============================] - 0s 478us/step - loss: 0.0324 - mean_absolute_error: 0.0515 - val_loss: 0.0298 - val_mean_absolute_error: 0.0403
# Epoch 53/128
# 302/302 [==============================] - 0s 475us/step - loss: 0.0318 - mean_absolute_error: 0.0484 - val_loss: 0.0301 - val_mean_absolute_error: 0.0445
# Epoch 54/128
# 302/302 [==============================] - 0s 495us/step - loss: 0.0321 - mean_absolute_error: 0.0499 - val_loss: 0.0301 - val_mean_absolute_error: 0.0445
# Epoch 55/128
# 302/302 [==============================] - 0s 505us/step - loss: 0.0327 - mean_absolute_error: 0.0525 - val_loss: 0.0301 - val_mean_absolute_error: 0.0445
# Epoch 56/128
# 302/302 [==============================] - 0s 497us/step - loss: 0.0324 - mean_absolute_error: 0.0508 - val_loss: 0.0297 - val_mean_absolute_error: 0.0408
# Epoch 57/128
# 302/302 [==============================] - 0s 483us/step - loss: 0.0320 - mean_absolute_error: 0.0487 - val_loss: 0.0298 - val_mean_absolute_error: 0.0418
# Epoch 58/128
# 302/302 [==============================] - 0s 493us/step - loss: 0.0314 - mean_absolute_error: 0.0467 - val_loss: 0.0298 - val_mean_absolute_error: 0.0423
# Epoch 59/128
# 302/302 [==============================] - 0s 495us/step - loss: 0.0317 - mean_absolute_error: 0.0478 - val_loss: 0.0299 - val_mean_absolute_error: 0.0434
# Epoch 60/128
# 302/302 [==============================] - 0s 514us/step - loss: 0.0322 - mean_absolute_error: 0.0516 - val_loss: 0.0293 - val_mean_absolute_error: 0.0363
# Epoch 61/128
# 302/302 [==============================] - 0s 492us/step - loss: 0.0316 - mean_absolute_error: 0.0471 - val_loss: 0.0299 - val_mean_absolute_error: 0.0436
# Epoch 62/128
# 302/302 [==============================] - 0s 476us/step - loss: 0.0316 - mean_absolute_error: 0.0465 - val_loss: 0.0297 - val_mean_absolute_error: 0.0419
# Epoch 63/128
# 302/302 [==============================] - 0s 491us/step - loss: 0.0317 - mean_absolute_error: 0.0491 - val_loss: 0.0298 - val_mean_absolute_error: 0.0426
# Epoch 64/128
# 302/302 [==============================] - 0s 504us/step - loss: 0.0316 - mean_absolute_error: 0.0461 - val_loss: 0.0295 - val_mean_absolute_error: 0.0395
# Epoch 65/128
# 302/302 [==============================] - 0s 502us/step - loss: 0.0320 - mean_absolute_error: 0.0491 - val_loss: 0.0299 - val_mean_absolute_error: 0.0453
# Epoch 66/128
# 302/302 [==============================] - 0s 509us/step - loss: 0.0324 - mean_absolute_error: 0.0510 - val_loss: 0.0296 - val_mean_absolute_error: 0.0417
# Epoch 67/128
# 302/302 [==============================] - 0s 502us/step - loss: 0.0308 - mean_absolute_error: 0.0434 - val_loss: 0.0296 - val_mean_absolute_error: 0.0422
# Epoch 68/128
# 302/302 [==============================] - 0s 515us/step - loss: 0.0311 - mean_absolute_error: 0.0458 - val_loss: 0.0299 - val_mean_absolute_error: 0.0452
# Epoch 69/128
# 302/302 [==============================] - 0s 504us/step - loss: 0.0308 - mean_absolute_error: 0.0432 - val_loss: 0.0298 - val_mean_absolute_error: 0.0446
# Epoch 70/128
# 302/302 [==============================] - 0s 506us/step - loss: 0.0311 - mean_absolute_error: 0.0461 - val_loss: 0.0295 - val_mean_absolute_error: 0.0411
# Epoch 71/128
# 302/302 [==============================] - 0s 522us/step - loss: 0.0308 - mean_absolute_error: 0.0436 - val_loss: 0.0294 - val_mean_absolute_error: 0.0401
# Epoch 72/128
# 302/302 [==============================] - 0s 509us/step - loss: 0.0310 - mean_absolute_error: 0.0458 - val_loss: 0.0299 - val_mean_absolute_error: 0.0468
# Epoch 73/128
# 302/302 [==============================] - 0s 491us/step - loss: 0.0310 - mean_absolute_error: 0.0449 - val_loss: 0.0293 - val_mean_absolute_error: 0.0396
# Epoch 74/128
# 302/302 [==============================] - 0s 499us/step - loss: 0.0310 - mean_absolute_error: 0.0437 - val_loss: 0.0293 - val_mean_absolute_error: 0.0408
# Epoch 75/128
# 302/302 [==============================] - 0s 526us/step - loss: 0.0311 - mean_absolute_error: 0.0449 - val_loss: 0.0292 - val_mean_absolute_error: 0.0398
# Epoch 76/128
# 302/302 [==============================] - 0s 481us/step - loss: 0.0309 - mean_absolute_error: 0.0444 - val_loss: 0.0296 - val_mean_absolute_error: 0.0450
# Epoch 77/128
# 302/302 [==============================] - 0s 527us/step - loss: 0.0310 - mean_absolute_error: 0.0439 - val_loss: 0.0296 - val_mean_absolute_error: 0.0446
# Epoch 78/128
# 302/302 [==============================] - 0s 502us/step - loss: 0.0303 - mean_absolute_error: 0.0411 - val_loss: 0.0293 - val_mean_absolute_error: 0.0422
# Epoch 79/128
# 302/302 [==============================] - 0s 483us/step - loss: 0.0304 - mean_absolute_error: 0.0422 - val_loss: 0.0294 - val_mean_absolute_error: 0.0426
# Epoch 80/128
# 302/302 [==============================] - 0s 502us/step - loss: 0.0300 - mean_absolute_error: 0.0389 - val_loss: 0.0297 - val_mean_absolute_error: 0.0471
# Epoch 81/128
# 302/302 [==============================] - 0s 488us/step - loss: 0.0298 - mean_absolute_error: 0.0379 - val_loss: 0.0294 - val_mean_absolute_error: 0.0435
# Epoch 82/128
# 302/302 [==============================] - 0s 458us/step - loss: 0.0301 - mean_absolute_error: 0.0399 - val_loss: 0.0293 - val_mean_absolute_error: 0.0427
# Epoch 83/128
# 302/302 [==============================] - 0s 494us/step - loss: 0.0301 - mean_absolute_error: 0.0393 - val_loss: 0.0295 - val_mean_absolute_error: 0.0458
# Epoch 84/128
# 302/302 [==============================] - 0s 454us/step - loss: 0.0304 - mean_absolute_error: 0.0426 - val_loss: 0.0291 - val_mean_absolute_error: 0.0410
# Epoch 85/128
# 302/302 [==============================] - 0s 459us/step - loss: 0.0305 - mean_absolute_error: 0.0431 - val_loss: 0.0291 - val_mean_absolute_error: 0.0401
# Epoch 86/128
# 302/302 [==============================] - 0s 477us/step - loss: 0.0298 - mean_absolute_error: 0.0382 - val_loss: 0.0292 - val_mean_absolute_error: 0.0428
# Epoch 87/128
# 302/302 [==============================] - 0s 481us/step - loss: 0.0301 - mean_absolute_error: 0.0410 - val_loss: 0.0291 - val_mean_absolute_error: 0.0419
# Epoch 88/128
# 302/302 [==============================] - 0s 499us/step - loss: 0.0295 - mean_absolute_error: 0.0366 - val_loss: 0.0294 - val_mean_absolute_error: 0.0453
# Epoch 89/128
# 302/302 [==============================] - 0s 453us/step - loss: 0.0295 - mean_absolute_error: 0.0371 - val_loss: 0.0293 - val_mean_absolute_error: 0.0445
# Epoch 90/128
# 302/302 [==============================] - 0s 500us/step - loss: 0.0303 - mean_absolute_error: 0.0404 - val_loss: 0.0290 - val_mean_absolute_error: 0.0414
# Epoch 91/128
# 302/302 [==============================] - 0s 498us/step - loss: 0.0297 - mean_absolute_error: 0.0395 - val_loss: 0.0293 - val_mean_absolute_error: 0.0450
# Epoch 92/128
# 302/302 [==============================] - 0s 468us/step - loss: 0.0295 - mean_absolute_error: 0.0370 - val_loss: 0.0291 - val_mean_absolute_error: 0.0432
# Epoch 93/128
# 302/302 [==============================] - 0s 498us/step - loss: 0.0298 - mean_absolute_error: 0.0384 - val_loss: 0.0290 - val_mean_absolute_error: 0.0420
# Epoch 94/128
# 302/302 [==============================] - 0s 514us/step - loss: 0.0298 - mean_absolute_error: 0.0390 - val_loss: 0.0293 - val_mean_absolute_error: 0.0451
# Epoch 95/128
# 302/302 [==============================] - 0s 488us/step - loss: 0.0291 - mean_absolute_error: 0.0331 - val_loss: 0.0290 - val_mean_absolute_error: 0.0423
# Epoch 96/128
# 302/302 [==============================] - 0s 503us/step - loss: 0.0294 - mean_absolute_error: 0.0367 - val_loss: 0.0291 - val_mean_absolute_error: 0.0441
# Epoch 97/128
# 302/302 [==============================] - 0s 493us/step - loss: 0.0295 - mean_absolute_error: 0.0381 - val_loss: 0.0291 - val_mean_absolute_error: 0.0441
# Epoch 98/128
# 302/302 [==============================] - 0s 486us/step - loss: 0.0297 - mean_absolute_error: 0.0384 - val_loss: 0.0291 - val_mean_absolute_error: 0.0436
# Epoch 99/128
# 302/302 [==============================] - 0s 490us/step - loss: 0.0293 - mean_absolute_error: 0.0359 - val_loss: 0.0293 - val_mean_absolute_error: 0.0472
# Epoch 100/128
# 302/302 [==============================] - 0s 485us/step - loss: 0.0297 - mean_absolute_error: 0.0386 - val_loss: 0.0292 - val_mean_absolute_error: 0.0461
# Epoch 101/128
# 302/302 [==============================] - 0s 498us/step - loss: 0.0290 - mean_absolute_error: 0.0347 - val_loss: 0.0289 - val_mean_absolute_error: 0.0421
# Epoch 102/128
# 302/302 [==============================] - 0s 481us/step - loss: 0.0293 - mean_absolute_error: 0.0361 - val_loss: 0.0287 - val_mean_absolute_error: 0.0405
# Epoch 103/128
# 302/302 [==============================] - 0s 483us/step - loss: 0.0296 - mean_absolute_error: 0.0380 - val_loss: 0.0285 - val_mean_absolute_error: 0.0375
# Epoch 104/128
# 302/302 [==============================] - 0s 476us/step - loss: 0.0291 - mean_absolute_error: 0.0358 - val_loss: 0.0288 - val_mean_absolute_error: 0.0416
# Epoch 105/128
# 302/302 [==============================] - 0s 493us/step - loss: 0.0290 - mean_absolute_error: 0.0361 - val_loss: 0.0288 - val_mean_absolute_error: 0.0423
# Epoch 106/128
# 302/302 [==============================] - 0s 466us/step - loss: 0.0291 - mean_absolute_error: 0.0351 - val_loss: 0.0288 - val_mean_absolute_error: 0.0419
# Epoch 107/128
# 302/302 [==============================] - 0s 486us/step - loss: 0.0289 - mean_absolute_error: 0.0360 - val_loss: 0.0286 - val_mean_absolute_error: 0.0397
# Epoch 108/128
# 302/302 [==============================] - 0s 491us/step - loss: 0.0293 - mean_absolute_error: 0.0377 - val_loss: 0.0284 - val_mean_absolute_error: 0.0382
# Epoch 109/128
# 302/302 [==============================] - 0s 473us/step - loss: 0.0292 - mean_absolute_error: 0.0387 - val_loss: 0.0287 - val_mean_absolute_error: 0.0423
# Epoch 110/128
# 302/302 [==============================] - 0s 505us/step - loss: 0.0293 - mean_absolute_error: 0.0369 - val_loss: 0.0285 - val_mean_absolute_error: 0.0396
# Epoch 111/128
# 302/302 [==============================] - 0s 512us/step - loss: 0.0292 - mean_absolute_error: 0.0376 - val_loss: 0.0287 - val_mean_absolute_error: 0.0430
# Epoch 112/128
# 302/302 [==============================] - 0s 509us/step - loss: 0.0290 - mean_absolute_error: 0.0370 - val_loss: 0.0288 - val_mean_absolute_error: 0.0443
# Epoch 113/128
# 302/302 [==============================] - 0s 482us/step - loss: 0.0288 - mean_absolute_error: 0.0348 - val_loss: 0.0286 - val_mean_absolute_error: 0.0415
# Epoch 114/128
# 302/302 [==============================] - 0s 462us/step - loss: 0.0289 - mean_absolute_error: 0.0361 - val_loss: 0.0285 - val_mean_absolute_error: 0.0403
# Epoch 115/128
# 302/302 [==============================] - 0s 451us/step - loss: 0.0285 - mean_absolute_error: 0.0336 - val_loss: 0.0285 - val_mean_absolute_error: 0.0406
# Epoch 116/128
# 302/302 [==============================] - 0s 453us/step - loss: 0.0289 - mean_absolute_error: 0.0363 - val_loss: 0.0285 - val_mean_absolute_error: 0.0404
# Epoch 117/128
# 302/302 [==============================] - 0s 470us/step - loss: 0.0285 - mean_absolute_error: 0.0338 - val_loss: 0.0284 - val_mean_absolute_error: 0.0402
# Epoch 118/128
# 302/302 [==============================] - 0s 495us/step - loss: 0.0288 - mean_absolute_error: 0.0356 - val_loss: 0.0285 - val_mean_absolute_error: 0.0412
# Epoch 119/128
# 302/302 [==============================] - 0s 449us/step - loss: 0.0288 - mean_absolute_error: 0.0355 - val_loss: 0.0284 - val_mean_absolute_error: 0.0410
# Epoch 120/128
# 302/302 [==============================] - 0s 478us/step - loss: 0.0287 - mean_absolute_error: 0.0343 - val_loss: 0.0282 - val_mean_absolute_error: 0.0382
# Epoch 121/128
# 302/302 [==============================] - 0s 471us/step - loss: 0.0288 - mean_absolute_error: 0.0342 - val_loss: 0.0283 - val_mean_absolute_error: 0.0403
# Epoch 122/128
# 302/302 [==============================] - 0s 499us/step - loss: 0.0285 - mean_absolute_error: 0.0333 - val_loss: 0.0285 - val_mean_absolute_error: 0.0425
# Epoch 123/128
# 302/302 [==============================] - 0s 479us/step - loss: 0.0287 - mean_absolute_error: 0.0352 - val_loss: 0.0285 - val_mean_absolute_error: 0.0432
# Epoch 124/128
# 302/302 [==============================] - 0s 479us/step - loss: 0.0289 - mean_absolute_error: 0.0366 - val_loss: 0.0284 - val_mean_absolute_error: 0.0425
# Epoch 125/128
# 302/302 [==============================] - 0s 512us/step - loss: 0.0285 - mean_absolute_error: 0.0338 - val_loss: 0.0282 - val_mean_absolute_error: 0.0394
# Epoch 126/128
# 302/302 [==============================] - 0s 474us/step - loss: 0.0283 - mean_absolute_error: 0.0327 - val_loss: 0.0284 - val_mean_absolute_error: 0.0430
# Epoch 127/128
# 302/302 [==============================] - 0s 495us/step - loss: 0.0285 - mean_absolute_error: 0.0356 - val_loss: 0.0281 - val_mean_absolute_error: 0.0392
# Epoch 128/128
# 302/302 [==============================] - 0s 501us/step - loss: 0.0283 - mean_absolute_error: 0.0336 - val_loss: 0.0283 - val_mean_absolute_error: 0.0410
# Test MSE Score:2.895 %
# Test MAE Score:4.180 %

# %%
#绘制mae-loss曲线
history.loss_plot('epoch')

# %% [markdown]
# 获取得到需要用于预测的电池数据集B0018号电池

# %%
# 获取预测所需的电池数据集
def getBattery008data(discharge_matrix):
    x_pred=[]
    flag=0

    # 获取得到x_pred的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取0--37这段的长度，叠加+1循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成3*T的时间维度
            x_pred.append(bataery_data_training.T)
        flag+=1

    x_pred=np.array(x_pred[:len(x_pred)-1])
    return x_pred

# return prediction  data &  prediction  data true_so
discharge_008=r'/home/aqts/yangHong/battery experiment/jsonData/B0008_discharge.json'
# 获取得到一节电池的 特征向量 与true soc 
discharge_matrix_008,true_soc_008 =batterydata2matrix(discharge_008)
print(len(discharge_matrix_008),len(true_soc_008))
# 得到预测样本集 t=7
x_test_008=getBattery008data(discharge_matrix_008)


print("x_test_008 data shape is",x_test_008.shape)
# 预测数据集进行转换
if K.image_dim_ordering() == 'th':
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], img_rows, img_cols,1)
    input_shape = (img_rows, img_cols, 1)
# Out:
# 132 132
# x_test_008 data shape is (124, 4, 8)

# %%
pred=model.predict(x_test_008, batch_size=16, verbose=0)
print(pred.shape)
# Out:
# (124, 1)

# %%
import pandas as pd # 导入pandas库用来处理csv文件
import matplotlib.pyplot as plt # 导入matplotlib.pyplot并用plt简称

# true soc predict plot
x_true_soc=range(len(true_soc_008))
# 切割开始的基数一定为7
start=8
x_test_soc_008=range(start,start+pred.shape[0])
print("x_true_soc range is ",x_true_soc,"\n x_test_soc_008  range is:",x_test_soc_008)
plt.plot(x_true_soc, true_soc_008, linewidth=2.0, color='r',label="True SOC")#线的宽度为2.0，颜色为红色
plt.plot(x_test_soc_008, pred, linewidth=2.0, color='g',label="Prediction SOC")#线的宽度为2.0，颜色为绿色


# 设置x ,y轴的步长与刻度属性
plt.xticks([x for x in range(len(x_true_soc) + 1) if x %10 == 0])  # x标记step设置为10
plt.ylim(ymin=0.3,ymax=1.1)
# remark for x & y
plt.xlabel('Cylce')
plt.ylabel('SOC')
plt.title('Real Soc and Predicted Soc')

plt.legend()
plt.show()#显示图像
# Out:
# x_true_soc range is  range(0, 132)
#  x_test_soc_008  range is: range(8, 132)
