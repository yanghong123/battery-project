# %% [markdown]
# battery json data  convert to matrix and input to CNN for train,有容量特征字段

# %%
from sklearn import preprocessing 
from scipy.io import loadmat, whosmat
import numpy as np
import datetime
import json
import os
# 获取得到 json data of battery 
def json_load(dictonary):
    with open(dictonary) as f:
        data = json.load(f)
    return data

'''
cycle为行数，循环读取一行数据，对一行数据里面的voltage,current and temp求均值，并添加capacity features
得到battery array
'''
def batteryData2array(battery_data):
    vol_sum = 0
    cur_sum = 0
    temp_sum=0
    battery_array = []
    for cycle in battery_data.keys():
        # list type 
        battery_vols = battery_data[cycle]["voltage_battery"]
        battery_curs = battery_data[cycle]["current_battery"]
        battery_temps=battery_data[cycle]["temp_battery"]
        battery_capacity=battery_data[cycle]["Capacity"]
        for battery_vol in battery_vols:
            vol_sum += float(battery_vol)
        for battery_cur in battery_curs:
            cur_sum += float(battery_cur)
        for battery_temp in battery_temps:
            temp_sum += float(battery_temp)
        #for voltage and current average  & battery_vols,battery_curs,battery_temps's len is equal
        num = len(battery_vols)
        vol_aver = vol_sum / num
        cur_aver = cur_sum / num
        temp_aver=temp_sum/num
        vol_sum = 0
        cur_sum = 0
        temp_sum=0
        battery_array.append([vol_aver,cur_aver,temp_aver,battery_capacity[0]])
#         battery_array.append([vol_aver,cur_aver,battery_capacity[0]])
    return battery_array

# get battery's true soc
def  getTrueSOC(battery_discharge_data):
    batteryCapcity=2
    soc_dict=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        soc_true=cycleCapacity[0]/batteryCapcity
        soc_dict.append(soc_true)
    return soc_dict

# get battery's discgarge capacity
def  getTrueCapacity(battery_discharge_data):
    capacity=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        capacity.append(cycleCapacity[0])
    return capacity

'''
获取得到 battery 's img matrix 图像矩阵  4维特征向量  vol_aver,cur_aver,temp_aver,battery_capacity
返回battery discharge matrix and true soc array
'''
def batterydata2matrix(discharge):
    #get the discharge and charge json data
    discharge_data =json_load(discharge)
    
    #get the true soc data
    true_soc=getTrueSOC(discharge_data)
#   true_capacity=getTrueCapacity(discharge_data)
    #get the battery discharge array data  convert to matrix
    discharge_array = batteryData2array(discharge_data)
    discharge_matrix = np.array(discharge_array)

    discharge_matrix=preprocessing.scale(discharge_matrix)
    return discharge_matrix,true_soc

'''
获取得到每一节电池数据的训练数据集
得到train & test data
'''
def getTrainData(discharge_matrix,true_soc):     
    #循环切片形成数据集
    x=[];y=[]
    x_train=[];y_train=[]
    flag=0

    # 获取得到x,y的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取长度为8的矩阵，叠加循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成4*T的时间维度
            x.append(bataery_data_training.T)
        flag+=1
    #0-》t时刻d x 预测得到t时刻的soc。为了对soc 进行预测，y矩阵为【7：】
    x=x[:len(x)-1]
    y=true_soc[8:]
#     print(len(x))
#     y=true_capacity[8:]

    VALIDATION_SPLIT=0.9
    x_validation_samples = int( VALIDATION_SPLIT* len(x))
    y_validation_samples = int( VALIDATION_SPLIT*len(y))
    
    
    # 获取得到训练集，验证集，比例9:1
    x_train=np.array(x[:x_validation_samples])
    x_test=np.array(x[x_validation_samples:])
    y_train=np.array(y[:y_validation_samples])
    y_test=np.array(y[y_validation_samples:])
    print("x_train's shape is:", x_train.shape,"，y_train's shape is:",y_train.shape)
    print("x_test's shape is:",x_test.shape,"，y_test's shape is:",y_test.shape)
    return x_train,x_test,y_train,y_test

# %%
# 定义全局变量，将所有电池数据集集合起来，形成训练集，测试集
# x_train_all,x_test_all,y_train_all,y_test_all=[],[],[],[]
for i in range(5,8):
    #/home/aqts/yangHong/battery experiment/jsonData
    discharge=r'/home/aqts/yangHong/battery experiment/jsonData/B000'+str(i)+'_discharge.json'
    discharge_matrix,true_soc=batterydata2matrix(discharge)
    train_x,test_x,train_y,test_y=getTrainData(discharge_matrix,true_soc)
    # start 开始时先赋值给x_train_all，x_test_all，y_train_all，y_test_all
    if i==5:
        x_train_all=train_x
        x_test_all=test_x
        y_train_all=train_y
        y_test_all=test_y
    else:
        x_train_all=np.concatenate((x_train_all,train_x),axis=0)
        x_test_all=np.concatenate((x_test_all,test_x),axis=0)
        y_train_all=np.concatenate((y_train_all,train_y),axis=0)
        y_test_all=np.concatenate((y_test_all,test_y),axis=0)
print(np.array(x_train_all).shape,np.array(x_test_all).shape,np.array(y_train_all).shape,np.array(y_test_all).shape)
# Out:
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (16, 4, 8) ，y_test's shape is: (16,)
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (16, 4, 8) ，y_test's shape is: (16,)
# x_train's shape is: (144, 4, 8) ，y_train's shape is: (144,)
# x_test's shape is: (16, 4, 8) ，y_test's shape is: (16,)
# (432, 4, 8) (48, 4, 8) (432,) (48,)

# %%
#写一个LossHistory类，保存loss和mae
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as k
import matplotlib.pyplot as plt
import numpy as np
from keras import backend as K
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = {'batch':[], 'epoch':[]}
        self.accuracy = {'batch':[], 'epoch':[]}
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_acc = {'batch':[], 'epoch':[]}

    def on_batch_end(self, batch, logs={}):
        self.losses['batch'].append(logs.get('loss'))
        self.accuracy['batch'].append(logs.get('mean_absolute_error'))
        self.val_loss['batch'].append(logs.get('val_loss'))
        self.val_acc['batch'].append(logs.get('val_mean_absolute_error'))

    def on_epoch_end(self, batch, logs={}):
        self.losses['epoch'].append(logs.get('loss'))
        self.accuracy['epoch'].append(logs.get('mean_absolute_error'))
        self.val_loss['epoch'].append(logs.get('val_loss'))
        self.val_acc['epoch'].append(logs.get('val_mean_absolute_error'))

    def loss_plot(self, loss_type):
        iters = range(len(self.losses[loss_type]))
        plt.figure()
        # mae
        plt.plot(iters, self.accuracy[loss_type], 'r', label='train mae')
        # loss
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        if loss_type == 'epoch':
            # val_mean_absolute_error
            plt.plot(iters, self.val_acc[loss_type], 'b', label='val mean absolute error')
            # val_loss
            plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('mae-loss')
        plt.legend(loc="upper right")
        plt.show()
# Out:
# /home/aqts/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#使用cnn训练的模型
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras import regularizers
from keras.optimizers import SGD, Adam
from keras.layers.normalization import BatchNormalization

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
num=1
img_rows, img_cols =x_train_all.shape[1],x_train_all.shape[2]
if K.image_dim_ordering() == 'th':
    x_train_all = x_train_all.reshape(x_train_all.shape[0], 1, img_rows, img_cols)
    x_test_all = x_test_all.reshape(x_test_all.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train_all = x_train_all.reshape(x_train_all.shape[0], img_rows, img_cols, 1)
    x_test_all= x_test_all.reshape(x_test_all.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)
# print(x_train.shape,x_test.shape)
# print(y_train.shape)
# keras序贯模型搭建CNN
# model building
model = Sequential()
#convolutional layer with rectified linear unit activation
model.add(Conv2D(64, kernel_size=(1,2),
                 activation='relu',
                 input_shape=input_shape,padding="same"))
#32 convolution filters used each of size 3x3
#again
model.add(Conv2D(128, (2,2), activation='relu',padding="same"))
#64 convolution filters used each of size 3x3
#choose the best features via pooling
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (2,1), activation='relu',padding="same"))

model.add(Conv2D(64, (2,2), activation='relu',padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
#randomly turn neurons on and off to improve convergence
# model.add(Dropout(0.30))
#flatten since too many dimensions, we only want a classification output
model.add(Flatten())
#fully connected to get all relevant data
model.add(Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
model.add(Dropout(0.20))

model.add(Dense(16, activation='relu'))
model.add(Dropout(0.20))
# model.add(Dense(num, activation='sigmoid'))
# The last layer does not use the activation function
model.add(Dense(num))

#Adaptive learning rate (adaDelta) is a popular form of gradient descent rivaled only by adam and adagrad
#categorical ce since we have multiple classes (10) 
# model.compile(loss=keras.losses.sparse_categorical_crossentropy,
#               optimizer=keras.optimizers.Adadelta(),
#               metrics=['accuracy'])
#回归问题评价指标使用mae
# sgd=SGD(lr=0.01, momentum=0.0, decay=1, nesterov=False)
sgd=SGD(lr=0.01, momentum=0.90, decay=1e-06, nesterov=False)
adma=Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
model.compile(loss='mse', optimizer=sgd, metrics=["mae"])

model.summary()
batch_size =16
num_epoch = 128



# decay_rate = learning_rate / num_epoch
# momentum = 0.8
# sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)

# model.compile(loss='mse', optimizer=sgd, metrics=["mae"])
#model training
history = LossHistory()
model.fit(x_train_all, y_train_all,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,validation_split=0.3,callbacks=[history])

mse_score,mae_score= model.evaluate(x_test_all, y_test_all, verbose=0)
print('Test MSE Score:%.3f %%'% (mse_score*100)) 
print('Test MAE Score:%.3f %%'% (mae_score*100))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_65 (Conv2D)           (None, 4, 8, 64)          192
# _________________________________________________________________
# conv2d_66 (Conv2D)           (None, 4, 8, 128)         32896
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 2, 4, 128)         0
# _________________________________________________________________
# conv2d_67 (Conv2D)           (None, 2, 4, 32)          8224
# _________________________________________________________________
# conv2d_68 (Conv2D)           (None, 2, 4, 64)          8256
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 1, 2, 64)          0
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_49 (Dense)             (None, 16)                2064
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_50 (Dense)             (None, 16)                272
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_51 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 51,921
# Trainable params: 51,921
# Non-trainable params: 0
# _________________________________________________________________
# Train on 302 samples, validate on 130 samples
# Epoch 1/128
# 302/302 [==============================] - 2s 5ms/step - loss: 0.1959 - mean_absolute_error: 0.3294 - val_loss: 0.0423 - val_mean_absolute_error: 0.0994
# Epoch 2/128
# 302/302 [==============================] - 0s 466us/step - loss: 0.0492 - mean_absolute_error: 0.1151 - val_loss: 0.0316 - val_mean_absolute_error: 0.0491
# Epoch 3/128
# 302/302 [==============================] - 0s 476us/step - loss: 0.0399 - mean_absolute_error: 0.0856 - val_loss: 0.0315 - val_mean_absolute_error: 0.0495
# Epoch 4/128
# 302/302 [==============================] - 0s 467us/step - loss: 0.0394 - mean_absolute_error: 0.0854 - val_loss: 0.0314 - val_mean_absolute_error: 0.0488
# Epoch 5/128
# 302/302 [==============================] - 0s 443us/step - loss: 0.0373 - mean_absolute_error: 0.0781 - val_loss: 0.0301 - val_mean_absolute_error: 0.0407
# Epoch 6/128
# 302/302 [==============================] - 0s 449us/step - loss: 0.0351 - mean_absolute_error: 0.0679 - val_loss: 0.0298 - val_mean_absolute_error: 0.0405
# Epoch 7/128
# 302/302 [==============================] - 0s 476us/step - loss: 0.0336 - mean_absolute_error: 0.0616 - val_loss: 0.0284 - val_mean_absolute_error: 0.0276
# Epoch 8/128
# 302/302 [==============================] - 0s 469us/step - loss: 0.0328 - mean_absolute_error: 0.0570 - val_loss: 0.0280 - val_mean_absolute_error: 0.0257
# Epoch 9/128
# 302/302 [==============================] - 0s 448us/step - loss: 0.0314 - mean_absolute_error: 0.0524 - val_loss: 0.0286 - val_mean_absolute_error: 0.0384
# Epoch 10/128
# 302/302 [==============================] - 0s 429us/step - loss: 0.0309 - mean_absolute_error: 0.0489 - val_loss: 0.0278 - val_mean_absolute_error: 0.0293
# Epoch 11/128
# 302/302 [==============================] - 0s 459us/step - loss: 0.0309 - mean_absolute_error: 0.0508 - val_loss: 0.0278 - val_mean_absolute_error: 0.0324
# Epoch 12/128
# 302/302 [==============================] - 0s 473us/step - loss: 0.0298 - mean_absolute_error: 0.0447 - val_loss: 0.0271 - val_mean_absolute_error: 0.0253
# Epoch 13/128
# 302/302 [==============================] - 0s 443us/step - loss: 0.0294 - mean_absolute_error: 0.0430 - val_loss: 0.0270 - val_mean_absolute_error: 0.0258
# Epoch 14/128
# 302/302 [==============================] - 0s 447us/step - loss: 0.0291 - mean_absolute_error: 0.0431 - val_loss: 0.0273 - val_mean_absolute_error: 0.0340
# Epoch 15/128
# 302/302 [==============================] - 0s 451us/step - loss: 0.0291 - mean_absolute_error: 0.0437 - val_loss: 0.0271 - val_mean_absolute_error: 0.0333
# Epoch 16/128
# 302/302 [==============================] - 0s 464us/step - loss: 0.0285 - mean_absolute_error: 0.0396 - val_loss: 0.0265 - val_mean_absolute_error: 0.0272
# Epoch 17/128
# 302/302 [==============================] - 0s 435us/step - loss: 0.0287 - mean_absolute_error: 0.0438 - val_loss: 0.0269 - val_mean_absolute_error: 0.0362
# Epoch 18/128
# 302/302 [==============================] - 0s 418us/step - loss: 0.0280 - mean_absolute_error: 0.0396 - val_loss: 0.0264 - val_mean_absolute_error: 0.0311
# Epoch 19/128
# 302/302 [==============================] - 0s 425us/step - loss: 0.0275 - mean_absolute_error: 0.0385 - val_loss: 0.0265 - val_mean_absolute_error: 0.0353
# Epoch 20/128
# 302/302 [==============================] - 0s 416us/step - loss: 0.0273 - mean_absolute_error: 0.0382 - val_loss: 0.0261 - val_mean_absolute_error: 0.0333
# Epoch 21/128
# 302/302 [==============================] - 0s 475us/step - loss: 0.0270 - mean_absolute_error: 0.0369 - val_loss: 0.0259 - val_mean_absolute_error: 0.0327
# Epoch 22/128
# 302/302 [==============================] - 0s 437us/step - loss: 0.0277 - mean_absolute_error: 0.0426 - val_loss: 0.0262 - val_mean_absolute_error: 0.0390
# Epoch 23/128
# 302/302 [==============================] - 0s 415us/step - loss: 0.0266 - mean_absolute_error: 0.0371 - val_loss: 0.0263 - val_mean_absolute_error: 0.0437
# Epoch 24/128
# 302/302 [==============================] - 0s 440us/step - loss: 0.0268 - mean_absolute_error: 0.0399 - val_loss: 0.0259 - val_mean_absolute_error: 0.0402
# Epoch 25/128
# 302/302 [==============================] - 0s 428us/step - loss: 0.0265 - mean_absolute_error: 0.0373 - val_loss: 0.0249 - val_mean_absolute_error: 0.0282
# Epoch 26/128
# 302/302 [==============================] - 0s 466us/step - loss: 0.0260 - mean_absolute_error: 0.0344 - val_loss: 0.0252 - val_mean_absolute_error: 0.0355
# Epoch 27/128
# 302/302 [==============================] - 0s 460us/step - loss: 0.0262 - mean_absolute_error: 0.0385 - val_loss: 0.0256 - val_mean_absolute_error: 0.0431
# Epoch 28/128
# 302/302 [==============================] - 0s 449us/step - loss: 0.0257 - mean_absolute_error: 0.0355 - val_loss: 0.0248 - val_mean_absolute_error: 0.0346
# Epoch 29/128
# 302/302 [==============================] - 0s 466us/step - loss: 0.0257 - mean_absolute_error: 0.0364 - val_loss: 0.0249 - val_mean_absolute_error: 0.0376
# Epoch 30/128
# 302/302 [==============================] - 0s 468us/step - loss: 0.0253 - mean_absolute_error: 0.0362 - val_loss: 0.0240 - val_mean_absolute_error: 0.0275
# Epoch 31/128
# 302/302 [==============================] - 0s 448us/step - loss: 0.0251 - mean_absolute_error: 0.0364 - val_loss: 0.0250 - val_mean_absolute_error: 0.0447
# Epoch 32/128
# 302/302 [==============================] - 0s 477us/step - loss: 0.0251 - mean_absolute_error: 0.0359 - val_loss: 0.0238 - val_mean_absolute_error: 0.0304
# Epoch 33/128
# 302/302 [==============================] - 0s 436us/step - loss: 0.0245 - mean_absolute_error: 0.0339 - val_loss: 0.0245 - val_mean_absolute_error: 0.0418
# Epoch 34/128
# 302/302 [==============================] - 0s 467us/step - loss: 0.0243 - mean_absolute_error: 0.0346 - val_loss: 0.0237 - val_mean_absolute_error: 0.0343
# Epoch 35/128
# 302/302 [==============================] - 0s 478us/step - loss: 0.0242 - mean_absolute_error: 0.0325 - val_loss: 0.0237 - val_mean_absolute_error: 0.0371
# Epoch 36/128
# 302/302 [==============================] - 0s 444us/step - loss: 0.0238 - mean_absolute_error: 0.0325 - val_loss: 0.0238 - val_mean_absolute_error: 0.0397
# Epoch 37/128
# 302/302 [==============================] - 0s 454us/step - loss: 0.0237 - mean_absolute_error: 0.0333 - val_loss: 0.0234 - val_mean_absolute_error: 0.0369
# Epoch 38/128
# 302/302 [==============================] - 0s 448us/step - loss: 0.0237 - mean_absolute_error: 0.0346 - val_loss: 0.0234 - val_mean_absolute_error: 0.0394
# Epoch 39/128
# 302/302 [==============================] - 0s 436us/step - loss: 0.0234 - mean_absolute_error: 0.0333 - val_loss: 0.0224 - val_mean_absolute_error: 0.0268
# Epoch 40/128
# 302/302 [==============================] - 0s 423us/step - loss: 0.0233 - mean_absolute_error: 0.0331 - val_loss: 0.0233 - val_mean_absolute_error: 0.0438
# Epoch 41/128
# 302/302 [==============================] - 0s 451us/step - loss: 0.0231 - mean_absolute_error: 0.0330 - val_loss: 0.0230 - val_mean_absolute_error: 0.0402
# Epoch 42/128
# 302/302 [==============================] - 0s 416us/step - loss: 0.0230 - mean_absolute_error: 0.0319 - val_loss: 0.0230 - val_mean_absolute_error: 0.0426
# Epoch 43/128
# 302/302 [==============================] - 0s 463us/step - loss: 0.0229 - mean_absolute_error: 0.0321 - val_loss: 0.0223 - val_mean_absolute_error: 0.0355
# Epoch 44/128
# 302/302 [==============================] - 0s 442us/step - loss: 0.0226 - mean_absolute_error: 0.0327 - val_loss: 0.0227 - val_mean_absolute_error: 0.0431
# Epoch 45/128
# 302/302 [==============================] - 0s 453us/step - loss: 0.0226 - mean_absolute_error: 0.0335 - val_loss: 0.0216 - val_mean_absolute_error: 0.0294
# Epoch 46/128
# 302/302 [==============================] - 0s 442us/step - loss: 0.0222 - mean_absolute_error: 0.0321 - val_loss: 0.0224 - val_mean_absolute_error: 0.0423
# Epoch 47/128
# 302/302 [==============================] - 0s 470us/step - loss: 0.0221 - mean_absolute_error: 0.0308 - val_loss: 0.0221 - val_mean_absolute_error: 0.0407
# Epoch 48/128
# 302/302 [==============================] - 0s 438us/step - loss: 0.0219 - mean_absolute_error: 0.0318 - val_loss: 0.0225 - val_mean_absolute_error: 0.0474
# Epoch 49/128
# 302/302 [==============================] - 0s 439us/step - loss: 0.0213 - mean_absolute_error: 0.0275 - val_loss: 0.0215 - val_mean_absolute_error: 0.0374
# Epoch 50/128
# 302/302 [==============================] - 0s 462us/step - loss: 0.0214 - mean_absolute_error: 0.0290 - val_loss: 0.0215 - val_mean_absolute_error: 0.0400
# Epoch 51/128
# 302/302 [==============================] - 0s 440us/step - loss: 0.0215 - mean_absolute_error: 0.0321 - val_loss: 0.0214 - val_mean_absolute_error: 0.0404
# Epoch 52/128
# 302/302 [==============================] - 0s 465us/step - loss: 0.0216 - mean_absolute_error: 0.0338 - val_loss: 0.0210 - val_mean_absolute_error: 0.0360
# Epoch 53/128
# 302/302 [==============================] - 0s 448us/step - loss: 0.0214 - mean_absolute_error: 0.0326 - val_loss: 0.0215 - val_mean_absolute_error: 0.0439
# Epoch 54/128
# 302/302 [==============================] - 0s 448us/step - loss: 0.0209 - mean_absolute_error: 0.0294 - val_loss: 0.0208 - val_mean_absolute_error: 0.0381
# Epoch 55/128
# 302/302 [==============================] - 0s 455us/step - loss: 0.0208 - mean_absolute_error: 0.0299 - val_loss: 0.0207 - val_mean_absolute_error: 0.0380
# Epoch 56/128
# 302/302 [==============================] - 0s 429us/step - loss: 0.0208 - mean_absolute_error: 0.0316 - val_loss: 0.0206 - val_mean_absolute_error: 0.0384
# Epoch 57/128
# 302/302 [==============================] - 0s 470us/step - loss: 0.0204 - mean_absolute_error: 0.0299 - val_loss: 0.0202 - val_mean_absolute_error: 0.0349
# Epoch 58/128
# 302/302 [==============================] - 0s 460us/step - loss: 0.0209 - mean_absolute_error: 0.0350 - val_loss: 0.0202 - val_mean_absolute_error: 0.0378
# Epoch 59/128
# 302/302 [==============================] - 0s 446us/step - loss: 0.0204 - mean_absolute_error: 0.0328 - val_loss: 0.0205 - val_mean_absolute_error: 0.0430
# Epoch 60/128
# 302/302 [==============================] - 0s 434us/step - loss: 0.0200 - mean_absolute_error: 0.0288 - val_loss: 0.0196 - val_mean_absolute_error: 0.0318
# Epoch 61/128
# 302/302 [==============================] - 0s 456us/step - loss: 0.0199 - mean_absolute_error: 0.0289 - val_loss: 0.0200 - val_mean_absolute_error: 0.0408
# Epoch 62/128
# 302/302 [==============================] - 0s 456us/step - loss: 0.0201 - mean_absolute_error: 0.0320 - val_loss: 0.0196 - val_mean_absolute_error: 0.0366
# Epoch 63/128
# 302/302 [==============================] - 0s 471us/step - loss: 0.0195 - mean_absolute_error: 0.0294 - val_loss: 0.0195 - val_mean_absolute_error: 0.0378
# Epoch 64/128
# 302/302 [==============================] - 0s 458us/step - loss: 0.0196 - mean_absolute_error: 0.0320 - val_loss: 0.0192 - val_mean_absolute_error: 0.0349
# Epoch 65/128
# 302/302 [==============================] - 0s 446us/step - loss: 0.0192 - mean_absolute_error: 0.0292 - val_loss: 0.0194 - val_mean_absolute_error: 0.0409
# Epoch 66/128
# 302/302 [==============================] - 0s 436us/step - loss: 0.0194 - mean_absolute_error: 0.0319 - val_loss: 0.0194 - val_mean_absolute_error: 0.0424
# Epoch 67/128
# 302/302 [==============================] - 0s 490us/step - loss: 0.0190 - mean_absolute_error: 0.0297 - val_loss: 0.0193 - val_mean_absolute_error: 0.0417
# Epoch 68/128
# 302/302 [==============================] - 0s 447us/step - loss: 0.0191 - mean_absolute_error: 0.0311 - val_loss: 0.0187 - val_mean_absolute_error: 0.0358
# Epoch 69/128
# 302/302 [==============================] - 0s 420us/step - loss: 0.0189 - mean_absolute_error: 0.0310 - val_loss: 0.0190 - val_mean_absolute_error: 0.0409
# Epoch 70/128
# 302/302 [==============================] - 0s 477us/step - loss: 0.0189 - mean_absolute_error: 0.0316 - val_loss: 0.0192 - val_mean_absolute_error: 0.0458
# Epoch 71/128
# 302/302 [==============================] - 0s 437us/step - loss: 0.0186 - mean_absolute_error: 0.0310 - val_loss: 0.0180 - val_mean_absolute_error: 0.0312
# Epoch 72/128
# 302/302 [==============================] - 0s 475us/step - loss: 0.0186 - mean_absolute_error: 0.0317 - val_loss: 0.0185 - val_mean_absolute_error: 0.0385
# Epoch 73/128
# 302/302 [==============================] - 0s 429us/step - loss: 0.0186 - mean_absolute_error: 0.0322 - val_loss: 0.0187 - val_mean_absolute_error: 0.0442
# Epoch 74/128
# 302/302 [==============================] - 0s 437us/step - loss: 0.0183 - mean_absolute_error: 0.0320 - val_loss: 0.0183 - val_mean_absolute_error: 0.0416
# Epoch 75/128
# 302/302 [==============================] - 0s 424us/step - loss: 0.0183 - mean_absolute_error: 0.0313 - val_loss: 0.0182 - val_mean_absolute_error: 0.0406
# Epoch 76/128
# 302/302 [==============================] - 0s 463us/step - loss: 0.0182 - mean_absolute_error: 0.0328 - val_loss: 0.0187 - val_mean_absolute_error: 0.0470
# Epoch 77/128
# 302/302 [==============================] - 0s 431us/step - loss: 0.0179 - mean_absolute_error: 0.0307 - val_loss: 0.0180 - val_mean_absolute_error: 0.0414
# Epoch 78/128
# 302/302 [==============================] - 0s 462us/step - loss: 0.0175 - mean_absolute_error: 0.0292 - val_loss: 0.0173 - val_mean_absolute_error: 0.0332
# Epoch 79/128
# 302/302 [==============================] - 0s 462us/step - loss: 0.0180 - mean_absolute_error: 0.0335 - val_loss: 0.0185 - val_mean_absolute_error: 0.0493
# Epoch 80/128
# 302/302 [==============================] - 0s 486us/step - loss: 0.0175 - mean_absolute_error: 0.0305 - val_loss: 0.0176 - val_mean_absolute_error: 0.0411
# Epoch 81/128
# 302/302 [==============================] - 0s 462us/step - loss: 0.0172 - mean_absolute_error: 0.0281 - val_loss: 0.0178 - val_mean_absolute_error: 0.0449
# Epoch 82/128
# 302/302 [==============================] - 0s 454us/step - loss: 0.0172 - mean_absolute_error: 0.0310 - val_loss: 0.0171 - val_mean_absolute_error: 0.0366
# Epoch 83/128
# 302/302 [==============================] - 0s 445us/step - loss: 0.0172 - mean_absolute_error: 0.0315 - val_loss: 0.0172 - val_mean_absolute_error: 0.0402
# Epoch 84/128
# 302/302 [==============================] - 0s 457us/step - loss: 0.0172 - mean_absolute_error: 0.0315 - val_loss: 0.0170 - val_mean_absolute_error: 0.0396
# Epoch 85/128
# 302/302 [==============================] - 0s 453us/step - loss: 0.0170 - mean_absolute_error: 0.0310 - val_loss: 0.0170 - val_mean_absolute_error: 0.0395
# Epoch 86/128
# 302/302 [==============================] - 0s 464us/step - loss: 0.0167 - mean_absolute_error: 0.0296 - val_loss: 0.0168 - val_mean_absolute_error: 0.0388
# Epoch 87/128
# 302/302 [==============================] - 0s 455us/step - loss: 0.0164 - mean_absolute_error: 0.0283 - val_loss: 0.0167 - val_mean_absolute_error: 0.0401
# Epoch 88/128
# 302/302 [==============================] - 0s 470us/step - loss: 0.0165 - mean_absolute_error: 0.0304 - val_loss: 0.0165 - val_mean_absolute_error: 0.0354
# Epoch 89/128
# 302/302 [==============================] - 0s 444us/step - loss: 0.0164 - mean_absolute_error: 0.0303 - val_loss: 0.0165 - val_mean_absolute_error: 0.0404
# Epoch 90/128
# 302/302 [==============================] - 0s 474us/step - loss: 0.0160 - mean_absolute_error: 0.0285 - val_loss: 0.0169 - val_mean_absolute_error: 0.0468
# Epoch 91/128
# 302/302 [==============================] - 0s 449us/step - loss: 0.0163 - mean_absolute_error: 0.0310 - val_loss: 0.0166 - val_mean_absolute_error: 0.0441
# Epoch 92/128
# 302/302 [==============================] - 0s 451us/step - loss: 0.0160 - mean_absolute_error: 0.0297 - val_loss: 0.0162 - val_mean_absolute_error: 0.0394
# Epoch 93/128
# 302/302 [==============================] - 0s 427us/step - loss: 0.0159 - mean_absolute_error: 0.0304 - val_loss: 0.0165 - val_mean_absolute_error: 0.0453
# Epoch 94/128
# 302/302 [==============================] - 0s 460us/step - loss: 0.0161 - mean_absolute_error: 0.0312 - val_loss: 0.0165 - val_mean_absolute_error: 0.0473
# Epoch 95/128
# 302/302 [==============================] - 0s 441us/step - loss: 0.0158 - mean_absolute_error: 0.0297 - val_loss: 0.0153 - val_mean_absolute_error: 0.0321
# Epoch 96/128
# 302/302 [==============================] - 0s 414us/step - loss: 0.0157 - mean_absolute_error: 0.0309 - val_loss: 0.0159 - val_mean_absolute_error: 0.0429
# Epoch 97/128
# 302/302 [==============================] - 0s 444us/step - loss: 0.0156 - mean_absolute_error: 0.0310 - val_loss: 0.0161 - val_mean_absolute_error: 0.0457
# Epoch 98/128
# 302/302 [==============================] - 0s 453us/step - loss: 0.0153 - mean_absolute_error: 0.0286 - val_loss: 0.0157 - val_mean_absolute_error: 0.0430
# Epoch 99/128
# 302/302 [==============================] - 0s 476us/step - loss: 0.0154 - mean_absolute_error: 0.0305 - val_loss: 0.0155 - val_mean_absolute_error: 0.0403
# Epoch 100/128
# 302/302 [==============================] - 0s 460us/step - loss: 0.0152 - mean_absolute_error: 0.0294 - val_loss: 0.0155 - val_mean_absolute_error: 0.0426
# Epoch 101/128
# 302/302 [==============================] - 0s 460us/step - loss: 0.0148 - mean_absolute_error: 0.0266 - val_loss: 0.0152 - val_mean_absolute_error: 0.0401
# Epoch 102/128
# 302/302 [==============================] - 0s 465us/step - loss: 0.0149 - mean_absolute_error: 0.0288 - val_loss: 0.0156 - val_mean_absolute_error: 0.0460
# Epoch 103/128
# 302/302 [==============================] - 0s 475us/step - loss: 0.0147 - mean_absolute_error: 0.0286 - val_loss: 0.0153 - val_mean_absolute_error: 0.0434
# Epoch 104/128
# 302/302 [==============================] - 0s 434us/step - loss: 0.0149 - mean_absolute_error: 0.0297 - val_loss: 0.0152 - val_mean_absolute_error: 0.0429
# Epoch 105/128
# 302/302 [==============================] - 0s 460us/step - loss: 0.0145 - mean_absolute_error: 0.0279 - val_loss: 0.0150 - val_mean_absolute_error: 0.0429
# Epoch 106/128
# 302/302 [==============================] - 0s 425us/step - loss: 0.0147 - mean_absolute_error: 0.0316 - val_loss: 0.0149 - val_mean_absolute_error: 0.0427
# Epoch 107/128
# 302/302 [==============================] - 0s 434us/step - loss: 0.0145 - mean_absolute_error: 0.0291 - val_loss: 0.0148 - val_mean_absolute_error: 0.0406
# Epoch 108/128
# 302/302 [==============================] - 0s 458us/step - loss: 0.0145 - mean_absolute_error: 0.0309 - val_loss: 0.0145 - val_mean_absolute_error: 0.0401
# Epoch 109/128
# 302/302 [==============================] - 0s 463us/step - loss: 0.0143 - mean_absolute_error: 0.0291 - val_loss: 0.0147 - val_mean_absolute_error: 0.0431
# Epoch 110/128
# 302/302 [==============================] - 0s 468us/step - loss: 0.0143 - mean_absolute_error: 0.0292 - val_loss: 0.0142 - val_mean_absolute_error: 0.0386
# Epoch 111/128
# 302/302 [==============================] - 0s 446us/step - loss: 0.0140 - mean_absolute_error: 0.0284 - val_loss: 0.0142 - val_mean_absolute_error: 0.0398
# Epoch 112/128
# 302/302 [==============================] - 0s 450us/step - loss: 0.0141 - mean_absolute_error: 0.0314 - val_loss: 0.0143 - val_mean_absolute_error: 0.0421
# Epoch 113/128
# 302/302 [==============================] - 0s 451us/step - loss: 0.0140 - mean_absolute_error: 0.0298 - val_loss: 0.0143 - val_mean_absolute_error: 0.0426
# Epoch 114/128
# 302/302 [==============================] - 0s 436us/step - loss: 0.0138 - mean_absolute_error: 0.0293 - val_loss: 0.0139 - val_mean_absolute_error: 0.0398
# Epoch 115/128
# 302/302 [==============================] - 0s 433us/step - loss: 0.0135 - mean_absolute_error: 0.0280 - val_loss: 0.0140 - val_mean_absolute_error: 0.0417
# Epoch 116/128
# 302/302 [==============================] - 0s 436us/step - loss: 0.0136 - mean_absolute_error: 0.0292 - val_loss: 0.0139 - val_mean_absolute_error: 0.0414
# Epoch 117/128
# 302/302 [==============================] - 0s 466us/step - loss: 0.0135 - mean_absolute_error: 0.0293 - val_loss: 0.0138 - val_mean_absolute_error: 0.0419
# Epoch 118/128
# 302/302 [==============================] - 0s 423us/step - loss: 0.0135 - mean_absolute_error: 0.0293 - val_loss: 0.0132 - val_mean_absolute_error: 0.0339
# Epoch 119/128
# 302/302 [==============================] - 0s 462us/step - loss: 0.0136 - mean_absolute_error: 0.0315 - val_loss: 0.0133 - val_mean_absolute_error: 0.0377
# Epoch 120/128
# 302/302 [==============================] - 0s 463us/step - loss: 0.0132 - mean_absolute_error: 0.0291 - val_loss: 0.0137 - val_mean_absolute_error: 0.0443
# Epoch 121/128
# 302/302 [==============================] - 0s 488us/step - loss: 0.0133 - mean_absolute_error: 0.0308 - val_loss: 0.0137 - val_mean_absolute_error: 0.0448
# Epoch 122/128
# 302/302 [==============================] - 0s 440us/step - loss: 0.0129 - mean_absolute_error: 0.0277 - val_loss: 0.0130 - val_mean_absolute_error: 0.0367
# Epoch 123/128
# 302/302 [==============================] - 0s 436us/step - loss: 0.0129 - mean_absolute_error: 0.0292 - val_loss: 0.0138 - val_mean_absolute_error: 0.0470
# Epoch 124/128
# 302/302 [==============================] - 0s 452us/step - loss: 0.0129 - mean_absolute_error: 0.0284 - val_loss: 0.0127 - val_mean_absolute_error: 0.0350
# Epoch 125/128
# 302/302 [==============================] - 0s 454us/step - loss: 0.0128 - mean_absolute_error: 0.0276 - val_loss: 0.0130 - val_mean_absolute_error: 0.0402
# Epoch 126/128
# 302/302 [==============================] - 0s 438us/step - loss: 0.0126 - mean_absolute_error: 0.0295 - val_loss: 0.0130 - val_mean_absolute_error: 0.0409
# Epoch 127/128
# 302/302 [==============================] - 0s 434us/step - loss: 0.0128 - mean_absolute_error: 0.0308 - val_loss: 0.0132 - val_mean_absolute_error: 0.0437
# Epoch 128/128
# 302/302 [==============================] - 0s 434us/step - loss: 0.0125 - mean_absolute_error: 0.0281 - val_loss: 0.0129 - val_mean_absolute_error: 0.0417
# Test MSE Score:1.363 %
# Test MAE Score:4.422 %

# %%
#绘制mae-loss曲线
history.loss_plot('epoch')

# %% [markdown]
# 获取得到需要用于预测的电池数据集B0018号电池

# %%
# 获取预测所需的电池数据集
def getBattery008data(discharge_matrix):
    x_pred=[]
    flag=0

    # 获取得到x_pred的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取0--37这段的长度，叠加+1循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成3*T的时间维度
            x_pred.append(bataery_data_training.T)
        flag+=1

    x_pred=np.array(x_pred[:len(x_pred)-1])
    return x_pred

# return prediction  data &  prediction  data true_so
discharge_008=r'/home/aqts/yangHong/battery experiment/jsonData/B0008_discharge.json'
# 获取得到一节电池的 特征向量 与true soc 
discharge_matrix_008,true_soc_008 =batterydata2matrix(discharge_008)
print(len(discharge_matrix_008),len(true_soc_008))
# 得到预测样本集 t=7
x_test_008=getBattery008data(discharge_matrix_008)


print("x_test_008 data shape is",x_test_008.shape)
# 预测数据集进行转换
if K.image_dim_ordering() == 'th':
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_test_008 = x_test_008.reshape(x_test_008.shape[0], img_rows, img_cols,1)
    input_shape = (img_rows, img_cols, 1)
# Out:
# 132 132
# x_test_008 data shape is (124, 4, 8)

# %%
pred=model.predict(x_test_008, batch_size=16, verbose=0)
print(pred.shape)
# Out:
# (124, 1)

# %%
import pandas as pd # 导入pandas库用来处理csv文件
import matplotlib.pyplot as plt # 导入matplotlib.pyplot并用plt简称

# true soc predict plot
x_true_soc=range(len(true_soc_008))
# 切割开始的基数一定为7
start=8
x_test_soc_008=range(start,start+pred.shape[0])
print("x_true_soc range is ",x_true_soc,"\n x_test_soc_008  range is:",x_test_soc_008)
plt.plot(x_true_soc, true_soc_008, linewidth=2.0, color='r',label="True SOC")#线的宽度为2.0，颜色为红色
plt.plot(x_test_soc_008, pred, linewidth=2.0, color='g',label="Prediction SOC")#线的宽度为2.0，颜色为绿色


# 设置x ,y轴的步长与刻度属性
plt.xticks([x for x in range(len(x_true_soc) + 1) if x %10 == 0])  # x标记step设置为10
plt.ylim(ymin=0.3,ymax=1.1)
# remark for x & y
plt.xlabel('Cylce')
plt.ylabel('SOC')
plt.title('Real Soc and Predicted Soc')

plt.legend()
plt.show()#显示图像
# Out:
# x_true_soc range is  range(0, 132)
#  x_test_soc_008  range is: range(8, 132)
