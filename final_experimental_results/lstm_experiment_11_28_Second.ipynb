# %% [markdown]
# battery json data  convert to matrix and input to CNN for train,no capacity feature

# %%
from sklearn import preprocessing 
from scipy.io import loadmat, whosmat
import numpy as np
import datetime
import json
import os
# 获取得到 json data of battery 
def json_load(dictonary):
    with open(dictonary) as f:
        data = json.load(f)
    return data

'''
cycle为行数，循环读取一行数据，对一行数据里面的voltage,current and temp求均值，并添加capacity features
得到battery array
'''
def batteryData2array(battery_data):
    vol_sum = 0
    cur_sum = 0
    temp_sum=0
    battery_array = []
    for cycle in battery_data.keys():
        # list type 
        battery_vols = battery_data[cycle]["voltage_battery"]
        battery_curs = battery_data[cycle]["current_battery"]
        battery_temps=battery_data[cycle]["temp_battery"]
        battery_capacity=battery_data[cycle]["Capacity"]
        for battery_vol in battery_vols:
            vol_sum += float(battery_vol)
        for battery_cur in battery_curs:
            cur_sum += float(battery_cur)
        for battery_temp in battery_temps:
            temp_sum += float(battery_temp)
        #for voltage and current average  & battery_vols,battery_curs,battery_temps's len is equal
        num = len(battery_vols)
        vol_aver = vol_sum / num
        cur_aver = cur_sum / num
        temp_aver=temp_sum/num
        vol_sum = 0
        cur_sum = 0
        temp_sum=0
#         battery_array.append([vol_aver,cur_aver,temp_aver,battery_capacity[0]])
        battery_array.append([vol_aver,cur_aver,temp_aver])
    return battery_array

# get battery's true soc
def  getTrueSOC(battery_discharge_data):
    batteryCapcity=2
    soc_dict=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        soc_true=cycleCapacity[0]/batteryCapcity
        soc_dict.append(soc_true)
    return soc_dict

# get battery's discgarge capacity
def  getTrueCapacity(battery_discharge_data):
    capacity=[]
    for cycle in battery_discharge_data.keys():
        cycleCapacity=battery_discharge_data[cycle]["Capacity"]
        capacity.append(cycleCapacity[0])
    return capacity

'''
获取得到 battery 's img matrix 图像矩阵  4维特征向量  vol_aver,cur_aver,temp_aver,battery_capacity
返回battery discharge matrix and true soc array
'''
def batterydata2matrix(discharge):
    #get the discharge and charge json data
    discharge_data =json_load(discharge)
    
    #get the true soc data
    true_soc=getTrueSOC(discharge_data)
#   true_capacity=getTrueCapacity(discharge_data)
    #get the battery discharge array data  convert to matrix
    discharge_array = batteryData2array(discharge_data)
    discharge_matrix = np.array(discharge_array)

    discharge_matrix=preprocessing.scale(discharge_matrix)
    return discharge_matrix,true_soc

'''
获取得到每一节电池数据的训练数据集
得到train & test data
'''
def getTrainData(discharge_matrix,true_soc):     
    #循环切片形成数据集
    x=[];y=[]
    x_train=[];y_train=[]
    flag=0

    # 获取得到x,y的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取长度为8的矩阵，叠加循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成4*T的时间维度
            x.append(bataery_data_training)
        flag+=1
    #0-》t时刻d x 预测得到t时刻的soc。为了对soc 进行预测，y矩阵为【7：】
    y=true_soc[8:]
    x=x[:len(x)-1]
#     y=true_capacity[8:]

    VALIDATION_SPLIT=0.9
    x_validation_samples = int( VALIDATION_SPLIT* len(x))
    y_validation_samples = int( VALIDATION_SPLIT*len(y))
    
    
    # 获取得到训练集，验证集，比例9:1
    x_train=np.array(x[:x_validation_samples])
    x_test=np.array(x[x_validation_samples:])
    y_train=np.array(y[:y_validation_samples])
    y_test=np.array(y[y_validation_samples:])
    print("x_train's shape is:", x_train.shape,"，y_train's shape is:",y_train.shape)
    print("x_test's shape is:",x_test.shape,"，y_test's shape is:",y_test.shape)
    return x_train,x_test,y_train,y_test

# %%
# 定义全局变量，将所有电池数据集集合起来，形成训练集，测试集
# x_train_all,x_test_all,y_train_all,y_test_all=[],[],[],[]
for i in range(5,8):
    #/home/aqts/yangHong/battery experiment/jsonData
    discharge=r'/home/aqts/yangHong/battery experiment/jsonData/B000'+str(i)+'_discharge.json'
    discharge_matrix,true_soc=batterydata2matrix(discharge)
    train_x,test_x,train_y,test_y=getTrainData(discharge_matrix,true_soc)
    # start 开始时先赋值给x_train_all，x_test_all，y_train_all，y_test_all
    if i==5:
        x_train_all=train_x
        x_test_all=test_x
        y_train_all=train_y
        y_test_all=test_y
    else:
        x_train_all=np.concatenate((x_train_all,train_x),axis=0)
        x_test_all=np.concatenate((x_test_all,test_x),axis=0)
        y_train_all=np.concatenate((y_train_all,train_y),axis=0)
        y_test_all=np.concatenate((y_test_all,test_y),axis=0)
print(np.array(x_train_all).shape,np.array(x_test_all).shape,np.array(y_train_all).shape,np.array(y_test_all).shape)
# Out:
# x_train's shape is: (144, 8, 3) ，y_train's shape is: (144,)
# x_test's shape is: (16, 8, 3) ，y_test's shape is: (16,)
# x_train's shape is: (144, 8, 3) ，y_train's shape is: (144,)
# x_test's shape is: (16, 8, 3) ，y_test's shape is: (16,)
# x_train's shape is: (144, 8, 3) ，y_train's shape is: (144,)
# x_test's shape is: (16, 8, 3) ，y_test's shape is: (16,)
# (432, 8, 3) (48, 8, 3) (432,) (48,)

# %%
#写一个LossHistory类，保存loss和mae
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D
from keras import backend as k
import matplotlib.pyplot as plt
import numpy as np
from keras import backend as K
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = {'batch':[], 'epoch':[]}
        self.accuracy = {'batch':[], 'epoch':[]}
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_acc = {'batch':[], 'epoch':[]}

    def on_batch_end(self, batch, logs={}):
        self.losses['batch'].append(logs.get('loss'))
        self.accuracy['batch'].append(logs.get('mean_absolute_error'))
        self.val_loss['batch'].append(logs.get('val_loss'))
        self.val_acc['batch'].append(logs.get('val_mean_absolute_error'))

    def on_epoch_end(self, batch, logs={}):
        self.losses['epoch'].append(logs.get('loss'))
        self.accuracy['epoch'].append(logs.get('mean_absolute_error'))
        self.val_loss['epoch'].append(logs.get('val_loss'))
        self.val_acc['epoch'].append(logs.get('val_mean_absolute_error'))

    def loss_plot(self, loss_type):
        iters = range(len(self.losses[loss_type]))
        plt.figure()
        # mae
        plt.plot(iters, self.accuracy[loss_type], 'r', label='train mae')
        # loss
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        if loss_type == 'epoch':
            # val_mean_absolute_error
            plt.plot(iters, self.val_acc[loss_type], 'b', label='val mean absolute error')
            # val_loss
            plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('mae-loss')
        plt.legend(loc="upper right")
        plt.show()
# Out:
# /home/aqts/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# 基于序贯(Sequential)编程方式的模型

# %%
#使用cnn训练的模型
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Convolution2D,GRU,LSTM,Bidirectional
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np
from keras import regularizers
from keras.optimizers import SGD, Adam,RMSprop
from keras.layers.normalization import BatchNormalization
from keras.callbacks import EarlyStopping
# 引用GPU命令
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

img_rows, img_cols =x_train_all.shape[1],x_train_all.shape[2]
num=1

#parameters for LSTM
# cell 里面有四个黄色小框里面，每个小黄框里面的神经元个数
nb_lstm_outputs =300 #神经元个数
nb_time_steps = img_rows  #时间序列长度
nb_input_vector=img_cols

# ,dropout=0.20, recurrent_dropout=0.20,return_sequences=True
tor = img_cols #输入特征序列
#build model
model = Sequential()
# dropout=0.2, recurrent_dropout=0.1,属性return_sequences用于返回数据用于下一层的lstm单元训练
model.add(GRU(units=nb_lstm_outputs, input_shape=(nb_time_steps, nb_input_vector),dropout=0.30))
# # model.add(GRU(64, dropout=0.2, recurrent_dropout=0.1,return_sequences=True))
# model.add(GRU(64, dropout=0.20,recurrent_dropout=0.20))
# model.add(Dropout(0.20))
# # model.add(BatchNormalization())
# model.add(Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001)))
# model.add(Dropout(0.20))

# model.add(Dense(32, activation='tanh'))
# model.add(Dropout(0.20))
model.add(Dense(num,activation="linear"))


model.summary()

#回归问题评价指标使用mae
# # keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=1e-06)
# adam=Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
# rmsprop=RMSprop(lr=0.01, rho=0.9, epsilon=1e-06)
sgd = SGD(lr=0.0005, decay=1e-7, momentum=0.90, nesterov=False)
model.compile(loss='mse', optimizer=sgd, metrics=["mae"])


batch_size =16
num_epoch =64

#model training
history = LossHistory()

# early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=2)

model.fit(x_train_all, y_train_all,
          batch_size=batch_size,
          epochs=num_epoch,
          verbose=1,validation_split=0.3,shuffle=True,callbacks=[history])

mse_score,mae_score= model.evaluate(x_test_all, y_test_all, verbose=0)
print('Test MSE Score:%.3f %%'% (mse_score*100)) 
print('Test MAE Score:%.3f %%'% (mae_score*100))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_57 (GRU)                 (None, 300)               273600
# _________________________________________________________________
# dense_58 (Dense)             (None, 1)                 301
# =================================================================
# Total params: 273,901
# Trainable params: 273,901
# Non-trainable params: 0
# _________________________________________________________________
# Train on 302 samples, validate on 130 samples
# Epoch 1/64
# 302/302 [==============================] - 5s 17ms/step - loss: 0.4996 - mean_absolute_error: 0.6938 - val_loss: 0.3118 - val_mean_absolute_error: 0.5580
# Epoch 2/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.1545 - mean_absolute_error: 0.3699 - val_loss: 0.0854 - val_mean_absolute_error: 0.2658
# Epoch 3/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0350 - mean_absolute_error: 0.1579 - val_loss: 0.0166 - val_mean_absolute_error: 0.1179
# Epoch 4/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0063 - mean_absolute_error: 0.0653 - val_loss: 0.0035 - val_mean_absolute_error: 0.0543
# Epoch 5/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0032 - mean_absolute_error: 0.0413 - val_loss: 0.0013 - val_mean_absolute_error: 0.0303
# Epoch 6/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0022 - mean_absolute_error: 0.0343 - val_loss: 0.0010 - val_mean_absolute_error: 0.0271
# Epoch 7/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0325 - val_loss: 0.0011 - val_mean_absolute_error: 0.0275
# Epoch 8/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0022 - mean_absolute_error: 0.0349 - val_loss: 0.0012 - val_mean_absolute_error: 0.0286
# Epoch 9/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0024 - mean_absolute_error: 0.0346 - val_loss: 0.0011 - val_mean_absolute_error: 0.0276
# Epoch 10/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0335 - val_loss: 0.0011 - val_mean_absolute_error: 0.0282
# Epoch 11/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0327 - val_loss: 0.0013 - val_mean_absolute_error: 0.0307
# Epoch 12/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0019 - mean_absolute_error: 0.0335 - val_loss: 0.0013 - val_mean_absolute_error: 0.0304
# Epoch 13/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0025 - mean_absolute_error: 0.0373 - val_loss: 0.0012 - val_mean_absolute_error: 0.0293
# Epoch 14/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0022 - mean_absolute_error: 0.0357 - val_loss: 0.0012 - val_mean_absolute_error: 0.0290
# Epoch 15/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0022 - mean_absolute_error: 0.0337 - val_loss: 0.0011 - val_mean_absolute_error: 0.0283
# Epoch 16/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0022 - mean_absolute_error: 0.0341 - val_loss: 0.0012 - val_mean_absolute_error: 0.0291
# Epoch 17/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0341 - val_loss: 0.0012 - val_mean_absolute_error: 0.0286
# Epoch 18/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0325 - val_loss: 0.0011 - val_mean_absolute_error: 0.0280
# Epoch 19/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0353 - val_loss: 0.0012 - val_mean_absolute_error: 0.0286
# Epoch 20/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0023 - mean_absolute_error: 0.0349 - val_loss: 0.0013 - val_mean_absolute_error: 0.0300
# Epoch 21/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0340 - val_loss: 0.0012 - val_mean_absolute_error: 0.0287
# Epoch 22/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0353 - val_loss: 0.0011 - val_mean_absolute_error: 0.0284
# Epoch 23/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0338 - val_loss: 0.0012 - val_mean_absolute_error: 0.0292
# Epoch 24/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0331 - val_loss: 0.0012 - val_mean_absolute_error: 0.0293
# Epoch 25/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0018 - mean_absolute_error: 0.0316 - val_loss: 0.0012 - val_mean_absolute_error: 0.0296
# Epoch 26/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0347 - val_loss: 0.0013 - val_mean_absolute_error: 0.0298
# Epoch 27/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0023 - mean_absolute_error: 0.0351 - val_loss: 0.0013 - val_mean_absolute_error: 0.0300
# Epoch 28/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0336 - val_loss: 0.0014 - val_mean_absolute_error: 0.0312
# Epoch 29/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0343 - val_loss: 0.0014 - val_mean_absolute_error: 0.0315
# Epoch 30/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0022 - mean_absolute_error: 0.0340 - val_loss: 0.0014 - val_mean_absolute_error: 0.0325
# Epoch 31/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0342 - val_loss: 0.0013 - val_mean_absolute_error: 0.0301
# Epoch 32/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0335 - val_loss: 0.0012 - val_mean_absolute_error: 0.0288
# Epoch 33/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0025 - mean_absolute_error: 0.0367 - val_loss: 0.0013 - val_mean_absolute_error: 0.0303
# Epoch 34/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0024 - mean_absolute_error: 0.0370 - val_loss: 0.0013 - val_mean_absolute_error: 0.0300
# Epoch 35/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0332 - val_loss: 0.0012 - val_mean_absolute_error: 0.0289
# Epoch 36/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0019 - mean_absolute_error: 0.0321 - val_loss: 0.0013 - val_mean_absolute_error: 0.0309
# Epoch 37/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0023 - mean_absolute_error: 0.0349 - val_loss: 0.0013 - val_mean_absolute_error: 0.0297
# Epoch 38/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0332 - val_loss: 0.0011 - val_mean_absolute_error: 0.0280
# Epoch 39/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0019 - mean_absolute_error: 0.0333 - val_loss: 0.0011 - val_mean_absolute_error: 0.0281
# Epoch 40/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0332 - val_loss: 0.0012 - val_mean_absolute_error: 0.0289
# Epoch 41/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0022 - mean_absolute_error: 0.0342 - val_loss: 0.0013 - val_mean_absolute_error: 0.0308
# Epoch 42/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0019 - mean_absolute_error: 0.0319 - val_loss: 0.0013 - val_mean_absolute_error: 0.0301
# Epoch 43/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0330 - val_loss: 0.0013 - val_mean_absolute_error: 0.0304
# Epoch 44/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0024 - mean_absolute_error: 0.0352 - val_loss: 0.0012 - val_mean_absolute_error: 0.0293
# Epoch 45/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0024 - mean_absolute_error: 0.0358 - val_loss: 0.0012 - val_mean_absolute_error: 0.0291
# Epoch 46/64
# 302/302 [==============================] - 0s 2ms/step - loss: 0.0022 - mean_absolute_error: 0.0354 - val_loss: 0.0011 - val_mean_absolute_error: 0.0279
# Epoch 47/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0343 - val_loss: 0.0011 - val_mean_absolute_error: 0.0278
# Epoch 48/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0027 - mean_absolute_error: 0.0379 - val_loss: 0.0013 - val_mean_absolute_error: 0.0302
# Epoch 49/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0022 - mean_absolute_error: 0.0346 - val_loss: 0.0013 - val_mean_absolute_error: 0.0302
# Epoch 50/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0022 - mean_absolute_error: 0.0342 - val_loss: 0.0012 - val_mean_absolute_error: 0.0294
# Epoch 51/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0024 - mean_absolute_error: 0.0350 - val_loss: 0.0012 - val_mean_absolute_error: 0.0296
# Epoch 52/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0023 - mean_absolute_error: 0.0349 - val_loss: 0.0012 - val_mean_absolute_error: 0.0288
# Epoch 53/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0017 - mean_absolute_error: 0.0309 - val_loss: 0.0012 - val_mean_absolute_error: 0.0289
# Epoch 54/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0022 - mean_absolute_error: 0.0345 - val_loss: 0.0011 - val_mean_absolute_error: 0.0277
# Epoch 55/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0335 - val_loss: 0.0012 - val_mean_absolute_error: 0.0284
# Epoch 56/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0339 - val_loss: 0.0011 - val_mean_absolute_error: 0.0282
# Epoch 57/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0025 - mean_absolute_error: 0.0366 - val_loss: 0.0011 - val_mean_absolute_error: 0.0275
# Epoch 58/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0024 - mean_absolute_error: 0.0364 - val_loss: 0.0012 - val_mean_absolute_error: 0.0288
# Epoch 59/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0020 - mean_absolute_error: 0.0340 - val_loss: 0.0013 - val_mean_absolute_error: 0.0301
# Epoch 60/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0023 - mean_absolute_error: 0.0340 - val_loss: 0.0012 - val_mean_absolute_error: 0.0289
# Epoch 61/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0023 - mean_absolute_error: 0.0341 - val_loss: 0.0012 - val_mean_absolute_error: 0.0287
# Epoch 62/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0349 - val_loss: 0.0012 - val_mean_absolute_error: 0.0286
# Epoch 63/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0019 - mean_absolute_error: 0.0326 - val_loss: 0.0013 - val_mean_absolute_error: 0.0300
# Epoch 64/64
# 302/302 [==============================] - 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0337 - val_loss: 0.0014 - val_mean_absolute_error: 0.0310
# Test MSE Score:0.287 %
# Test MAE Score:4.325 %

# %%
#绘制mae-loss曲线
history.loss_plot('epoch')
# input_shape[]

# %% [markdown]
# 获取得到需要用于预测的电池数据集B0018号电池

# %%
# 获取预测所需的电池数据集
def getBattery008data(discharge_matrix):
    x_pred=[]
    flag=0

    # 获取得到x_pred的数据集
    for i in range(len(discharge_matrix.tolist())):
        #首先截取0--37这段的长度，叠加+1循环得到x
        bataery_data_training=discharge_matrix[flag:flag+8,:]
    #     print(bataery_data_training.shape)
        if(len(bataery_data_training)<8):
            break
        else:
            #进行转置，形成3*T的时间维度
            x_pred.append(bataery_data_training)
        flag+=1

    x_pred=np.array(x_pred[:len(x_pred)-1])
    return x_pred

# return prediction  data &  prediction  data true_so
discharge_008=r'/home/aqts/yangHong/battery experiment/jsonData/B0008_discharge.json'
# 获取得到一节电池的 特征向量 与true soc 
discharge_matrix_008,true_soc_008 =batterydata2matrix(discharge_008)
# 得到预测样本集 t=7
x_test_008=getBattery008data(discharge_matrix_008)


print("x_test_008 data shape is",x_test_008.shape)
# Out:
# x_test_008 data shape is (124, 8, 3)

# %%
pred=model.predict(x_test_008, batch_size=16, verbose=0)
print(pred.shape)
# Out:
# (124, 1)

# %%
import pandas as pd # 导入pandas库用来处理csv文件
import matplotlib.pyplot as plt # 导入matplotlib.pyplot并用plt简称

# true soc predict plot
x_true_soc=range(len(true_soc_008))
# 切割开始的基数一定为7
start=8
x_test_soc_008=range(start,start+pred.shape[0])
print("x_true_soc range is ",x_true_soc,"\n x_test_soc_008  range is:",x_test_soc_008)
plt.plot(x_true_soc, true_soc_008, linewidth=2.0, color='r',label="True SOC")#线的宽度为2.0，颜色为红色
plt.plot(x_test_soc_008, pred, linewidth=2.0, color='g',label="Prediction SOC")#线的宽度为2.0，颜色为绿色


# 设置x ,y轴的步长与刻度属性
plt.xticks([x for x in range(len(x_true_soc) + 1) if x %10 == 0])  # x标记step设置为10
plt.ylim(ymin=0.3,ymax=1.1)
# remark for x & y
plt.xlabel('Cylce')
plt.ylabel('SOC')
plt.title('Real Soc and Predicted Soc')

plt.legend()
plt.show()#显示图像
# Out:
# x_true_soc range is  range(0, 132)
#  x_test_soc_008  range is: range(8, 132)
